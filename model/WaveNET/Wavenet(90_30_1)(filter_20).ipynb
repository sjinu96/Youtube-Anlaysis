# %%
import os
from datetime import datetime, date
from sklearn import utils
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as fn
import torch.optim as optim

device = 'cuda:1' if torch.cuda.is_available() else 'cpu'
plt.style.use('ggplot')

# %% [markdown]
# ### 0. Utils

# %% [markdown]
# ### 1-1. Preprocessor

# %%
class Preprocessor:
    def _fit_transform(self, raw):
        result = raw.copy()

        result = self._n_comment_to_float(result)
        result = self._str_to_datetype(result)
        result = self._add_n_hashtag(result)
        
        self.non_numeric = ['channel', 'title', 'genre', 'description', 'date', 'sign_in']
        result = self._merge(result, self.non_numeric)
        
        features = ['cumul_view', 'n_dislike', 'n_like', 'n_comment', 'video_n_view', 'cumul_subs']
        new_name = ['view_diff', 'dislike_diff', 'like_diff', 'comment_diff', 'video_n_view_diff', 'sub_diff']
        result = self._add_diff(result, features, new_name)
        
        result = self._add_no_upload_interval(result)
        result = self._remove_nan(result)
        self._one_hot(result)

        return result
        
        
        
    #FEATRUES TO ADD & MODIFY
    ####################################################################     
    def _n_comment_to_float(self,result):
        idx1 = result['n_comment'] == '댓글 사용 중지'
        idx2 = result.n_comment.isna()
        idx = idx1|idx2
        result['n_comment'].loc[idx] = result['n_comment'].loc[idx].apply(lambda x: 0)
        result['n_comment'] = result['n_comment'].astype(float)
        return result
        
    
    def _str_to_datetype(self,result):
        if pd.api.types.is_datetime64_ns_dtype(result['date']):
            pass
        else:
            result['date'] = pd.to_datetime(result['date'])
        return result
    
    
    def _add_n_hashtag(self,result):
        result['n_hashtage'] = 0
        idx = result['description'].notnull()
        result.loc[idx, 'n_hashtage'] = result.loc[idx, 'description'].apply(lambda x: len(x.split('#'))-1)
        return result
        
    
    @staticmethod
    def _get_to_merge(data, numeric, non_numeric):
        data = data.reset_index(drop=True)
        num_to_add = data.title.shape[0] - data.title.isna().sum()
        data = pd.concat((data.loc[0,non_numeric], data[numeric].mean()))
        data['video_num'] = num_to_add
        return data
    def _merge(self, result, non_numeric):
        #operate both merge and creating video_num featrue simultaneously.
        numeric = [col for col in result.columns.tolist() if col not in non_numeric]
        return result.groupby(['channel', 'date']).apply(lambda x: self._get_to_merge(x, numeric, non_numeric)).reset_index(drop=True)
    
    
    @staticmethod
    def _get_diff(result, feature, new_name):
        result = result.reset_index(drop=True)
        result[new_name] = (result[feature] - result[feature].shift())
        return result
    def _add_diff(self, result, feature, new_name):
        result = result.groupby('channel').apply(lambda x: self._get_diff(x, feature, new_name)).reset_index(drop=True)
        result[new_name] = result[new_name].fillna(0)
        return result
    
    
    @staticmethod
    def _get_no_upload_interval(result):
        result = result.reset_index(drop=True)
        upload_idx = result[result['video_num'] != 0].index.tolist()
        temp = [0 for i in range(result.shape[0])]
        for i in range(len(upload_idx)):
            if i == len(upload_idx)-1:
                former = upload_idx[i]
                temp[former+1:] = [i+1 for i in range(len(temp[former+1:]))]
            else:
                former, latter = upload_idx[i], upload_idx[i+1]
                temp[former+1:latter] = [i+1 for i in range(len(temp[former+1:latter]))]
        result['no_upload_interval'] = temp
        return result
    def _add_no_upload_interval(self,result):
        return result.groupby('channel').apply(lambda x: self._get_no_upload_interval(x)).reset_index(drop=True)
    
    
    def _remove_nan(self, result):
        numeric = [col for col in result.columns.tolist() if col not in self.non_numeric]
        result.loc[:, numeric] = result.loc[:,numeric].fillna(0)
        return result
    
    
    def _one_hot(self, data):
        data.loc[:,'genre'] = data.genre.fillna('etc')
        genre = data.genre.unique().tolist()
        for i, name in enumerate(genre):
            data.genre[data.genre==name] = data.genre[data.genre==name].apply(lambda x: i)
            
        one_hot = pd.get_dummies(data.genre.unique().tolist())
        data['one_hot'] = data.genre
        for i in range(len(one_hot)):
            data.loc[data.genre==i,'one_hot'] = data.loc[data.genre==i, 'genre'].apply(lambda x: one_hot[i].values)
    ####################################################################
    
    
    
    #CREATE SEQUENTIAL DATA
    ####################################################################
    def _extract_at_least_filter(self, result, filter_size):
        #fillter_size 이상인 채널 추출하기
        alive_idx = result['channel'].value_counts() >= filter_size
        alive_array = alive_idx[alive_idx==True].index
        return result[result['channel'].isin(alive_array)].reset_index(drop=True)
    
    
    @staticmethod
    def _to_sequential(result, filter_size, target_size, stride, features, target_features):
        result = result.reset_index(drop=True)
        idx_list = result.index.tolist()
        
        train, target = [],[]
        for i in range((len(idx_list)-filter_size-target_size)//stride +1):
            train_idx = idx_list[i*stride : i*stride + filter_size]
            target_idx = idx_list[i*stride + filter_size : i*stride + filter_size + target_size]
            train_temp = result.loc[train_idx,:].values.reshape(1,-1)
            target_temp = result.loc[target_idx,target_features].values.reshape(1,-1)
            
            train = train_temp.copy() if i == 0 else np.vstack([train, train_temp])
            target = target_temp.copy() if i == 0 else np.vstack([target, target_temp])
            
        train = pd.DataFrame(train, columns = result.columns.tolist()*filter_size)
        target = pd.DataFrame(target, columns = target_features*target_size)
        return train[features], target
    def _create_sequential_data(self, result, filter_size=7, target_size=1, stride=1, features=None, target_features=None):
        #remove channels with few information with respect to filter_size and target_size to extract
        result = self._extract_at_least_filter(result, filter_size + target_size)
        
        #features: features to drop fromf X (features)
        #target_features: features to extract from Y (targets)
        if features is None:
            features = ['date', 'genre','title', 'channel', 'description',	'sign_in', 'current_cumul_view', 'current_n_video', 'current_cumul_subs']
        if target_features is None:
            target_features = ['sub_diff']
        
        #return train, target set wrt groups
        result = result.groupby('channel').apply(lambda x: self._to_sequential(x, filter_size, target_size, stride, features, target_features)).reset_index(drop=True)
        return self._combine(result)
    
    
    def _combine(self, result):
        temp0, temp1 = [], []
        for i in range(len(result)):
            temp0.append(result[i][0])
            temp1.append(result[i][1])
        temp0 = pd.concat(temp0)
        temp1 = pd.concat(temp1)
        return (temp0, temp1)
    ####################################################################


    
    #SCALE
    ####################################################################
    def scale(self, data, return_original_scale=True):
        original_scale = pd.concat((data.max(), data.min()), axis=1).T
        original_scale.index=['max', 'min']
        scaler = preprocessing.MinMaxScaler()
        data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
        if return_original_scale:
            return data, original_scale
        return data
    
        
    def inverse_scale(self, pred, scl):
        for idx in range(pred.shape[1]):
            pred.iloc[:,idx] = (scl.iloc[0,idx]-scl.iloc[1,idx])*pred.iloc[:,idx]+scl.iloc[1,idx]

# %% [markdown]
# ### 1-2. Data Loader

# %%
class Loader(Preprocessor):
    def __init__(self, path):
        self._raw = pd.read_csv(path)
        self.data = super()._fit_transform(self._raw.copy())
        print('Data Loaded. :P')
        
        
    def get_data(self, filter_size=7, target_size=1, stride=1, features=None, target_features=None,
                         channel:list=None, shuffle=False, random_state=None, order=None):
        if channel is None:
            data_to_extract = self.data
        else:
            channels = self.list_channel[channel].tolist()
            data_to_extract = self.data.set_index('channel').loc[channels].reset_index()
            
        train, target = self._create_sequential_data(data_to_extract, filter_size, target_size, stride, features, target_features)
        if shuffle:
            train, target = utils.shuffle(train, target, random_state=random_state)
        
        if order:
            train_col = [col for col in train.columns.unique().tolist()]
            target_col = [col for col in target.columns.unique().tolist()]
            train, target = train[train_col], target[target_col]
            
        return train, target

    
    @property
    def list_features(self):
        #list the entire features, hence you can choose which features are included in whole set.
        return self.data.columns.tolist()
    
    @property
    def list_channel(self):
        #list indices of channel.
        return pd.Series(self.data.channel.unique().tolist())

# %% [markdown]
# > load함수

# %%
def load(
    filter_size: '60, 90, 180', 
    target_size: '1, 7, 30, 180', 
    stride: '1, 2, 3',
    drop_suffix: '각 변수 끝에 붙은 번호를 제거할지 여부'=True,
    path='/home/mskang/CapstoneUOS/notebooks/ModelResearch_iloveslowfood/data_variants'):
    
    print(f'Setting: filter_size({filter_size})\ttarget_size({target_size})\tstride({stride})\tdrop_suffix({drop_suffix})')
    X_name = f'fs({filter_size})_ts({target_size})_st({stride}).csv'
    y_name = f'fs({filter_size})_ts({target_size})_st({stride})_label.csv'
    
    print('Load feature data...', end='\t')
    X = pd.read_csv(os.path.join(path, X_name))
    print('loaded!')
    print('Load label data...', end='\t')
    y = pd.read_csv(os.path.join(path, y_name))
    print('loaded!')
    
    if drop_suffix:
        X.columns = list(map(lambda x: x.split('.')[0], X.columns.tolist()))
        y.columns = list(map(lambda x: x.split('.')[0], y.columns.tolist()))
    return X, y

# %% [markdown]
# > 데이터 불러오기

# %%
filter_size = 90
target_size = 30
stride = 1
X, y = load(filter_size, target_size, stride)
# Out:
# Setting: filter_size(90)	target_size(30)	stride(1)	drop_suffix(True)
# Load feature data...	loaded!
# Load label data...	loaded!

# %% [markdown]
# > Train/Test/VAlid 분할

# %%
random_state = 42
test_size = 0.2

X_trn, X_test, y_trn, y_test = train_test_split(
    X, y, 
    shuffle=True, 
    test_size=test_size, 
    random_state=random_state
) 

X_train, X_valid, y_train, y_valid = train_test_split(
    X_trn, y_trn, 
    shuffle=True, 
    test_size=test_size, 
    random_state=random_state
) 

### 스케일링 필요 시 다음을 진행(타깃에 대한 스케일링은 진행되지 않음)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# scaler = MinMaxScaler()
# X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
# X_valid_scaled = pd.DataFrame(scaler.transform(X_valid), columns=X_valid.columns)
# X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# ### 2D TO 3D

# %%
def stack_to_multi(df):
    feature_num=len(set(df.columns))
    window_num=int(df.shape[1]/feature_num)
    sample_num=int(df.shape[0])
    temp=np.empty([sample_num,window_num,feature_num])
    for i in range(feature_num):
        temp[:,:,i]=df.iloc[:,window_num*i:window_num*i+window_num]
    
    return temp

# %%
X_train
# Out:
#         duration  duration  duration   duration   duration   duration  \
# 121697      0.00      0.00      0.00   0.000000   0.000000   0.000000
# 129642      2.00      2.08      2.00   2.670000   1.600000   1.750000
# 86794       0.00      0.00      0.00   0.000000   0.000000   0.000000
# 6042        8.88      0.00      1.77  14.776667   7.371667   9.296667
# 32195       0.00      0.00     31.92   0.000000  11.100000  11.400000
# ...          ...       ...       ...        ...        ...        ...
# 3285        7.22      0.00      6.98   7.000000   9.950000   0.000000
# 66254       0.00      0.00      0.00   0.000000   0.000000   0.000000
# 52248       0.00      0.00      0.00   0.000000   0.000000   0.000000
# 100988      0.00      0.00      0.00   0.000000   0.000000   0.000000
# 70219       0.00      2.97      0.00   0.000000   0.000000   0.000000
#
#         duration  duration  duration  duration  ...  no_upload_interval  \
# 121697      0.00       0.0     0.000       0.0  ...                   0
# 129642      0.00       0.0     0.000       0.0  ...                   1
# 86794       0.00       0.0     0.000       0.0  ...                   2
# 6042       14.15       0.0    16.575       0.0  ...                   0
# 32195       0.00       0.0     0.000       0.0  ...                   0
# ...          ...       ...       ...       ...  ...                 ...
# 3285      157.73       0.0     0.000       0.0  ...                   3
# 66254       0.00       0.0     0.000       0.0  ...                   0
# 52248       0.00       0.0     0.000       0.0  ...                  15
# 100988      0.00       0.0     0.000       0.0  ...                  89
# 70219       0.00       0.0     0.000       0.0  ...                   6
#
#         no_upload_interval  no_upload_interval  no_upload_interval  \
# 121697                   0                   0                   0
# 129642                   2                   0                   1
# 86794                    0                   1                   2
# 6042                     1                   0                   1
# 32195                    1                   2                   0
# ...                    ...                 ...                 ...
# 3285                     4                   5                   0
# 66254                    0                   0                   0
# 52248                   16                  17                  18
# 100988                  90                  91                  92
# 70219                    7                   8                   9
#
#         no_upload_interval  no_upload_interval  no_upload_interval  \
# 121697                   0                   0                   0
# 129642                   2                   0                   1
# 86794                    3                   4                   5
# 6042                     2                   0                   0
# 32195                    1                   2                   0
# ...                    ...                 ...                 ...
# 3285                     1                   2                   3
# 66254                    0                   0                   0
# 52248                   19                  20                  21
# 100988                  93                  94                  95
# 70219                   10                  11                  12
#
#         no_upload_interval  no_upload_interval  no_upload_interval
# 121697                   0                   0                   0
# 129642                   2                   0                   1
# 86794                    6                   0                   0
# 6042                     1                   2                   0
# 32195                    1                   0                   1
# ...                    ...                 ...                 ...
# 3285                     4                   0                   1
# 66254                    0                   0                   0
# 52248                   22                  23                  24
# 100988                  96                  97                   0
# 70219                   13                  14                  15
#
# [101780 rows x 1530 columns]

# %%
X_train_3d=stack_to_multi(X_train)
X_valid_3d=stack_to_multi(X_valid)
X_test_3d=stack_to_multi(X_test)

# %%
print(X_train_3d.shape)
print(X_valid_3d.shape)
print(X_test_3d.shape)
# Out:
# (101780, 90, 17)
# (25445, 90, 17)
# (31807, 90, 17)

# %%
print(y_train.shape)
print(y_valid.shape)
print(y_test.shape)
# Out:
# (101780, 30)
# (25445, 30)
# (31807, 30)

# %% [markdown]
# #### 3D 스케일링, 타겟 스케일링

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=preprocessing.MinMaxScaler()
#scaler_y=preprocessing.MinMaxScaler()
def fit_3d(x_train,x_val,x_test):
    x_train_sample = x_train.shape[0] #샘플 개수
    x_val_sample=x_val.shape[0]
    x_test_sample=x_test.shape[0]
    
    x_timestep = x_train.shape[1] # timestep
    x_feature = x_train.shape[2]# feature 차원 
    scaler=MinMaxScaler()
    for ss in range(x_timestep):
        scaler.partial_fit(x_train[:, ss, :]) # 순회피팅

    results1,results2,results3=([],[],[])
    for ss in range(x_timestep):
        results1.append(scaler.transform(x_train[:, ss, :]).reshape(x_train_sample, 1, x_feature))
        results2.append(scaler.transform(x_val[:,ss,:]).reshape(x_val_sample,1,x_feature))
        results3.append(scaler.transform(x_test[:,ss,:]).reshape(x_test_sample,1,x_feature))
    df_train_scaled = np.concatenate(results1, axis=1) #합치기.
    df_val_scaled=np.concatenate(results2,axis=1)
    df_test_scaled=np.concatenate(results3,axis=1)
    
    
    
    return df_train_scaled,df_val_scaled,df_test_scaled

# %%
X_train_scaled,X_valid_scaled,X_test_scaled=fit_3d(X_train_3d, X_valid_3d, X_test_3d)

# %% [markdown]
# > target shape 변경 ( 샘플 x 타입스텝 x 예측일수)

# %%
X_train_subdiff=X_train['sub_diff']
X_valid_subdiff=X_valid['sub_diff']
X_test_subdiff=X_test['sub_diff']

# %%
X_train_subdiff[:]
# Out:
#         sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  \
# 121697      10.0      20.0      15.0      15.0      20.0      10.0      20.0
# 129642       0.0     200.0     800.0     500.0    1200.0      99.0     601.0
# 86794      100.0     100.0     100.0     100.0     100.0     100.0     100.0
# 6042        15.0      15.0      10.0      30.0      20.0      20.0      15.0
# 32195        0.0       0.0    1000.0    1500.0    1500.0    1000.0       0.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 3285        -5.0      -3.0      -2.0       0.0       0.0       0.0      85.0
# 66254        2.0       1.0       2.0       1.0       1.0       2.0       1.0
# 52248      200.0     200.0     200.0     100.0     100.0     200.0      99.0
# 100988       4.0       4.0       4.0       4.0       4.0       4.0       3.0
# 70219      250.0     250.0     500.0     700.0     400.0     200.0     200.0
#
#         sub_diff  sub_diff  sub_diff  ...  sub_diff  sub_diff  sub_diff  \
# 121697      10.0      15.0      15.0  ...       0.0       0.0      30.0
# 129642     100.0     100.0       0.0  ...     100.0     200.0     100.0
# 86794      100.0     100.0     100.0  ...     100.0     100.0     100.0
# 6042        15.0      30.0      20.0  ...      15.0      15.0      10.0
# 32195     1000.0     500.0     500.0  ...     700.0       0.0    1000.0
# ...          ...       ...       ...  ...       ...       ...       ...
# 3285        85.0      10.0     -30.0  ...      10.0      36.0      37.0
# 66254        1.0       2.0       0.0  ...       0.0       0.0       5.0
# 52248      101.0      99.0     101.0  ...     300.0     100.0     100.0
# 100988       4.0       4.0       4.0  ...       0.0      20.0       5.0
# 70219      299.0     201.0     300.0  ...     200.0     300.0     200.0
#
#         sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff
# 121697      25.0      55.0      40.0      20.0      20.0       0.0      10.0
# 129642     100.0     100.0       0.0     200.0       0.0     100.0     100.0
# 86794      100.0     100.0     100.0     100.0     100.0       0.0     100.0
# 6042        15.0      15.0      10.0      20.0      10.0      10.0      10.0
# 32195        0.0       0.0       0.0    1000.0       0.0     500.0     500.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 3285        37.0      40.0      40.0      40.0      20.0      30.0      30.0
# 66254        5.0       6.0       7.0       7.0       0.0      10.0       0.0
# 52248      200.0     100.0     200.0     100.0     100.0      99.0     201.0
# 100988       5.0      10.0      30.0      20.0       0.0      20.0      30.0
# 70219      300.0     200.0     300.0     200.0     300.0     200.0     300.0
#
# [101780 rows x 90 columns]

# %%
# (샘플개수 , (180+30)의 TARGET
temp1=pd.concat([X_train_subdiff,y_train],axis=1)
temp2=pd.concat([X_valid_subdiff,y_valid],axis=1)
temp3=pd.concat([X_test_subdiff,y_test],axis=1)

# %%
# (샘플, timestep, targetsize)
y_train_3d=np.empty((X_train_subdiff.shape[0],X_train_subdiff.shape[1],30)) # 30 : targetsize
y_valid_3d=np.empty((X_valid_subdiff.shape[0],X_valid_subdiff.shape[1],30))
y_test_3d=np.empty((X_test_subdiff.shape[0],X_test_subdiff.shape[1],30))

# %%
for t in range(X_train_subdiff.shape[1]): # 180 Timestep
    y_train_3d[:,t]=temp1.iloc[:,t:t+30]
    y_valid_3d[:,t]=temp2.iloc[:,t:t+30]
    y_test_3d[:,t]=temp3.iloc[:,t:t+30]

# %%
print(y_train_3d.shape)
print(y_valid_3d.shape)
print(y_test_3d.shape)
# Out:
# (101780, 90, 30)
# (25445, 90, 30)
# (31807, 90, 30)

# %% [markdown]
# > y scaling

# %%
y_train_temp=y_train_3d.reshape(-1,1)
y_valid_temp=y_valid_3d.reshape(-1,1)
y_test_temp=y_test_3d.reshape(-1,1)

# %%
scaler_y=MinMaxScaler()
y_train_scaled=scaler_y.fit_transform(y_train_temp)
y_val_scaled=scaler_y.transform(y_valid_temp)
y_test_scaled=scaler_y.transform(y_test_temp)

# %%
y_train_scaled=y_train_scaled.reshape(y_train_3d.shape[0],y_train_3d.shape[1],y_train_3d.shape[2])
y_valid_scaled=y_val_scaled.reshape(y_valid_3d.shape[0],y_valid_3d.shape[1],y_valid_3d.shape[2])
y_test_scaled=y_test_scaled.reshape(y_test_3d.shape[0],y_test_3d.shape[1],y_test_3d.shape[2])

# %%
print(y_train_scaled.shape)
print(y_valid_scaled.shape)
print(y_test_scaled.shape)
# Out:
# (101780, 90, 30)
# (25445, 90, 30)
# (31807, 90, 30)

# %% [markdown]
# > MODEL

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# > 마지막 Timestep의 loss만 중요하다.

# %%
def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_absolute_error(Y_true[:, -1], Y_pred[:, -1]) #### <<-

# %% [markdown]
# ### Wavenet

# %% [markdown]
# >MODEL

# %%
model_Full=keras.models.Sequential()
model_Full.add(keras.layers.InputLayer(input_shape=[None,17]))
for rate in (1,2,4,8)*2:
    model_Full.add(keras.layers.Conv1D(filters=60,kernel_size=2,padding="causal",
                                 activation='relu',dilation_rate=rate))
model_Full.add(keras.layers.Conv1D(filters=30,kernel_size=1))
model_Full.compile(loss="mae", optimizer='adam', metrics=[last_time_step_mse])

# %%
model_Full.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_9 (Conv1D)            (None, None, 60)          2100
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, None, 60)          7260
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, None, 60)          7260
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, None, 60)          7260
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, None, 60)          7260
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, None, 60)          7260
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, None, 60)          7260
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, None, 60)          7260
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, None, 30)          1830
# =================================================================
# Total params: 54,750
# Trainable params: 54,750
# Non-trainable params: 0
# _________________________________________________________________

# %%
filename='Wavenet(90_30_1)(filter=20).h5'
callback_list1 = [tf.keras.callbacks.ModelCheckpoint(filepath='Checkpoint/{}'.format(filename),
                                                    monitor='val_last_time_step_mse',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min'),
                 tf.keras.callbacks.EarlyStopping(monitor='val_last_time_step_mse',
                                                  patience=15)]

# %%
model_Full=keras.models.Sequential()
model_Full.add(keras.layers.InputLayer(input_shape=[None,17]))
for rate in (1,2,4,8)*2:
    model_Full.add(keras.layers.Conv1D(filters=20,kernel_size=2,padding="causal",
                                 activation='relu',dilation_rate=rate))
model_Full.add(keras.layers.Conv1D(filters=30,kernel_size=1))
model_Full.compile(loss="mae", optimizer='adam', metrics=[last_time_step_mse])

# %%
model_Full.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, None, 20)          700
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 20)          820
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, None, 20)          820
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, None, 20)          820
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, None, 20)          820
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, None, 20)          820
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, None, 20)          820
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, None, 20)          820
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, None, 30)          630
# =================================================================
# Total params: 7,070
# Trainable params: 7,070
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_Full= model_Full.fit(X_train_scaled, y_train_scaled, epochs=100,
                    validation_data=(X_valid_scaled,y_valid_scaled),callbacks=callback_list1)
# Out:
# Epoch 1/100
# 3181/3181 [==============================] - ETA: 0s - loss: 0.0011 - last_time_step_mse: 0.0011
# Epoch 00001: val_last_time_step_mse improved from inf to 0.00084, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 85s 27ms/step - loss: 0.0011 - last_time_step_mse: 0.0011 - val_loss: 8.2251e-04 - val_last_time_step_mse: 8.4362e-04
# Epoch 2/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 8.4221e-04 - last_time_step_mse: 8.7235e-04
# Epoch 00002: val_last_time_step_mse improved from 0.00084 to 0.00082, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 78s 25ms/step - loss: 8.4232e-04 - last_time_step_mse: 8.7250e-04 - val_loss: 7.9688e-04 - val_last_time_step_mse: 8.2013e-04
# Epoch 3/100
# 3178/3181 [============================>.] - ETA: 0s - loss: 8.0574e-04 - last_time_step_mse: 8.3706e-04
# Epoch 00003: val_last_time_step_mse did not improve from 0.00082
# 3181/3181 [==============================] - 61s 19ms/step - loss: 8.0572e-04 - last_time_step_mse: 8.3722e-04 - val_loss: 8.1499e-04 - val_last_time_step_mse: 8.3139e-04
# Epoch 4/100
# 3181/3181 [==============================] - ETA: 0s - loss: 7.7954e-04 - last_time_step_mse: 8.1137e-04
# Epoch 00004: val_last_time_step_mse improved from 0.00082 to 0.00079, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 66s 21ms/step - loss: 7.7954e-04 - last_time_step_mse: 8.1137e-04 - val_loss: 7.5991e-04 - val_last_time_step_mse: 7.9450e-04
# Epoch 5/100
# 3181/3181 [==============================] - ETA: 0s - loss: 8.1201e-04 - last_time_step_mse: 8.4344e-04
# Epoch 00005: val_last_time_step_mse did not improve from 0.00079
# 3181/3181 [==============================] - 65s 21ms/step - loss: 8.1201e-04 - last_time_step_mse: 8.4344e-04 - val_loss: 7.9125e-04 - val_last_time_step_mse: 8.1406e-04
# Epoch 6/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 7.6042e-04 - last_time_step_mse: 7.9195e-04
# Epoch 00006: val_last_time_step_mse did not improve from 0.00079
# 3181/3181 [==============================] - 64s 20ms/step - loss: 7.6052e-04 - last_time_step_mse: 7.9208e-04 - val_loss: 8.1493e-04 - val_last_time_step_mse: 8.3296e-04
# Epoch 7/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 7.4530e-04 - last_time_step_mse: 7.7654e-04
# Epoch 00007: val_last_time_step_mse improved from 0.00079 to 0.00073, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 66s 21ms/step - loss: 7.4530e-04 - last_time_step_mse: 7.7653e-04 - val_loss: 7.0782e-04 - val_last_time_step_mse: 7.3403e-04
# Epoch 8/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 7.3230e-04 - last_time_step_mse: 7.6369e-04
# Epoch 00008: val_last_time_step_mse improved from 0.00073 to 0.00073, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 66s 21ms/step - loss: 7.3226e-04 - last_time_step_mse: 7.6374e-04 - val_loss: 7.0835e-04 - val_last_time_step_mse: 7.3368e-04
# Epoch 9/100
# 3178/3181 [============================>.] - ETA: 0s - loss: 7.1872e-04 - last_time_step_mse: 7.5064e-04
# Epoch 00009: val_last_time_step_mse improved from 0.00073 to 0.00071, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 72s 23ms/step - loss: 7.1885e-04 - last_time_step_mse: 7.5077e-04 - val_loss: 6.8290e-04 - val_last_time_step_mse: 7.0877e-04
# Epoch 10/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 7.1580e-04 - last_time_step_mse: 7.4640e-04
# Epoch 00010: val_last_time_step_mse did not improve from 0.00071
# 3181/3181 [==============================] - 72s 23ms/step - loss: 7.1570e-04 - last_time_step_mse: 7.4630e-04 - val_loss: 6.8085e-04 - val_last_time_step_mse: 7.0990e-04
# Epoch 11/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 7.0858e-04 - last_time_step_mse: 7.3980e-04
# Epoch 00011: val_last_time_step_mse did not improve from 0.00071
# 3181/3181 [==============================] - 72s 23ms/step - loss: 7.0882e-04 - last_time_step_mse: 7.4013e-04 - val_loss: 7.5508e-04 - val_last_time_step_mse: 7.7933e-04
# Epoch 12/100
# 3181/3181 [==============================] - ETA: 0s - loss: 7.0903e-04 - last_time_step_mse: 7.4003e-04
# Epoch 00012: val_last_time_step_mse did not improve from 0.00071
# 3181/3181 [==============================] - 71s 22ms/step - loss: 7.0903e-04 - last_time_step_mse: 7.4003e-04 - val_loss: 6.9005e-04 - val_last_time_step_mse: 7.1070e-04
# Epoch 13/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 7.0277e-04 - last_time_step_mse: 7.3409e-04
# Epoch 00013: val_last_time_step_mse did not improve from 0.00071
# 3181/3181 [==============================] - 72s 23ms/step - loss: 7.0267e-04 - last_time_step_mse: 7.3398e-04 - val_loss: 6.9791e-04 - val_last_time_step_mse: 7.1998e-04
# Epoch 14/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.9528e-04 - last_time_step_mse: 7.2598e-04
# Epoch 00014: val_last_time_step_mse did not improve from 0.00071
# 3181/3181 [==============================] - 69s 22ms/step - loss: 6.9541e-04 - last_time_step_mse: 7.2616e-04 - val_loss: 7.8255e-04 - val_last_time_step_mse: 8.1123e-04
# Epoch 15/100
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.9442e-04 - last_time_step_mse: 7.2552e-04
# Epoch 00015: val_last_time_step_mse improved from 0.00071 to 0.00070, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 70s 22ms/step - loss: 6.9423e-04 - last_time_step_mse: 7.2519e-04 - val_loss: 6.7692e-04 - val_last_time_step_mse: 7.0393e-04
# Epoch 16/100
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.9352e-04 - last_time_step_mse: 7.2415e-04
# Epoch 00016: val_last_time_step_mse improved from 0.00070 to 0.00070, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 68s 22ms/step - loss: 6.9356e-04 - last_time_step_mse: 7.2412e-04 - val_loss: 6.7148e-04 - val_last_time_step_mse: 6.9730e-04
# Epoch 17/100
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.9262e-04 - last_time_step_mse: 7.2319e-04
# Epoch 00017: val_last_time_step_mse did not improve from 0.00070
# 3181/3181 [==============================] - 67s 21ms/step - loss: 6.9244e-04 - last_time_step_mse: 7.2296e-04 - val_loss: 7.0731e-04 - val_last_time_step_mse: 7.3620e-04
# Epoch 18/100
# 3181/3181 [==============================] - ETA: 0s - loss: 6.8689e-04 - last_time_step_mse: 7.1698e-04
# Epoch 00018: val_last_time_step_mse improved from 0.00070 to 0.00068, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 74s 23ms/step - loss: 6.8689e-04 - last_time_step_mse: 7.1698e-04 - val_loss: 6.5963e-04 - val_last_time_step_mse: 6.8485e-04
# Epoch 19/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.8515e-04 - last_time_step_mse: 7.1552e-04
# Epoch 00019: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 76s 24ms/step - loss: 6.8519e-04 - last_time_step_mse: 7.1560e-04 - val_loss: 6.8010e-04 - val_last_time_step_mse: 7.1034e-04
# Epoch 20/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.8154e-04 - last_time_step_mse: 7.1191e-04
# Epoch 00020: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.8143e-04 - last_time_step_mse: 7.1183e-04 - val_loss: 6.8471e-04 - val_last_time_step_mse: 7.0639e-04
# Epoch 21/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.8010e-04 - last_time_step_mse: 7.1027e-04
# Epoch 00021: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 73s 23ms/step - loss: 6.8007e-04 - last_time_step_mse: 7.1022e-04 - val_loss: 7.1526e-04 - val_last_time_step_mse: 7.4234e-04
# Epoch 22/100
# 3181/3181 [==============================] - ETA: 0s - loss: 6.7718e-04 - last_time_step_mse: 7.0803e-04 ETA: 0s - loss: 6.7641e-04 - la
# Epoch 00022: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 74s 23ms/step - loss: 6.7718e-04 - last_time_step_mse: 7.0803e-04 - val_loss: 6.7091e-04 - val_last_time_step_mse: 7.0085e-04
# Epoch 23/100
# 3181/3181 [==============================] - ETA: 0s - loss: 6.8066e-04 - last_time_step_mse: 7.1024e-04
# Epoch 00023: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 73s 23ms/step - loss: 6.8066e-04 - last_time_step_mse: 7.1024e-04 - val_loss: 6.6811e-04 - val_last_time_step_mse: 6.9293e-04
# Epoch 24/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.7056e-04 - last_time_step_mse: 7.0110e-04
# Epoch 00024: val_last_time_step_mse improved from 0.00068 to 0.00068, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 74s 23ms/step - loss: 6.7064e-04 - last_time_step_mse: 7.0123e-04 - val_loss: 6.5389e-04 - val_last_time_step_mse: 6.7576e-04
# Epoch 25/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.7259e-04 - last_time_step_mse: 7.0269e-04
# Epoch 00025: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.7277e-04 - last_time_step_mse: 7.0286e-04 - val_loss: 7.0635e-04 - val_last_time_step_mse: 7.2905e-04
# Epoch 26/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.7068e-04 - last_time_step_mse: 7.0022e-04
# Epoch 00026: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.7066e-04 - last_time_step_mse: 7.0027e-04 - val_loss: 6.8336e-04 - val_last_time_step_mse: 7.0497e-04
# Epoch 27/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.6887e-04 - last_time_step_mse: 6.9822e-04
# Epoch 00027: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.6893e-04 - last_time_step_mse: 6.9812e-04 - val_loss: 6.6701e-04 - val_last_time_step_mse: 6.9378e-04
# Epoch 28/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.7166e-04 - last_time_step_mse: 7.0051e-04
# Epoch 00028: val_last_time_step_mse did not improve from 0.00068
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.7153e-04 - last_time_step_mse: 7.0036e-04 - val_loss: 6.5362e-04 - val_last_time_step_mse: 6.7658e-04
# Epoch 29/100
# 3181/3181 [==============================] - ETA: 0s - loss: 6.6847e-04 - last_time_step_mse: 6.9797e-04
# Epoch 00029: val_last_time_step_mse improved from 0.00068 to 0.00066, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 71s 22ms/step - loss: 6.6847e-04 - last_time_step_mse: 6.9797e-04 - val_loss: 6.4005e-04 - val_last_time_step_mse: 6.6419e-04
# Epoch 30/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.6892e-04 - last_time_step_mse: 6.9863e-04
# Epoch 00030: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.6888e-04 - last_time_step_mse: 6.9858e-04 - val_loss: 7.0503e-04 - val_last_time_step_mse: 7.3105e-04
# Epoch 31/100
# 3181/3181 [==============================] - ETA: 0s - loss: 6.6706e-04 - last_time_step_mse: 6.9607e-04
# Epoch 00031: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 73s 23ms/step - loss: 6.6706e-04 - last_time_step_mse: 6.9607e-04 - val_loss: 6.4250e-04 - val_last_time_step_mse: 6.6659e-04
# Epoch 32/100
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.6481e-04 - last_time_step_mse: 6.9332e-04
# Epoch 00032: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.6490e-04 - last_time_step_mse: 6.9343e-04 - val_loss: 6.6455e-04 - val_last_time_step_mse: 6.8341e-04
# Epoch 33/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.6342e-04 - last_time_step_mse: 6.9188e-04
# Epoch 00033: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 73s 23ms/step - loss: 6.6329e-04 - last_time_step_mse: 6.9174e-04 - val_loss: 6.5055e-04 - val_last_time_step_mse: 6.7691e-04
# Epoch 34/100
# 3181/3181 [==============================] - ETA: 0s - loss: 6.6126e-04 - last_time_step_mse: 6.8887e-04
# Epoch 00034: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 73s 23ms/step - loss: 6.6126e-04 - last_time_step_mse: 6.8887e-04 - val_loss: 6.5016e-04 - val_last_time_step_mse: 6.7578e-04
# Epoch 35/100
# 3181/3181 [==============================] - ETA: 0s - loss: 6.6670e-04 - last_time_step_mse: 6.9465e-04
# Epoch 00035: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 72s 23ms/step - loss: 6.6670e-04 - last_time_step_mse: 6.9465e-04 - val_loss: 6.6279e-04 - val_last_time_step_mse: 6.8841e-04
# Epoch 36/100
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.6276e-04 - last_time_step_mse: 6.9091e-04
# Epoch 00036: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 69s 22ms/step - loss: 6.6264e-04 - last_time_step_mse: 6.9076e-04 - val_loss: 6.8829e-04 - val_last_time_step_mse: 7.0771e-04
# Epoch 37/100
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5950e-04 - last_time_step_mse: 6.8760e-04
# Epoch 00037: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 69s 22ms/step - loss: 6.5949e-04 - last_time_step_mse: 6.8762e-04 - val_loss: 6.5907e-04 - val_last_time_step_mse: 6.8015e-04

# %%
history_Full2= model_Full.fit(X_train_scaled, y_train_scaled, epochs=50,
                    validation_data=(X_valid_scaled,y_valid_scaled),callbacks=callback_list1)
# Out:
# Epoch 1/50
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.6113e-04 - last_time_step_mse: 6.8916e-04
# Epoch 00001: val_last_time_step_mse improved from inf to 0.00067, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 90s 28ms/step - loss: 6.6112e-04 - last_time_step_mse: 6.8910e-04 - val_loss: 6.4662e-04 - val_last_time_step_mse: 6.7320e-04
# Epoch 2/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.6099e-04 - last_time_step_mse: 6.8947e-04
# Epoch 00002: val_last_time_step_mse improved from 0.00067 to 0.00066, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 77s 24ms/step - loss: 6.6098e-04 - last_time_step_mse: 6.8943e-04 - val_loss: 6.3655e-04 - val_last_time_step_mse: 6.5953e-04
# Epoch 3/50
# 3181/3181 [==============================] - ETA: 0s - loss: 6.5932e-04 - last_time_step_mse: 6.8705e-04
# Epoch 00003: val_last_time_step_mse improved from 0.00066 to 0.00066, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 77s 24ms/step - loss: 6.5932e-04 - last_time_step_mse: 6.8705e-04 - val_loss: 6.3714e-04 - val_last_time_step_mse: 6.5874e-04
# Epoch 4/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5992e-04 - last_time_step_mse: 6.8781e-04
# Epoch 00004: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 82s 26ms/step - loss: 6.5990e-04 - last_time_step_mse: 6.8785e-04 - val_loss: 6.5395e-04 - val_last_time_step_mse: 6.7494e-04
# Epoch 5/50
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.5744e-04 - last_time_step_mse: 6.8523e-04
# Epoch 00005: val_last_time_step_mse did not improve from 0.00066
# 3181/3181 [==============================] - 79s 25ms/step - loss: 6.5827e-04 - last_time_step_mse: 6.8580e-04 - val_loss: 6.7559e-04 - val_last_time_step_mse: 7.0172e-04
# Epoch 6/50
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.5754e-04 - last_time_step_mse: 6.8584e-04
# Epoch 00006: val_last_time_step_mse improved from 0.00066 to 0.00065, saving model to Checkpoint/Wavenet(90_30_1)(filter=20).h5
# 3181/3181 [==============================] - 64s 20ms/step - loss: 6.5765e-04 - last_time_step_mse: 6.8596e-04 - val_loss: 6.2889e-04 - val_last_time_step_mse: 6.5253e-04
# Epoch 7/50
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.5587e-04 - last_time_step_mse: 6.8376e-04
# Epoch 00007: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 61s 19ms/step - loss: 6.5584e-04 - last_time_step_mse: 6.8373e-04 - val_loss: 6.3870e-04 - val_last_time_step_mse: 6.6171e-04
# Epoch 8/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5779e-04 - last_time_step_mse: 6.8542e-04
# Epoch 00008: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 64s 20ms/step - loss: 6.5780e-04 - last_time_step_mse: 6.8538e-04 - val_loss: 6.3850e-04 - val_last_time_step_mse: 6.6097e-04
# Epoch 9/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5359e-04 - last_time_step_mse: 6.8043e-04
# Epoch 00009: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 64s 20ms/step - loss: 6.5359e-04 - last_time_step_mse: 6.8039e-04 - val_loss: 6.3730e-04 - val_last_time_step_mse: 6.6108e-04
# Epoch 10/50
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.5633e-04 - last_time_step_mse: 6.8386e-04
# Epoch 00010: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 63s 20ms/step - loss: 6.5626e-04 - last_time_step_mse: 6.8376e-04 - val_loss: 6.4557e-04 - val_last_time_step_mse: 6.6955e-04
# Epoch 11/50
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.5563e-04 - last_time_step_mse: 6.8310e-04
# Epoch 00011: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 63s 20ms/step - loss: 6.5560e-04 - last_time_step_mse: 6.8303e-04 - val_loss: 6.6944e-04 - val_last_time_step_mse: 6.9484e-04
# Epoch 12/50
# 3181/3181 [==============================] - ETA: 0s - loss: 6.5596e-04 - last_time_step_mse: 6.8370e-04
# Epoch 00012: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 62s 19ms/step - loss: 6.5596e-04 - last_time_step_mse: 6.8370e-04 - val_loss: 6.6958e-04 - val_last_time_step_mse: 6.8885e-04
# Epoch 13/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5493e-04 - last_time_step_mse: 6.8228e-04
# Epoch 00013: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 63s 20ms/step - loss: 6.5494e-04 - last_time_step_mse: 6.8231e-04 - val_loss: 6.3306e-04 - val_last_time_step_mse: 6.5283e-04
# Epoch 14/50
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.5397e-04 - last_time_step_mse: 6.8079e-04
# Epoch 00014: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 63s 20ms/step - loss: 6.5380e-04 - last_time_step_mse: 6.8059e-04 - val_loss: 6.3439e-04 - val_last_time_step_mse: 6.5771e-04
# Epoch 15/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5103e-04 - last_time_step_mse: 6.7875e-04
# Epoch 00015: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 63s 20ms/step - loss: 6.5104e-04 - last_time_step_mse: 6.7876e-04 - val_loss: 6.3921e-04 - val_last_time_step_mse: 6.6215e-04
# Epoch 16/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5144e-04 - last_time_step_mse: 6.7881e-04
# Epoch 00016: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 63s 20ms/step - loss: 6.5138e-04 - last_time_step_mse: 6.7875e-04 - val_loss: 6.5731e-04 - val_last_time_step_mse: 6.8058e-04
# Epoch 17/50
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.5447e-04 - last_time_step_mse: 6.8143e-04
# Epoch 00017: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 63s 20ms/step - loss: 6.5476e-04 - last_time_step_mse: 6.8261e-04 - val_loss: 6.5546e-04 - val_last_time_step_mse: 6.7842e-04
# Epoch 18/50
# 3178/3181 [============================>.] - ETA: 0s - loss: 6.5348e-04 - last_time_step_mse: 6.8052e-04
# Epoch 00018: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 65s 20ms/step - loss: 6.5339e-04 - last_time_step_mse: 6.8031e-04 - val_loss: 6.5352e-04 - val_last_time_step_mse: 6.8054e-04
# Epoch 19/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5194e-04 - last_time_step_mse: 6.7904e-04
# Epoch 00019: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 64s 20ms/step - loss: 6.5189e-04 - last_time_step_mse: 6.7896e-04 - val_loss: 6.4301e-04 - val_last_time_step_mse: 6.6742e-04
# Epoch 20/50
# 3179/3181 [============================>.] - ETA: 0s - loss: 6.5064e-04 - last_time_step_mse: 6.7736e-04
# Epoch 00020: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 65s 20ms/step - loss: 6.5070e-04 - last_time_step_mse: 6.7747e-04 - val_loss: 6.3739e-04 - val_last_time_step_mse: 6.6106e-04
# Epoch 21/50
# 3180/3181 [============================>.] - ETA: 0s - loss: 6.5218e-04 - last_time_step_mse: 6.8012e-04
# Epoch 00021: val_last_time_step_mse did not improve from 0.00065
# 3181/3181 [==============================] - 68s 21ms/step - loss: 6.5211e-04 - last_time_step_mse: 6.8003e-04 - val_loss: 6.4194e-04 - val_last_time_step_mse: 6.6556e-04

# %% [markdown]
# > 재실행

# %%
filtersize=90
targetsize=30
stride=1

# %%
path='Checkpoint'+'/Wavenet({}_{}_{})'.format(filtersize,targetsize,stride)+'.h5'

# %%
loaded_model = tf.keras.models.load_model(path,custom_objects={'customLoss1':last_time_step_mse},compile=False)

# %%
# compile the model
loaded_model.compile(optimizer='adam', loss='mae',metrics=[last_time_step_mse])

# %%
loaded_model.fit(X_train_scaled, y_train_scaled, epochs=8,
                    validation_data=(X_valid_scaled,y_valid_scaled),callbacks=callback_list1)
# Out:
# Epoch 1/8
# 3181/3181 [==============================] - ETA: 0s - loss: 5.3794e-04 - last_time_step_mse: 5.3657e-04
# Epoch 00001: val_last_time_step_mse improved from inf to 0.00054, saving model to Checkpoint/Wavenet(90_30_1).h5
# 3181/3181 [==============================] - 1736s 546ms/step - loss: 5.3794e-04 - last_time_step_mse: 5.3657e-04 - val_loss: 5.4332e-04 - val_last_time_step_mse: 5.4078e-04
# Epoch 2/8
#  225/3181 [=>............................] - ETA: 30:12 - loss: 5.3094e-04 - last_time_step_mse: 5.0259e-04
