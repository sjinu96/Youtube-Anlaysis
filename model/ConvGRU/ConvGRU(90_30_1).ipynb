# %%
import os
from datetime import datetime, date
from sklearn import utils
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as fn
import torch.optim as optim

device = 'cuda:1' if torch.cuda.is_available() else 'cpu'
plt.style.use('ggplot')

# %% [markdown]
# ### 0. Utils

# %% [markdown]
# ### 1-1. Preprocessor

# %%
class Preprocessor:
    def _fit_transform(self, raw):
        result = raw.copy()

        result = self._n_comment_to_float(result)
        result = self._str_to_datetype(result)
        result = self._add_n_hashtag(result)
        
        self.non_numeric = ['channel', 'title', 'genre', 'description', 'date', 'sign_in']
        result = self._merge(result, self.non_numeric)
        
        features = ['cumul_view', 'n_dislike', 'n_like', 'n_comment', 'video_n_view', 'cumul_subs']
        new_name = ['view_diff', 'dislike_diff', 'like_diff', 'comment_diff', 'video_n_view_diff', 'sub_diff']
        result = self._add_diff(result, features, new_name)
        
        result = self._add_no_upload_interval(result)
        result = self._remove_nan(result)
        self._one_hot(result)

        return result
        
        
        
    #FEATRUES TO ADD & MODIFY
    ####################################################################     
    def _n_comment_to_float(self,result):
        idx1 = result['n_comment'] == '댓글 사용 중지'
        idx2 = result.n_comment.isna()
        idx = idx1|idx2
        result['n_comment'].loc[idx] = result['n_comment'].loc[idx].apply(lambda x: 0)
        result['n_comment'] = result['n_comment'].astype(float)
        return result
        
    
    def _str_to_datetype(self,result):
        if pd.api.types.is_datetime64_ns_dtype(result['date']):
            pass
        else:
            result['date'] = pd.to_datetime(result['date'])
        return result
    
    
    def _add_n_hashtag(self,result):
        result['n_hashtage'] = 0
        idx = result['description'].notnull()
        result.loc[idx, 'n_hashtage'] = result.loc[idx, 'description'].apply(lambda x: len(x.split('#'))-1)
        return result
        
    
    @staticmethod
    def _get_to_merge(data, numeric, non_numeric):
        data = data.reset_index(drop=True)
        num_to_add = data.title.shape[0] - data.title.isna().sum()
        data = pd.concat((data.loc[0,non_numeric], data[numeric].mean()))
        data['video_num'] = num_to_add
        return data
    def _merge(self, result, non_numeric):
        #operate both merge and creating video_num featrue simultaneously.
        numeric = [col for col in result.columns.tolist() if col not in non_numeric]
        return result.groupby(['channel', 'date']).apply(lambda x: self._get_to_merge(x, numeric, non_numeric)).reset_index(drop=True)
    
    
    @staticmethod
    def _get_diff(result, feature, new_name):
        result = result.reset_index(drop=True)
        result[new_name] = (result[feature] - result[feature].shift())
        return result
    def _add_diff(self, result, feature, new_name):
        result = result.groupby('channel').apply(lambda x: self._get_diff(x, feature, new_name)).reset_index(drop=True)
        result[new_name] = result[new_name].fillna(0)
        return result
    
    
    @staticmethod
    def _get_no_upload_interval(result):
        result = result.reset_index(drop=True)
        upload_idx = result[result['video_num'] != 0].index.tolist()
        temp = [0 for i in range(result.shape[0])]
        for i in range(len(upload_idx)):
            if i == len(upload_idx)-1:
                former = upload_idx[i]
                temp[former+1:] = [i+1 for i in range(len(temp[former+1:]))]
            else:
                former, latter = upload_idx[i], upload_idx[i+1]
                temp[former+1:latter] = [i+1 for i in range(len(temp[former+1:latter]))]
        result['no_upload_interval'] = temp
        return result
    def _add_no_upload_interval(self,result):
        return result.groupby('channel').apply(lambda x: self._get_no_upload_interval(x)).reset_index(drop=True)
    
    
    def _remove_nan(self, result):
        numeric = [col for col in result.columns.tolist() if col not in self.non_numeric]
        result.loc[:, numeric] = result.loc[:,numeric].fillna(0)
        return result
    
    
    def _one_hot(self, data):
        data.loc[:,'genre'] = data.genre.fillna('etc')
        genre = data.genre.unique().tolist()
        for i, name in enumerate(genre):
            data.genre[data.genre==name] = data.genre[data.genre==name].apply(lambda x: i)
            
        one_hot = pd.get_dummies(data.genre.unique().tolist())
        data['one_hot'] = data.genre
        for i in range(len(one_hot)):
            data.loc[data.genre==i,'one_hot'] = data.loc[data.genre==i, 'genre'].apply(lambda x: one_hot[i].values)
    ####################################################################
    
    
    
    #CREATE SEQUENTIAL DATA
    ####################################################################
    def _extract_at_least_filter(self, result, filter_size):
        #fillter_size 이상인 채널 추출하기
        alive_idx = result['channel'].value_counts() >= filter_size
        alive_array = alive_idx[alive_idx==True].index
        return result[result['channel'].isin(alive_array)].reset_index(drop=True)
    
    
    @staticmethod
    def _to_sequential(result, filter_size, target_size, stride, features, target_features):
        result = result.reset_index(drop=True)
        idx_list = result.index.tolist()
        
        train, target = [],[]
        for i in range((len(idx_list)-filter_size-target_size)//stride +1):
            train_idx = idx_list[i*stride : i*stride + filter_size]
            target_idx = idx_list[i*stride + filter_size : i*stride + filter_size + target_size]
            train_temp = result.loc[train_idx,:].values.reshape(1,-1)
            target_temp = result.loc[target_idx,target_features].values.reshape(1,-1)
            
            train = train_temp.copy() if i == 0 else np.vstack([train, train_temp])
            target = target_temp.copy() if i == 0 else np.vstack([target, target_temp])
            
        train = pd.DataFrame(train, columns = result.columns.tolist()*filter_size)
        target = pd.DataFrame(target, columns = target_features*target_size)
        return train[features], target
    def _create_sequential_data(self, result, filter_size=7, target_size=1, stride=1, features=None, target_features=None):
        #remove channels with few information with respect to filter_size and target_size to extract
        result = self._extract_at_least_filter(result, filter_size + target_size)
        
        #features: features to drop fromf X (features)
        #target_features: features to extract from Y (targets)
        if features is None:
            features = ['date', 'genre','title', 'channel', 'description',	'sign_in', 'current_cumul_view', 'current_n_video', 'current_cumul_subs']
        if target_features is None:
            target_features = ['sub_diff']
        
        #return train, target set wrt groups
        result = result.groupby('channel').apply(lambda x: self._to_sequential(x, filter_size, target_size, stride, features, target_features)).reset_index(drop=True)
        return self._combine(result)
    
    
    def _combine(self, result):
        temp0, temp1 = [], []
        for i in range(len(result)):
            temp0.append(result[i][0])
            temp1.append(result[i][1])
        temp0 = pd.concat(temp0)
        temp1 = pd.concat(temp1)
        return (temp0, temp1)
    ####################################################################


    
    #SCALE
    ####################################################################
    def scale(self, data, return_original_scale=True):
        original_scale = pd.concat((data.max(), data.min()), axis=1).T
        original_scale.index=['max', 'min']
        scaler = preprocessing.MinMaxScaler()
        data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
        if return_original_scale:
            return data, original_scale
        return data
    
        
    def inverse_scale(self, pred, scl):
        for idx in range(pred.shape[1]):
            pred.iloc[:,idx] = (scl.iloc[0,idx]-scl.iloc[1,idx])*pred.iloc[:,idx]+scl.iloc[1,idx]

# %% [markdown]
# ### 1-2. Data Loader

# %%
class Loader(Preprocessor):
    def __init__(self, path):
        self._raw = pd.read_csv(path)
        self.data = super()._fit_transform(self._raw.copy())
        print('Data Loaded. :P')
        
        
    def get_data(self, filter_size=7, target_size=1, stride=1, features=None, target_features=None,
                         channel:list=None, shuffle=False, random_state=None, order=None):
        if channel is None:
            data_to_extract = self.data
        else:
            channels = self.list_channel[channel].tolist()
            data_to_extract = self.data.set_index('channel').loc[channels].reset_index()
            
        train, target = self._create_sequential_data(data_to_extract, filter_size, target_size, stride, features, target_features)
        if shuffle:
            train, target = utils.shuffle(train, target, random_state=random_state)
        
        if order:
            train_col = [col for col in train.columns.unique().tolist()]
            target_col = [col for col in target.columns.unique().tolist()]
            train, target = train[train_col], target[target_col]
            
        return train, target

    
    @property
    def list_features(self):
        #list the entire features, hence you can choose which features are included in whole set.
        return self.data.columns.tolist()
    
    @property
    def list_channel(self):
        #list indices of channel.
        return pd.Series(self.data.channel.unique().tolist())

# %% [markdown]
# > load함수

# %%
def load(
    filter_size: '60, 90, 180', 
    target_size: '1, 7, 30, 180', 
    stride: '1, 2, 3',
    drop_suffix: '각 변수 끝에 붙은 번호를 제거할지 여부'=True,
    path='/home/mskang/CapstoneUOS/notebooks/ModelResearch_iloveslowfood/data_variants'):
    
    print(f'Setting: filter_size({filter_size})\ttarget_size({target_size})\tstride({stride})\tdrop_suffix({drop_suffix})')
    X_name = f'fs({filter_size})_ts({target_size})_st({stride}).csv'
    y_name = f'fs({filter_size})_ts({target_size})_st({stride})_label.csv'
    
    print('Load feature data...', end='\t')
    X = pd.read_csv(os.path.join(path, X_name))
    print('loaded!')
    print('Load label data...', end='\t')
    y = pd.read_csv(os.path.join(path, y_name))
    print('loaded!')
    
    if drop_suffix:
        X.columns = list(map(lambda x: x.split('.')[0], X.columns.tolist()))
        y.columns = list(map(lambda x: x.split('.')[0], y.columns.tolist()))
    return X, y

# %% [markdown]
# > 데이터 불러오기

# %%
filter_size = 90
target_size = 30
stride = 1
X, y = load(filter_size, target_size, stride)
# Out:
# Setting: filter_size(90)	target_size(30)	stride(1)	drop_suffix(True)
# Load feature data...	loaded!
# Load label data...	loaded!

# %% [markdown]
# > Train/Test/VAlid 분할

# %%
random_state = 42
test_size = 0.2

X_trn, X_test, y_trn, y_test = train_test_split(
    X, y, 
    shuffle=True, 
    test_size=test_size, 
    random_state=random_state
) 

X_train, X_valid, y_train, y_valid = train_test_split(
    X_trn, y_trn, 
    shuffle=True, 
    test_size=test_size, 
    random_state=random_state
) 

### 스케일링 필요 시 다음을 진행(타깃에 대한 스케일링은 진행되지 않음)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# scaler = MinMaxScaler()
# X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
# X_valid_scaled = pd.DataFrame(scaler.transform(X_valid), columns=X_valid.columns)
# X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# ### 2D TO 3D

# %%
def stack_to_multi(df):
    feature_num=len(set(df.columns))
    window_num=int(df.shape[1]/feature_num)
    sample_num=int(df.shape[0])
    temp=np.empty([sample_num,window_num,feature_num])
    for i in range(feature_num):
        temp[:,:,i]=df.iloc[:,window_num*i:window_num*i+window_num]
    
    return temp

# %%
X_train
# Out:
#         duration  duration  duration   duration   duration   duration  \
# 121697      0.00      0.00      0.00   0.000000   0.000000   0.000000
# 129642      2.00      2.08      2.00   2.670000   1.600000   1.750000
# 86794       0.00      0.00      0.00   0.000000   0.000000   0.000000
# 6042        8.88      0.00      1.77  14.776667   7.371667   9.296667
# 32195       0.00      0.00     31.92   0.000000  11.100000  11.400000
# ...          ...       ...       ...        ...        ...        ...
# 3285        7.22      0.00      6.98   7.000000   9.950000   0.000000
# 66254       0.00      0.00      0.00   0.000000   0.000000   0.000000
# 52248       0.00      0.00      0.00   0.000000   0.000000   0.000000
# 100988      0.00      0.00      0.00   0.000000   0.000000   0.000000
# 70219       0.00      2.97      0.00   0.000000   0.000000   0.000000
#
#         duration  duration  duration  duration  ...  no_upload_interval  \
# 121697      0.00       0.0     0.000       0.0  ...                   0
# 129642      0.00       0.0     0.000       0.0  ...                   1
# 86794       0.00       0.0     0.000       0.0  ...                   2
# 6042       14.15       0.0    16.575       0.0  ...                   0
# 32195       0.00       0.0     0.000       0.0  ...                   0
# ...          ...       ...       ...       ...  ...                 ...
# 3285      157.73       0.0     0.000       0.0  ...                   3
# 66254       0.00       0.0     0.000       0.0  ...                   0
# 52248       0.00       0.0     0.000       0.0  ...                  15
# 100988      0.00       0.0     0.000       0.0  ...                  89
# 70219       0.00       0.0     0.000       0.0  ...                   6
#
#         no_upload_interval  no_upload_interval  no_upload_interval  \
# 121697                   0                   0                   0
# 129642                   2                   0                   1
# 86794                    0                   1                   2
# 6042                     1                   0                   1
# 32195                    1                   2                   0
# ...                    ...                 ...                 ...
# 3285                     4                   5                   0
# 66254                    0                   0                   0
# 52248                   16                  17                  18
# 100988                  90                  91                  92
# 70219                    7                   8                   9
#
#         no_upload_interval  no_upload_interval  no_upload_interval  \
# 121697                   0                   0                   0
# 129642                   2                   0                   1
# 86794                    3                   4                   5
# 6042                     2                   0                   0
# 32195                    1                   2                   0
# ...                    ...                 ...                 ...
# 3285                     1                   2                   3
# 66254                    0                   0                   0
# 52248                   19                  20                  21
# 100988                  93                  94                  95
# 70219                   10                  11                  12
#
#         no_upload_interval  no_upload_interval  no_upload_interval
# 121697                   0                   0                   0
# 129642                   2                   0                   1
# 86794                    6                   0                   0
# 6042                     1                   2                   0
# 32195                    1                   0                   1
# ...                    ...                 ...                 ...
# 3285                     4                   0                   1
# 66254                    0                   0                   0
# 52248                   22                  23                  24
# 100988                  96                  97                   0
# 70219                   13                  14                  15
#
# [101780 rows x 1530 columns]

# %%
X_train_3d=stack_to_multi(X_train)
X_valid_3d=stack_to_multi(X_valid)
X_test_3d=stack_to_multi(X_test)

# %%
print(X_train_3d.shape)
print(X_valid_3d.shape)
print(X_test_3d.shape)
# Out:
# (101780, 90, 17)
# (25445, 90, 17)
# (31807, 90, 17)

# %%
print(y_train.shape)
print(y_valid.shape)
print(y_test.shape)
# Out:
# (101780, 30)
# (25445, 30)
# (31807, 30)

# %% [markdown]
# #### 3D 스케일링, 타겟 스케일링

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=preprocessing.MinMaxScaler()
#scaler_y=preprocessing.MinMaxScaler()
def fit_3d(x_train,x_val,x_test):
    x_train_sample = x_train.shape[0] #샘플 개수
    x_val_sample=x_val.shape[0]
    x_test_sample=x_test.shape[0]
    
    x_timestep = x_train.shape[1] # timestep
    x_feature = x_train.shape[2]# feature 차원 
    scaler=MinMaxScaler()
    for ss in range(x_timestep):
        scaler.partial_fit(x_train[:, ss, :]) # 순회피팅

    results1,results2,results3=([],[],[])
    for ss in range(x_timestep):
        results1.append(scaler.transform(x_train[:, ss, :]).reshape(x_train_sample, 1, x_feature))
        results2.append(scaler.transform(x_val[:,ss,:]).reshape(x_val_sample,1,x_feature))
        results3.append(scaler.transform(x_test[:,ss,:]).reshape(x_test_sample,1,x_feature))
    df_train_scaled = np.concatenate(results1, axis=1) #합치기.
    df_val_scaled=np.concatenate(results2,axis=1)
    df_test_scaled=np.concatenate(results3,axis=1)
    
    
    
    return df_train_scaled,df_val_scaled,df_test_scaled

# %%
X_train_scaled,X_valid_scaled,X_test_scaled=fit_3d(X_train_3d, X_valid_3d, X_test_3d)

# %% [markdown]
# > target shape 변경 ( 샘플 x 타입스텝 x 예측일수)

# %%
X_train_subdiff=X_train['sub_diff']
X_valid_subdiff=X_valid['sub_diff']
X_test_subdiff=X_test['sub_diff']

# %%
X_train_subdiff[:]
# Out:
#         sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  \
# 121697      10.0      20.0      15.0      15.0      20.0      10.0      20.0
# 129642       0.0     200.0     800.0     500.0    1200.0      99.0     601.0
# 86794      100.0     100.0     100.0     100.0     100.0     100.0     100.0
# 6042        15.0      15.0      10.0      30.0      20.0      20.0      15.0
# 32195        0.0       0.0    1000.0    1500.0    1500.0    1000.0       0.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 3285        -5.0      -3.0      -2.0       0.0       0.0       0.0      85.0
# 66254        2.0       1.0       2.0       1.0       1.0       2.0       1.0
# 52248      200.0     200.0     200.0     100.0     100.0     200.0      99.0
# 100988       4.0       4.0       4.0       4.0       4.0       4.0       3.0
# 70219      250.0     250.0     500.0     700.0     400.0     200.0     200.0
#
#         sub_diff  sub_diff  sub_diff  ...  sub_diff  sub_diff  sub_diff  \
# 121697      10.0      15.0      15.0  ...       0.0       0.0      30.0
# 129642     100.0     100.0       0.0  ...     100.0     200.0     100.0
# 86794      100.0     100.0     100.0  ...     100.0     100.0     100.0
# 6042        15.0      30.0      20.0  ...      15.0      15.0      10.0
# 32195     1000.0     500.0     500.0  ...     700.0       0.0    1000.0
# ...          ...       ...       ...  ...       ...       ...       ...
# 3285        85.0      10.0     -30.0  ...      10.0      36.0      37.0
# 66254        1.0       2.0       0.0  ...       0.0       0.0       5.0
# 52248      101.0      99.0     101.0  ...     300.0     100.0     100.0
# 100988       4.0       4.0       4.0  ...       0.0      20.0       5.0
# 70219      299.0     201.0     300.0  ...     200.0     300.0     200.0
#
#         sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff  sub_diff
# 121697      25.0      55.0      40.0      20.0      20.0       0.0      10.0
# 129642     100.0     100.0       0.0     200.0       0.0     100.0     100.0
# 86794      100.0     100.0     100.0     100.0     100.0       0.0     100.0
# 6042        15.0      15.0      10.0      20.0      10.0      10.0      10.0
# 32195        0.0       0.0       0.0    1000.0       0.0     500.0     500.0
# ...          ...       ...       ...       ...       ...       ...       ...
# 3285        37.0      40.0      40.0      40.0      20.0      30.0      30.0
# 66254        5.0       6.0       7.0       7.0       0.0      10.0       0.0
# 52248      200.0     100.0     200.0     100.0     100.0      99.0     201.0
# 100988       5.0      10.0      30.0      20.0       0.0      20.0      30.0
# 70219      300.0     200.0     300.0     200.0     300.0     200.0     300.0
#
# [101780 rows x 90 columns]

# %%
# (샘플개수 , (180+30)의 TARGET
temp1=pd.concat([X_train_subdiff,y_train],axis=1)
temp2=pd.concat([X_valid_subdiff,y_valid],axis=1)
temp3=pd.concat([X_test_subdiff,y_test],axis=1)

# %%
# (샘플, timestep, targetsize)
y_train_3d=np.empty((X_train_subdiff.shape[0],X_train_subdiff.shape[1],30)) # 30 : targetsize
y_valid_3d=np.empty((X_valid_subdiff.shape[0],X_valid_subdiff.shape[1],30))
y_test_3d=np.empty((X_test_subdiff.shape[0],X_test_subdiff.shape[1],30))

# %%
for t in range(X_train_subdiff.shape[1]): # 180 Timestep
    y_train_3d[:,t]=temp1.iloc[:,t:t+30]
    y_valid_3d[:,t]=temp2.iloc[:,t:t+30]
    y_test_3d[:,t]=temp3.iloc[:,t:t+30]

# %%
print(y_train_3d.shape)
print(y_valid_3d.shape)
print(y_test_3d.shape)
# Out:
# (101780, 90, 30)
# (25445, 90, 30)
# (31807, 90, 30)

# %% [markdown]
# > y scaling

# %%
y_train_temp=y_train_3d.reshape(-1,1)
y_valid_temp=y_valid_3d.reshape(-1,1)
y_test_temp=y_test_3d.reshape(-1,1)

# %%
scaler_y=MinMaxScaler()
y_train_scaled=scaler_y.fit_transform(y_train_temp)
y_val_scaled=scaler_y.transform(y_valid_temp)
y_test_scaled=scaler_y.transform(y_test_temp)

# %%
y_train_scaled=y_train_scaled.reshape(y_train_3d.shape[0],y_train_3d.shape[1],y_train_3d.shape[2])
y_valid_scaled=y_val_scaled.reshape(y_valid_3d.shape[0],y_valid_3d.shape[1],y_valid_3d.shape[2])
y_test_scaled=y_test_scaled.reshape(y_test_3d.shape[0],y_test_3d.shape[1],y_test_3d.shape[2])

# %%
print(y_train_scaled.shape)
print(y_valid_scaled.shape)
print(y_test_scaled.shape)
# Out:
# (101780, 90, 30)
# (25445, 90, 30)
# (31807, 90, 30)

# %% [markdown]
# > MODEL

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# > 마지막 Timestep의 loss만 중요하다.

# %%
def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_absolute_error(Y_true[:, -1], Y_pred[:, -1]) #### <<-

# %% [markdown]
# ### Wavenet

# %% [markdown]
# >MODEL

# %%
filename='ConvGRU(90_30_1).h5'
callback_list1 = [tf.keras.callbacks.ModelCheckpoint(filepath='Checkpoint/{}'.format(filename),
                                                    monitor='val_last_time_step_mse',
                                                    verbose=1,
                                                    save_best_only=True,
                                                    mode='min'),
                 tf.keras.callbacks.EarlyStopping(monitor='val_last_time_step_mse',
                                                  patience=15)]

# %%
model= keras.models.Sequential([
    keras.layers.Conv1D(filters=180, kernel_size=4, strides=2, padding="valid",
                        input_shape=[None, 17]),
    #-------뭐라도 해보기 ----- OK, !! 
    #keras.layers.MaxPooling1D(pool_size=1, strides=None),
    keras.layers.GRU(180, return_sequences=True),
    keras.layers.GRU(180, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(30))
    ,
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, None, 180)         12420
# _________________________________________________________________
# gru_2 (GRU)                  (None, None, 180)         195480
# _________________________________________________________________
# gru_3 (GRU)                  (None, None, 180)         195480
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, None, 30)          5430
# =================================================================
# Total params: 408,810
# Trainable params: 408,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="mae", optimizer="adam", metrics=[last_time_step_mse])


history = model.fit(X_train_scaled, y_train_scaled[:, 3::2], epochs=80,
                    validation_data=(X_valid_scaled,y_valid_scaled[:, 3::2]),callbacks=callback_list1)
# Out:
# Epoch 1/80
# 3181/3181 [==============================] - ETA: 0s - loss: 0.0016 - last_time_step_mse: 0.0017
# Epoch 00001: val_last_time_step_mse improved from inf to 0.00103, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 306s 96ms/step - loss: 0.0016 - last_time_step_mse: 0.0017 - val_loss: 9.9967e-04 - val_last_time_step_mse: 0.0010
# Epoch 2/80
# 3181/3181 [==============================] - ETA: 0s - loss: 9.6954e-04 - last_time_step_mse: 0.0010
# Epoch 00002: val_last_time_step_mse did not improve from 0.00103
# 3181/3181 [==============================] - 356s 112ms/step - loss: 9.6954e-04 - last_time_step_mse: 0.0010 - val_loss: 0.0010 - val_last_time_step_mse: 0.0011
# Epoch 3/80
# 3181/3181 [==============================] - ETA: 0s - loss: 8.7376e-04 - last_time_step_mse: 9.0752e-04
# Epoch 00003: val_last_time_step_mse improved from 0.00103 to 0.00086, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 360s 113ms/step - loss: 8.7376e-04 - last_time_step_mse: 9.0752e-04 - val_loss: 8.4403e-04 - val_last_time_step_mse: 8.5864e-04
# Epoch 4/80
# 3181/3181 [==============================] - ETA: 0s - loss: 8.2318e-04 - last_time_step_mse: 8.5203e-04
# Epoch 00004: val_last_time_step_mse did not improve from 0.00086
# 3181/3181 [==============================] - 366s 115ms/step - loss: 8.2318e-04 - last_time_step_mse: 8.5203e-04 - val_loss: 8.5594e-04 - val_last_time_step_mse: 8.8667e-04
# Epoch 5/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.9250e-04 - last_time_step_mse: 8.2033e-04
# Epoch 00005: val_last_time_step_mse improved from 0.00086 to 0.00078, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 358s 112ms/step - loss: 7.9250e-04 - last_time_step_mse: 8.2033e-04 - val_loss: 7.5492e-04 - val_last_time_step_mse: 7.8012e-04
# Epoch 6/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.6747e-04 - last_time_step_mse: 7.9400e-04
# Epoch 00006: val_last_time_step_mse improved from 0.00078 to 0.00073, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 363s 114ms/step - loss: 7.6747e-04 - last_time_step_mse: 7.9400e-04 - val_loss: 7.2801e-04 - val_last_time_step_mse: 7.3162e-04
# Epoch 7/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.6074e-04 - last_time_step_mse: 7.8691e-04
# Epoch 00007: val_last_time_step_mse did not improve from 0.00073
# 3181/3181 [==============================] - 377s 119ms/step - loss: 7.6074e-04 - last_time_step_mse: 7.8691e-04 - val_loss: 7.2571e-04 - val_last_time_step_mse: 7.4955e-04
# Epoch 8/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.4670e-04 - last_time_step_mse: 7.7329e-04
# Epoch 00008: val_last_time_step_mse did not improve from 0.00073
# 3181/3181 [==============================] - 366s 115ms/step - loss: 7.4670e-04 - last_time_step_mse: 7.7329e-04 - val_loss: 7.2298e-04 - val_last_time_step_mse: 7.4727e-04
# Epoch 9/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.3626e-04 - last_time_step_mse: 7.6125e-04
# Epoch 00009: val_last_time_step_mse did not improve from 0.00073
# 3181/3181 [==============================] - 360s 113ms/step - loss: 7.3626e-04 - last_time_step_mse: 7.6125e-04 - val_loss: 7.3431e-04 - val_last_time_step_mse: 7.6020e-04
# Epoch 10/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.2534e-04 - last_time_step_mse: 7.4949e-04
# Epoch 00010: val_last_time_step_mse improved from 0.00073 to 0.00072, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 350s 110ms/step - loss: 7.2534e-04 - last_time_step_mse: 7.4949e-04 - val_loss: 6.9884e-04 - val_last_time_step_mse: 7.1673e-04
# Epoch 11/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.1291e-04 - last_time_step_mse: 7.3608e-04
# Epoch 00011: val_last_time_step_mse did not improve from 0.00072
# 3181/3181 [==============================] - 354s 111ms/step - loss: 7.1291e-04 - last_time_step_mse: 7.3608e-04 - val_loss: 7.1491e-04 - val_last_time_step_mse: 7.3398e-04
# Epoch 12/80
# 3181/3181 [==============================] - ETA: 0s - loss: 7.0556e-04 - last_time_step_mse: 7.2713e-04
# Epoch 00012: val_last_time_step_mse improved from 0.00072 to 0.00070, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 358s 113ms/step - loss: 7.0556e-04 - last_time_step_mse: 7.2713e-04 - val_loss: 6.8269e-04 - val_last_time_step_mse: 6.9503e-04
# Epoch 13/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.8931e-04 - last_time_step_mse: 7.0932e-04
# Epoch 00013: val_last_time_step_mse did not improve from 0.00070
# 3181/3181 [==============================] - 353s 111ms/step - loss: 6.8931e-04 - last_time_step_mse: 7.0932e-04 - val_loss: 7.2015e-04 - val_last_time_step_mse: 7.2186e-04
# Epoch 14/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.7574e-04 - last_time_step_mse: 6.9130e-04
# Epoch 00014: val_last_time_step_mse improved from 0.00070 to 0.00069, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 347s 109ms/step - loss: 6.7574e-04 - last_time_step_mse: 6.9130e-04 - val_loss: 6.8571e-04 - val_last_time_step_mse: 6.9372e-04
# Epoch 15/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.6289e-04 - last_time_step_mse: 6.7633e-04
# Epoch 00015: val_last_time_step_mse improved from 0.00069 to 0.00066, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 349s 110ms/step - loss: 6.6289e-04 - last_time_step_mse: 6.7633e-04 - val_loss: 6.4813e-04 - val_last_time_step_mse: 6.5603e-04
# Epoch 16/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.5255e-04 - last_time_step_mse: 6.6430e-04
# Epoch 00016: val_last_time_step_mse improved from 0.00066 to 0.00063, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 353s 111ms/step - loss: 6.5255e-04 - last_time_step_mse: 6.6430e-04 - val_loss: 6.2817e-04 - val_last_time_step_mse: 6.2808e-04
# Epoch 17/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.4407e-04 - last_time_step_mse: 6.5354e-04
# Epoch 00017: val_last_time_step_mse did not improve from 0.00063
# 3181/3181 [==============================] - 355s 112ms/step - loss: 6.4407e-04 - last_time_step_mse: 6.5354e-04 - val_loss: 6.2675e-04 - val_last_time_step_mse: 6.3709e-04
# Epoch 18/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.3387e-04 - last_time_step_mse: 6.4279e-04
# Epoch 00018: val_last_time_step_mse did not improve from 0.00063
# 3181/3181 [==============================] - 356s 112ms/step - loss: 6.3387e-04 - last_time_step_mse: 6.4279e-04 - val_loss: 6.5390e-04 - val_last_time_step_mse: 6.5889e-04
# Epoch 19/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.2621e-04 - last_time_step_mse: 6.3298e-04
# Epoch 00019: val_last_time_step_mse did not improve from 0.00063
# 3181/3181 [==============================] - 352s 111ms/step - loss: 6.2621e-04 - last_time_step_mse: 6.3298e-04 - val_loss: 6.5035e-04 - val_last_time_step_mse: 6.4599e-04
# Epoch 20/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.1729e-04 - last_time_step_mse: 6.2185e-04
# Epoch 00020: val_last_time_step_mse did not improve from 0.00063
# 3181/3181 [==============================] - 347s 109ms/step - loss: 6.1729e-04 - last_time_step_mse: 6.2185e-04 - val_loss: 6.2602e-04 - val_last_time_step_mse: 6.3207e-04
# Epoch 21/80
# 3181/3181 [==============================] - ETA: 0s - loss: 6.0662e-04 - last_time_step_mse: 6.0854e-04
# Epoch 00021: val_last_time_step_mse improved from 0.00063 to 0.00059, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 347s 109ms/step - loss: 6.0662e-04 - last_time_step_mse: 6.0854e-04 - val_loss: 5.9734e-04 - val_last_time_step_mse: 5.9472e-04
# Epoch 22/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.9960e-04 - last_time_step_mse: 5.9882e-04
# Epoch 00022: val_last_time_step_mse improved from 0.00059 to 0.00059, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 344s 108ms/step - loss: 5.9960e-04 - last_time_step_mse: 5.9882e-04 - val_loss: 5.9565e-04 - val_last_time_step_mse: 5.8687e-04
# Epoch 23/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.9226e-04 - last_time_step_mse: 5.8987e-04
# Epoch 00023: val_last_time_step_mse improved from 0.00059 to 0.00058, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 354s 111ms/step - loss: 5.9226e-04 - last_time_step_mse: 5.8987e-04 - val_loss: 5.9692e-04 - val_last_time_step_mse: 5.7873e-04
# Epoch 24/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.8584e-04 - last_time_step_mse: 5.7918e-04
# Epoch 00024: val_last_time_step_mse improved from 0.00058 to 0.00057, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 349s 110ms/step - loss: 5.8584e-04 - last_time_step_mse: 5.7918e-04 - val_loss: 5.8262e-04 - val_last_time_step_mse: 5.6652e-04
# Epoch 25/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.7907e-04 - last_time_step_mse: 5.7002e-04
# Epoch 00025: val_last_time_step_mse improved from 0.00057 to 0.00056, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 349s 110ms/step - loss: 5.7907e-04 - last_time_step_mse: 5.7002e-04 - val_loss: 5.7740e-04 - val_last_time_step_mse: 5.6028e-04
# Epoch 26/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.7198e-04 - last_time_step_mse: 5.6062e-04
# Epoch 00026: val_last_time_step_mse improved from 0.00056 to 0.00056, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 349s 110ms/step - loss: 5.7198e-04 - last_time_step_mse: 5.6062e-04 - val_loss: 5.7599e-04 - val_last_time_step_mse: 5.5972e-04
# Epoch 27/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.6810e-04 - last_time_step_mse: 5.5461e-04
# Epoch 00027: val_last_time_step_mse did not improve from 0.00056
# 3181/3181 [==============================] - 346s 109ms/step - loss: 5.6810e-04 - last_time_step_mse: 5.5461e-04 - val_loss: 5.9814e-04 - val_last_time_step_mse: 5.8104e-04
# Epoch 28/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.6364e-04 - last_time_step_mse: 5.4803e-04
# Epoch 00028: val_last_time_step_mse did not improve from 0.00056
# 3181/3181 [==============================] - 355s 112ms/step - loss: 5.6364e-04 - last_time_step_mse: 5.4803e-04 - val_loss: 5.8532e-04 - val_last_time_step_mse: 5.6659e-04
# Epoch 29/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.5975e-04 - last_time_step_mse: 5.4307e-04
# Epoch 00029: val_last_time_step_mse improved from 0.00056 to 0.00054, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 340s 107ms/step - loss: 5.5975e-04 - last_time_step_mse: 5.4307e-04 - val_loss: 5.5823e-04 - val_last_time_step_mse: 5.3776e-04
# Epoch 30/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.5468e-04 - last_time_step_mse: 5.3615e-04
# Epoch 00030: val_last_time_step_mse did not improve from 0.00054
# 3181/3181 [==============================] - 303s 95ms/step - loss: 5.5468e-04 - last_time_step_mse: 5.3615e-04 - val_loss: 5.6569e-04 - val_last_time_step_mse: 5.4412e-04
# Epoch 31/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.5421e-04 - last_time_step_mse: 5.3471e-04
# Epoch 00031: val_last_time_step_mse improved from 0.00054 to 0.00052, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 299s 94ms/step - loss: 5.5421e-04 - last_time_step_mse: 5.3471e-04 - val_loss: 5.4483e-04 - val_last_time_step_mse: 5.1920e-04
# Epoch 32/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.4552e-04 - last_time_step_mse: 5.2458e-04
# Epoch 00032: val_last_time_step_mse did not improve from 0.00052
# 3181/3181 [==============================] - 299s 94ms/step - loss: 5.4552e-04 - last_time_step_mse: 5.2458e-04 - val_loss: 5.6709e-04 - val_last_time_step_mse: 5.4489e-04
# Epoch 33/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.4329e-04 - last_time_step_mse: 5.2169e-04
# Epoch 00033: val_last_time_step_mse did not improve from 0.00052
# 3181/3181 [==============================] - 300s 94ms/step - loss: 5.4329e-04 - last_time_step_mse: 5.2169e-04 - val_loss: 5.6777e-04 - val_last_time_step_mse: 5.3864e-04
# Epoch 34/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.4068e-04 - last_time_step_mse: 5.1782e-04
# Epoch 00034: val_last_time_step_mse improved from 0.00052 to 0.00052, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 297s 93ms/step - loss: 5.4068e-04 - last_time_step_mse: 5.1782e-04 - val_loss: 5.5028e-04 - val_last_time_step_mse: 5.1863e-04
# Epoch 35/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.3687e-04 - last_time_step_mse: 5.1234e-04
# Epoch 00035: val_last_time_step_mse improved from 0.00052 to 0.00052, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 302s 95ms/step - loss: 5.3687e-04 - last_time_step_mse: 5.1234e-04 - val_loss: 5.4682e-04 - val_last_time_step_mse: 5.1679e-04
# Epoch 36/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.3462e-04 - last_time_step_mse: 5.0979e-04
# Epoch 00036: val_last_time_step_mse improved from 0.00052 to 0.00050, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 298s 94ms/step - loss: 5.3462e-04 - last_time_step_mse: 5.0979e-04 - val_loss: 5.3063e-04 - val_last_time_step_mse: 4.9853e-04
# Epoch 37/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.3131e-04 - last_time_step_mse: 5.0550e-04
# Epoch 00037: val_last_time_step_mse did not improve from 0.00050
# 3181/3181 [==============================] - 299s 94ms/step - loss: 5.3131e-04 - last_time_step_mse: 5.0550e-04 - val_loss: 5.4996e-04 - val_last_time_step_mse: 5.1657e-04
# Epoch 38/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.2891e-04 - last_time_step_mse: 5.0293e-04
# Epoch 00038: val_last_time_step_mse improved from 0.00050 to 0.00050, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 299s 94ms/step - loss: 5.2891e-04 - last_time_step_mse: 5.0293e-04 - val_loss: 5.2714e-04 - val_last_time_step_mse: 4.9516e-04
# Epoch 39/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.2715e-04 - last_time_step_mse: 5.0086e-04
# Epoch 00039: val_last_time_step_mse did not improve from 0.00050
# 3181/3181 [==============================] - 298s 94ms/step - loss: 5.2715e-04 - last_time_step_mse: 5.0086e-04 - val_loss: 5.4513e-04 - val_last_time_step_mse: 5.0769e-04
# Epoch 40/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.2483e-04 - last_time_step_mse: 4.9674e-04
# Epoch 00040: val_last_time_step_mse improved from 0.00050 to 0.00049, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 300s 94ms/step - loss: 5.2483e-04 - last_time_step_mse: 4.9674e-04 - val_loss: 5.2381e-04 - val_last_time_step_mse: 4.8912e-04
# Epoch 41/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.2205e-04 - last_time_step_mse: 4.9316e-04
# Epoch 00041: val_last_time_step_mse did not improve from 0.00049
# 3181/3181 [==============================] - 308s 97ms/step - loss: 5.2205e-04 - last_time_step_mse: 4.9316e-04 - val_loss: 5.5980e-04 - val_last_time_step_mse: 5.0915e-04
# Epoch 42/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.2023e-04 - last_time_step_mse: 4.9086e-04
# Epoch 00042: val_last_time_step_mse did not improve from 0.00049
# 3181/3181 [==============================] - 304s 96ms/step - loss: 5.2023e-04 - last_time_step_mse: 4.9086e-04 - val_loss: 5.3823e-04 - val_last_time_step_mse: 5.0199e-04
# Epoch 43/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.1809e-04 - last_time_step_mse: 4.8847e-04
# Epoch 00043: val_last_time_step_mse did not improve from 0.00049
# 3181/3181 [==============================] - 302s 95ms/step - loss: 5.1809e-04 - last_time_step_mse: 4.8847e-04 - val_loss: 5.2853e-04 - val_last_time_step_mse: 4.9423e-04
# Epoch 44/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.1595e-04 - last_time_step_mse: 4.8554e-04
# Epoch 00044: val_last_time_step_mse did not improve from 0.00049
# 3181/3181 [==============================] - 304s 96ms/step - loss: 5.1595e-04 - last_time_step_mse: 4.8554e-04 - val_loss: 5.2859e-04 - val_last_time_step_mse: 4.9352e-04
# Epoch 45/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.1449e-04 - last_time_step_mse: 4.8367e-04
# Epoch 00045: val_last_time_step_mse did not improve from 0.00049
# 3181/3181 [==============================] - 298s 94ms/step - loss: 5.1449e-04 - last_time_step_mse: 4.8367e-04 - val_loss: 5.5230e-04 - val_last_time_step_mse: 5.1378e-04
# Epoch 46/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.1230e-04 - last_time_step_mse: 4.8080e-04
# Epoch 00046: val_last_time_step_mse improved from 0.00049 to 0.00047, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 299s 94ms/step - loss: 5.1230e-04 - last_time_step_mse: 4.8080e-04 - val_loss: 5.0478e-04 - val_last_time_step_mse: 4.6577e-04
# Epoch 47/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.1060e-04 - last_time_step_mse: 4.7848e-04
# Epoch 00047: val_last_time_step_mse did not improve from 0.00047
# 3181/3181 [==============================] - 306s 96ms/step - loss: 5.1060e-04 - last_time_step_mse: 4.7848e-04 - val_loss: 5.3579e-04 - val_last_time_step_mse: 4.9870e-04
# Epoch 48/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.0943e-04 - last_time_step_mse: 4.7771e-04
# Epoch 00048: val_last_time_step_mse did not improve from 0.00047
# 3181/3181 [==============================] - 299s 94ms/step - loss: 5.0943e-04 - last_time_step_mse: 4.7771e-04 - val_loss: 5.2684e-04 - val_last_time_step_mse: 4.8501e-04
# Epoch 49/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.0714e-04 - last_time_step_mse: 4.7384e-04
# Epoch 00049: val_last_time_step_mse did not improve from 0.00047
# 3181/3181 [==============================] - 304s 96ms/step - loss: 5.0714e-04 - last_time_step_mse: 4.7384e-04 - val_loss: 5.1578e-04 - val_last_time_step_mse: 4.7850e-04
# Epoch 50/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.0551e-04 - last_time_step_mse: 4.7240e-04
# Epoch 00050: val_last_time_step_mse did not improve from 0.00047
# 3181/3181 [==============================] - 307s 97ms/step - loss: 5.0551e-04 - last_time_step_mse: 4.7240e-04 - val_loss: 5.1400e-04 - val_last_time_step_mse: 4.7346e-04
# Epoch 51/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.0373e-04 - last_time_step_mse: 4.6916e-04
# Epoch 00051: val_last_time_step_mse did not improve from 0.00047
# 3181/3181 [==============================] - 298s 94ms/step - loss: 5.0373e-04 - last_time_step_mse: 4.6916e-04 - val_loss: 5.2719e-04 - val_last_time_step_mse: 4.8185e-04
# Epoch 52/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.0367e-04 - last_time_step_mse: 4.6911e-04
# Epoch 00052: val_last_time_step_mse did not improve from 0.00047
# 3181/3181 [==============================] - 300s 94ms/step - loss: 5.0367e-04 - last_time_step_mse: 4.6911e-04 - val_loss: 5.2165e-04 - val_last_time_step_mse: 4.8564e-04
# Epoch 53/80
# 3181/3181 [==============================] - ETA: 0s - loss: 5.0134e-04 - last_time_step_mse: 4.6653e-04
# Epoch 00053: val_last_time_step_mse did not improve from 0.00047
# 3181/3181 [==============================] - 276s 87ms/step - loss: 5.0134e-04 - last_time_step_mse: 4.6653e-04 - val_loss: 5.1229e-04 - val_last_time_step_mse: 4.7200e-04
# Epoch 54/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.9978e-04 - last_time_step_mse: 4.6513e-04
# Epoch 00054: val_last_time_step_mse improved from 0.00047 to 0.00046, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 277s 87ms/step - loss: 4.9978e-04 - last_time_step_mse: 4.6513e-04 - val_loss: 5.1405e-04 - val_last_time_step_mse: 4.6455e-04
# Epoch 55/80
# 3180/3181 [============================>.] - ETA: 0s - loss: 4.9810e-04 - last_time_step_mse: 4.6227e-04
# Epoch 00055: val_last_time_step_mse did not improve from 0.00046
# 3181/3181 [==============================] - 277s 87ms/step - loss: 4.9813e-04 - last_time_step_mse: 4.6225e-04 - val_loss: 5.0738e-04 - val_last_time_step_mse: 4.6687e-04
# Epoch 56/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.9748e-04 - last_time_step_mse: 4.6173e-04
# Epoch 00056: val_last_time_step_mse improved from 0.00046 to 0.00046, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 283s 89ms/step - loss: 4.9748e-04 - last_time_step_mse: 4.6173e-04 - val_loss: 5.1030e-04 - val_last_time_step_mse: 4.6297e-04
# Epoch 57/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.9526e-04 - last_time_step_mse: 4.5861e-04
# Epoch 00057: val_last_time_step_mse improved from 0.00046 to 0.00046, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 282s 89ms/step - loss: 4.9526e-04 - last_time_step_mse: 4.5861e-04 - val_loss: 5.0592e-04 - val_last_time_step_mse: 4.6069e-04
# Epoch 58/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.9521e-04 - last_time_step_mse: 4.5855e-04
# Epoch 00058: val_last_time_step_mse did not improve from 0.00046
# 3181/3181 [==============================] - 267s 84ms/step - loss: 4.9521e-04 - last_time_step_mse: 4.5855e-04 - val_loss: 5.0102e-04 - val_last_time_step_mse: 4.6232e-04
# Epoch 59/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.9233e-04 - last_time_step_mse: 4.5503e-04
# Epoch 00059: val_last_time_step_mse improved from 0.00046 to 0.00045, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 288s 91ms/step - loss: 4.9233e-04 - last_time_step_mse: 4.5503e-04 - val_loss: 4.9918e-04 - val_last_time_step_mse: 4.5397e-04
# Epoch 60/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.9266e-04 - last_time_step_mse: 4.5521e-04
# Epoch 00060: val_last_time_step_mse did not improve from 0.00045
# 3181/3181 [==============================] - 287s 90ms/step - loss: 4.9266e-04 - last_time_step_mse: 4.5521e-04 - val_loss: 5.1182e-04 - val_last_time_step_mse: 4.6886e-04
# Epoch 61/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.9125e-04 - last_time_step_mse: 4.5288e-04
# Epoch 00061: val_last_time_step_mse did not improve from 0.00045
# 3181/3181 [==============================] - 276s 87ms/step - loss: 4.9125e-04 - last_time_step_mse: 4.5288e-04 - val_loss: 5.0533e-04 - val_last_time_step_mse: 4.6167e-04
# Epoch 62/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8927e-04 - last_time_step_mse: 4.5002e-04
# Epoch 00062: val_last_time_step_mse did not improve from 0.00045
# 3181/3181 [==============================] - 263s 83ms/step - loss: 4.8927e-04 - last_time_step_mse: 4.5002e-04 - val_loss: 5.1200e-04 - val_last_time_step_mse: 4.6173e-04
# Epoch 63/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8883e-04 - last_time_step_mse: 4.5004e-04
# Epoch 00063: val_last_time_step_mse did not improve from 0.00045
# 3181/3181 [==============================] - 256s 81ms/step - loss: 4.8883e-04 - last_time_step_mse: 4.5004e-04 - val_loss: 5.0268e-04 - val_last_time_step_mse: 4.5680e-04
# Epoch 64/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8712e-04 - last_time_step_mse: 4.4789e-04
# Epoch 00064: val_last_time_step_mse improved from 0.00045 to 0.00044, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 302s 95ms/step - loss: 4.8712e-04 - last_time_step_mse: 4.4789e-04 - val_loss: 4.8985e-04 - val_last_time_step_mse: 4.4352e-04
# Epoch 65/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8530e-04 - last_time_step_mse: 4.4528e-04
# Epoch 00065: val_last_time_step_mse did not improve from 0.00044
# 3181/3181 [==============================] - 255s 80ms/step - loss: 4.8530e-04 - last_time_step_mse: 4.4528e-04 - val_loss: 4.9525e-04 - val_last_time_step_mse: 4.5560e-04
# Epoch 66/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8647e-04 - last_time_step_mse: 4.4731e-04
# Epoch 00066: val_last_time_step_mse did not improve from 0.00044
# 3181/3181 [==============================] - 237s 74ms/step - loss: 4.8647e-04 - last_time_step_mse: 4.4731e-04 - val_loss: 5.0453e-04 - val_last_time_step_mse: 4.5714e-04
# Epoch 67/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8454e-04 - last_time_step_mse: 4.4445e-04
# Epoch 00067: val_last_time_step_mse improved from 0.00044 to 0.00044, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 229s 72ms/step - loss: 4.8454e-04 - last_time_step_mse: 4.4445e-04 - val_loss: 4.8920e-04 - val_last_time_step_mse: 4.3916e-04
# Epoch 68/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8378e-04 - last_time_step_mse: 4.4253e-04
# Epoch 00068: val_last_time_step_mse did not improve from 0.00044
# 3181/3181 [==============================] - 225s 71ms/step - loss: 4.8378e-04 - last_time_step_mse: 4.4253e-04 - val_loss: 5.0464e-04 - val_last_time_step_mse: 4.5703e-04
# Epoch 69/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8375e-04 - last_time_step_mse: 4.4336e-04
# Epoch 00069: val_last_time_step_mse did not improve from 0.00044
# 3181/3181 [==============================] - 224s 70ms/step - loss: 4.8375e-04 - last_time_step_mse: 4.4336e-04 - val_loss: 4.9232e-04 - val_last_time_step_mse: 4.4779e-04
# Epoch 70/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8142e-04 - last_time_step_mse: 4.3987e-04
# Epoch 00070: val_last_time_step_mse did not improve from 0.00044
# 3181/3181 [==============================] - 222s 70ms/step - loss: 4.8142e-04 - last_time_step_mse: 4.3987e-04 - val_loss: 4.9389e-04 - val_last_time_step_mse: 4.4735e-04
# Epoch 71/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8049e-04 - last_time_step_mse: 4.3890e-04
# Epoch 00071: val_last_time_step_mse did not improve from 0.00044
# 3181/3181 [==============================] - 223s 70ms/step - loss: 4.8049e-04 - last_time_step_mse: 4.3890e-04 - val_loss: 5.0331e-04 - val_last_time_step_mse: 4.5519e-04
# Epoch 72/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7917e-04 - last_time_step_mse: 4.3729e-04
# Epoch 00072: val_last_time_step_mse did not improve from 0.00044
# 3181/3181 [==============================] - 236s 74ms/step - loss: 4.7917e-04 - last_time_step_mse: 4.3729e-04 - val_loss: 4.9664e-04 - val_last_time_step_mse: 4.4614e-04
# Epoch 73/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.8016e-04 - last_time_step_mse: 4.3810e-04
# Epoch 00073: val_last_time_step_mse improved from 0.00044 to 0.00043, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 303s 95ms/step - loss: 4.8016e-04 - last_time_step_mse: 4.3810e-04 - val_loss: 4.8120e-04 - val_last_time_step_mse: 4.2993e-04
# Epoch 74/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7829e-04 - last_time_step_mse: 4.3590e-04
# Epoch 00074: val_last_time_step_mse did not improve from 0.00043
# 3181/3181 [==============================] - 224s 70ms/step - loss: 4.7829e-04 - last_time_step_mse: 4.3590e-04 - val_loss: 4.8262e-04 - val_last_time_step_mse: 4.3099e-04
# Epoch 75/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7771e-04 - last_time_step_mse: 4.3493e-04
# Epoch 00075: val_last_time_step_mse did not improve from 0.00043
# 3181/3181 [==============================] - 261s 82ms/step - loss: 4.7771e-04 - last_time_step_mse: 4.3493e-04 - val_loss: 4.9641e-04 - val_last_time_step_mse: 4.4534e-04
# Epoch 76/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7684e-04 - last_time_step_mse: 4.3426e-04
# Epoch 00076: val_last_time_step_mse improved from 0.00043 to 0.00043, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 232s 73ms/step - loss: 4.7684e-04 - last_time_step_mse: 4.3426e-04 - val_loss: 4.8726e-04 - val_last_time_step_mse: 4.2927e-04
# Epoch 77/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7638e-04 - last_time_step_mse: 4.3311e-04
# Epoch 00077: val_last_time_step_mse did not improve from 0.00043
# 3181/3181 [==============================] - 221s 70ms/step - loss: 4.7638e-04 - last_time_step_mse: 4.3311e-04 - val_loss: 4.9120e-04 - val_last_time_step_mse: 4.4677e-04
# Epoch 78/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7322e-04 - last_time_step_mse: 4.2918e-04
# Epoch 00078: val_last_time_step_mse did not improve from 0.00043
# 3181/3181 [==============================] - 222s 70ms/step - loss: 4.7322e-04 - last_time_step_mse: 4.2918e-04 - val_loss: 4.9700e-04 - val_last_time_step_mse: 4.4743e-04
# Epoch 79/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7553e-04 - last_time_step_mse: 4.3187e-04
# Epoch 00079: val_last_time_step_mse improved from 0.00043 to 0.00043, saving model to Checkpoint/ConvGRU(90_30_1).h5
# 3181/3181 [==============================] - 222s 70ms/step - loss: 4.7553e-04 - last_time_step_mse: 4.3187e-04 - val_loss: 4.7826e-04 - val_last_time_step_mse: 4.2725e-04
# Epoch 80/80
# 3181/3181 [==============================] - ETA: 0s - loss: 4.7326e-04 - last_time_step_mse: 4.2887e-04
# Epoch 00080: val_last_time_step_mse did not improve from 0.00043
# 3181/3181 [==============================] - 222s 70ms/step - loss: 4.7326e-04 - last_time_step_mse: 4.2887e-04 - val_loss: 5.0484e-04 - val_last_time_step_mse: 4.5576e-04

# %% [markdown]
# > 재실행

# %%
filtersize=90
targetsize=30
stride=1

# %%
path='Checkpoint'+'/Wavenet({}_{}_{})'.format(filtersize,targetsize,stride)+'.h5'

# %%
loaded_model = tf.keras.models.load_model(path,custom_objects={'customLoss1':last_time_step_mse},compile=False)

# %%
# compile the model
loaded_model.compile(optimizer='adam', loss='mae',metrics=[last_time_step_mse])

# %%
loaded_model.fit(X_train_scaled, y_train_scaled, epochs=8,
                    validation_data=(X_valid_scaled,y_valid_scaled),callbacks=callback_list1)
# Out:
# Epoch 1/8
# 3181/3181 [==============================] - ETA: 0s - loss: 5.3794e-04 - last_time_step_mse: 5.3657e-04
# Epoch 00001: val_last_time_step_mse improved from inf to 0.00054, saving model to Checkpoint/Wavenet(90_30_1).h5
# 3181/3181 [==============================] - 1736s 546ms/step - loss: 5.3794e-04 - last_time_step_mse: 5.3657e-04 - val_loss: 5.4332e-04 - val_last_time_step_mse: 5.4078e-04
# Epoch 2/8
#  225/3181 [=>............................] - ETA: 30:12 - loss: 5.3094e-04 - last_time_step_mse: 5.0259e-04
