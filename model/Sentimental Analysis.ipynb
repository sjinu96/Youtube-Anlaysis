# %%
import os
from glob import glob

import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from konlpy.tag import Okt

# %% [markdown]
# ### 함수 정의

# %%
def for_tokenizer(tokenizer):
    threshold=3 # 이것들 구하는 이유를 확실히 하자 *** 빈도수 적은 건 빼는게 나음.

    total_cnt=len(tokenizer.word_index)
    rare_cnt=0 # threshold보다 작은 단어의 수  ?
    total_freq=0 # 전체 단어 빈도수의 합
    rare_freq=0 # 빈도수의 총 합.

    for key,value in tokenizer.word_counts.items(): #역시, 하나만 쓰여도 2개로 받아야 한다.
        total_freq+=value

        if(value<threshold):  #OrderedDict ? *** 
            rare_cnt+=1
            rare_freq+=value
    vocab_size=total_cnt-rare_cnt+2 # 0,1번의 패딩과 OOV토큰 고려
    print('단어 집합의 크기 :', vocab_size)
    return vocab_size

# %% [markdown]
# ### 정제함수 , 완료 : 한국어 // 미완료 : 영어, 이모티콘
# > 한글만 사용 가능
# * INPUT : 원본 댓글.csv의 DataFrame 형식  ( pd.read_csv('comment.csv') )
# * OUTPUT : 정제 후 댓글.csv의 DataFrame 형식 ( ~.to_csv('comment_refined.csv')로 저장)

# %%
def refining (comment_csv): # 입력으로 댓글 csv하나를 받는다. (pd.Dataframe 형식으로 )
    prev_len=len(comment_csv) # 정제 전 댓글 개수
    
    #한글 외 댓글들은 '    '처럼 모두 공백 or null값으로 저장. 
    comment_csv['comment_refined']=comment_csv['comment'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") #띄어쓰기까지
    #공백댓글 인덱스 추출
    blank_index=[index for index,comment in enumerate(comment_csv['comment_refined']) if (set(comment)=={' '})]
    #공백댓글 제거
    comment_csv.drop(blank_index,inplace=True)
    #null댓글 제거
    comment_csv['comment_refined'].replace('', np.nan, inplace=True) #empty comment를 null로.
    comment_csv.dropna(how='any',inplace=True) # null값 삭제
    #인덱스 초기화
    comment_csv.reset_index(drop=True,inplace=True)
    after_len=len(comment_csv)
    
    #열 순서 변경
    comment_csv=comment_csv[['author','comment','comment_refined','like']]
    print(f'[{prev_len}개 -->  {after_len}개]')
    
    #정제 문자열이 추가된 Dataframe 반환. 
    return comment_csv

# 보강 : 물음표, 특수문자, 이모티콘, 영어
# 정제 된 댓글은 konlpy의 형태소 분석기를 이용하여 시뮬레이션을 해본다.
# 정제 후 저장되는 폴더만 다를 뿐, 댓글 csv의 이름은 동일하다.


#INPUT
# folder : 주피터 노트북 파일과 같은 경로에 있는 폴더 이름
# meta_path_list : 위에서 정의한 (BJ)_meta.csv의 경로 array
# channel_path_list : 위에서 정의한 folder/(BJ) 의 경로 array 
# channel_list : BJ list.
# opt : 용량이 크기 때문에, 잘못 저장되면 큰일나므로 기본적으로 상위 1개의 폴더에 대해서만 진행
# opt = 'test' : BJ 1개의 폴더만 저장 진행 /// opt = 'full' : BJ 전체의 폴더에 대해 저장 진행
def all_refining(folder,meta_path_list,channel_path_list,channel_list): 
    #새로 저장할 폴더 만들기 (폴더 이름 : comment_refined)
    for bj in os.listdir(folder):
        try:
            os.mkdir(os.path.join(folder,bj,'comments_refined'))
        except:
            pass
        
    before_num=[]
    after_num=[]
    # meta_path_list = [././오스틴_meta.csv,     ./.버들Buddle_meta.csv , .....]
    for index, meta_path in enumerate(meta_path_list): 
        meta_temp=pd.read_csv(meta_path) # 1개의 meta파일 불러오기.
        
        #channel 하나당, 총 댓글 meta file 생성
        meta_comment=pd.DataFrame(columns=['channel','title','author','comment','comment_refined','like'])
        
        
        num=len(meta_temp)-1 #동영상 개수
        before_num.append(num) # 변경 이전 동영상 개수 지정
        error_count=0 #동영상을 불러오지 못한 개수 카운팅
        for idx,(channel,title) in enumerate(meta_temp[['channel','title']].to_numpy()):
            
            try: #하나의 댓글 불러오기, 가끔 인코딩 오류 뜰 수도 있음 #오류 확인해야함 ***
                temp=pd.read_csv(os.path.join(channel_path_list[index],r'comments\{}.csv'.format(title)),engine='python',encoding='UTF-8')

            except :
                error_count+=1
                print(f'댓글 로드 실패 : [{idx}/{num}] [{channel}] <{title}>')
                continue
                
            try: #간혹, 정제할 때 오류 뜰 수도 있음
                temp=refining(temp) # 우선, 한국어만 변환, title도 저장
            except:
                error_count+=1
                print(f'댓글 정제 실패 : [{idx}/{num}] [{channel}] <{title}>')
                continue
            # 저장
            #열 추가 생성
            temp['channel']=channel
            temp['title']=title
            temp=temp[['channel','title','author','comment','comment_refined','like']] #순서조정
            meta_comment=meta_comment.append(temp)
            print(f'댓글 변환 성공 : [{idx}/{num}] [{channel}] <{title}>') 
        #################이거 to_csv대신 to_pickle?
        meta_comment.to_csv(os.path.join(channel_path_list[index],r'{}_meta_comment.csv'.format(channel_list[index])),index=False)
        after_num.append(num-error_count)
        
    print('------------------------------------------------------------------')
    print('실행 종료')
    for i in range(len(before_num)):
        print('[{}]채널의 댓글 정제 결과 , 변경 전 동영상 개수: {} 변경 후 동영상 개수 : {}'.format(channel_list[i],before_num[i],after_num[i]))

# %% [markdown]
# ### 댓글 예측 함수(개별모니터링용, 채널전체용)

# %%
# 단순 모니터링용, meta_comment에 영향 xs
# 위에서 tokenizer를 가져와야 쓸 수 있다.
def sentiment_predict(meta_comment,start,end): #이는 모니터링 용으로, [start:end]로 slicing함.
    meta_comment=pd.read_csv(meta_comment) # meta_comment : 의 경로
    X_train=[]
    okt=Okt() #형태소 분석기
    original=meta_comment['comment'][start:end]
    original=original.to_frame()
    original.columns=['comment']
    score_array=[]
    for index,sentence in enumerate(meta_comment['comment_refined'][start:end]): # 토큰화
        temp_X=okt.morphs(sentence,stem=True)
        #이거 lstm에서는 하나 빼야함
        temp_X=[word for word in temp_X if not word in stopwords_movie]
        #temp_X=[word for word in temp_X if not word in stopwords_shop]
        encoded=tokenizer2.texts_to_sequences([temp_X])
        pad_new=pad_sequences(encoded,maxlen=30)        
        score=float(loaded_model2.predict(pad_new))
        print(original.values[index])
        score_array.append(score*100)
        if(score > 0.5):
            print("--> ","{:.2f}% 확률로 긍정적인 댓글입니다.\n".format(score * 100))
            
        else:
            print("-->","{:.2f}% 확률로 부정적인 댓글입니다.\n".format((1 - score) * 100))
            
    original["sentiment_score"]=score_array
    return original

# 단순 모니터링용, meta_comment에 영향 xs
# 위에서 tokenizer를 가져와야 쓸 수 있다.
# meta_comment : 경로. 
# output : 전체 결과의 meta_comment_predict1(1,2,3... ) 생성(모델마다 비교해야함)
def sentiment_predict_all(meta_comment):
    meta_comment=pd.read_csv(meta_comment) # meta_comment : 의 경로
    X_train=[]
    okt=Okt() #형태소 분석기
    original=meta_comment['comment']
    for sentence in meta_comment['comment_refined'][start:end]: # 토큰화
        temp_X=okt.morphs(sentence,stem=True)
        temp_X=[word for word in temp_X if not word in stopwords_movie]
        temp_X=[word for word in temp_X if not word in stopwords_shop]
        X_train.append(temp_X)
    encoded=tokenizer.texts_to_sequences(X_train)
    print(encoded)
    pad_new=pad_sequences(encoded,maxlen=max_len)
    score_array=[]
    for index,comment in enumerate(pad_new):
        score=float(loaded_model.predict(comment))
        if(score > 0.5):
            print(comment)
            print("--> ","{:.2f}% 확률로 긍정적인 댓글입니다.\n".format(score * 100))
            socre_array.append(score*100)
        else:
            print(comment)
            print("-->","{:.2f}% 확률로 부정적인 댓글입니다.\n".format((1 - score) * 100))
            score_array.append(score*100)
    original["sentiment_score"]=score_array
    return original

# %% [markdown]
# ## 폴더 내 댓글들 정제

# %%
folder='크롤링폴더' # 크롤링 할 폴더 이름 (주피터노트북과 같은 경로에 있을 때)

# %%
# 폴더 내 모든 정보 수집
channel_list=os.listdir(folder) #채널 이름 list
channel_path_list=glob(r'{}\*'.format(folder)) #채널 경로 list (위랑 같아야 함, 다르다면 수동 설정)
meta_path_list=[]
for i in range(len(channel_list)):
    meta_path_list.append(os.path.join(channel_path_list[i],
                                       '{}_meta.csv'.format(channel_list[i])))

# %%
print('크롤링 할 채널들 : ',channel_list)
print('크롤링 할 채널 경로들 : ',channel_path_list)
print('메타 파일 경로들 : ', meta_path_list)
# Out:
# 크롤링 할 채널들 :  ['BENI 유베니', 'Eating what is Given 오스틴', '가오니의 메뉴판GAONI', '리폴LeePaul', '밍칭mingching', '버들Buddle', '부엉이TV', '살빼조DietJo', '세리티 Serity', '유노-U_know', '캐피 KEPHI']
# 크롤링 할 채널 경로들 :  ['크롤링폴더\\BENI 유베니', '크롤링폴더\\Eating what is Given 오스틴', '크롤링폴더\\가오니의 메뉴판GAONI', '크롤링폴더\\리폴LeePaul', '크롤링폴더\\밍칭mingching', '크롤링폴더\\버들Buddle', '크롤링폴더\\부엉이TV', '크롤링폴더\\살빼조DietJo', '크롤링폴더\\세리티 Serity', '크롤링폴더\\유노-U_know', '크롤링폴더\\캐피 KEPHI']
# 메타 파일 경로들 :  ['크롤링폴더\\BENI 유베니\\BENI 유베니_meta.csv', '크롤링폴더\\Eating what is Given 오스틴\\Eating what is Given 오스틴_meta.csv', '크롤링폴더\\가오니의 메뉴판GAONI\\가오니의 메뉴판GAONI_meta.csv', '크롤링폴더\\리폴LeePaul\\리폴LeePaul_meta.csv', '크롤링폴더\\밍칭mingching\\밍칭mingching_meta.csv', '크롤링폴더\\버들Buddle\\버들Buddle_meta.csv', '크롤링폴더\\부엉이TV\\부엉이TV_meta.csv', '크롤링폴더\\살빼조DietJo\\살빼조DietJo_meta.csv', '크롤링폴더\\세리티 Serity\\세리티 Serity_meta.csv', '크롤링폴더\\유노-U_know\\유노-U_know_meta.csv', '크롤링폴더\\캐피 KEPHI\\캐피 KEPHI_meta.csv']

# %% [markdown]
# ### 폴더 내 comments 정제 - 한국어 , 영어,이모티콘(미완)
# > 실행 결과 ~_meta_comment.csv가 생김

# %%
pd.read_csv('버들Buddle_meta.csv')
# Out:
#       channel  subscribe                                              title  \
# 0    버들Buddle      90000  [와차밥] 갓담은 김치 하나면 됩니다 먹방 요리 레시피 🌶🌶 Korean Kimch...
# 1    버들Buddle      90000  [와차밥]햄 가득 부대찌개 라면사리 치즈닭갈비 먹방 Budae jjigae(Spic...
# 2    버들Buddle      90000  [와차밥] 신라면 대파김치 콘치즈밥전 먹방 Spicy Noodles & Cheese...
# 3    버들Buddle      90000  [와차밥] LA갈비 부추무침 먹방 요리 레시피 LA Galbi(Beef rib) M...
# 4    버들Buddle      90000  [와차밥] 육회비빔밥 꽃게된장찌개 먹방 요리 Korean Home Made Food...
# ..        ...        ...                                                ...
# 310  버들Buddle      90000  BHC 뿌링클 닭다리 치즈볼 먹방 Chicken Cheese ball REAL SO...
# 311  버들Buddle      90000  문현전통 한우 곱창전골 먹방 REAL SOUND ASMR MUKBANG EATING...
# 312  버들Buddle      90000  짜파게티 3봉 통단무지 먹방 Black been noodles REAL SOUND ...
# 313  버들Buddle      90000  통삼겹 고추냉이 비빔국수 먹방 Pork belly Spicy noodle REAL ...
# 314  버들Buddle      90000  첫 영상 스파이시 투움바 파스타 교촌 레드스틱 먹방 Pasta Chicken REA...
#
#       view  duration        date  \
# 0    39283      9.70  2020-11-02
# 1    31884     12.65  2020-10-31
# 2    52445     10.43  2020-10-29
# 3    61211     13.10  2020-10-27
# 4    27966     10.65  2020-10-25
# ..     ...       ...         ...
# 310   3283     19.42  2019-02-01
# 311   5078     14.30  2019-01-30
# 312   2698     12.37  2019-01-29
# 313   2284     13.63  2019-01-27
# 314   4546     21.98  2019-01-26
#
#                                            description  comment  like  \
# 0    ✅Turn on subtitle settings.\n\n구독 좋아요는 사랑입니다❤\...      161  1820
# 1    ✅Turn on subtitle settings.\n\n구독 좋아요는 사랑입니다❤ ...       79  1349
# 2    ✅Turn on subtitle settings.\n\n구독 좋아요는 사랑입니다❤ ...       94  1683
# 3    ✅Turn on subtitle settings.\n\n구독 좋아요는 사랑입니다❤ ...      109  2081
# 4    ✅Turn on subtitle settings.\n\n구독 좋아요는 사랑입니다❤\...       75  1273
# ..                                                 ...      ...   ...
# 310  #BHC뿌링클#치즈볼#먹방#mukbang\n좋아요와 구독 눌러주세요 ! ❤️\n시청...       23   125
# 311  #곱창전골#먹방#mukbang\n구독과 좋아요 눌러주세요 ! ❤️\n시청해주셔서 감...       29   137
# 312  #짜파게티#통단무지#먹방#mukbang\n구독과 좋아요 눌러주세요 ! ❤️\n시청해...       20   115
# 313  #통삼겹#비빔국수#먹방#mukbang\n구독과 좋아요 눌러주세요! ❤️\n시청해주셔...       15   110
# 314  #스파이시투움바파스타#교촌레드스틱#먹방#mukbang\n구독과 좋아요 눌러주세요! ...       32   194
#
#      dislike                                          thumbnail
# 0         57  https://i.ytimg.com/vi/9A_pTN6fHeg/maxresdefau...
# 1         33  https://i.ytimg.com/vi/i1MmA1svaO0/maxresdefau...
# 2         51  https://i.ytimg.com/vi/sQe9-EzszC8/maxresdefau...
# 3         59  https://i.ytimg.com/vi/oEMKvwETpTI/maxresdefau...
# 4         33  https://i.ytimg.com/vi/TnxNVpH9KeM/maxresdefau...
# ..       ...                                                ...
# 310        3  https://i.ytimg.com/vi/-3dKTUprGgw/maxresdefau...
# 311        9  https://i.ytimg.com/vi/dblCYv4rh2g/maxresdefau...
# 312        3  https://i.ytimg.com/vi/T9QIzXPad-s/maxresdefau...
# 313        2  https://i.ytimg.com/vi/YWGknEqWHgs/maxresdefau...
# 314        7  https://i.ytimg.com/vi/P4eGbIyeLhs/maxresdefau...
#
# [315 rows x 11 columns]

# %%
all_refining(folder,meta_path_list,channel_path_list,channel_list)
# Out:
# [106개 -->  103개]
# 댓글 변환 성공 : [0/62] [유노-U_know] <한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶음면 2개 먹고 4분 44초 버티기! korean eating show K food fighter>
# 댓글 로드 실패 : [1/62] [유노-U_know] <빵이 16종이나!? 미슐랭 별 3개 빵집 다 털어 왔습니다!! 빵 16종 먹방!! korean eating show korean food fighter>
# 댓글 로드 실패 : [2/62] [유노-U_know] <불마왕 라면 2개를 12초컷..? 아니;; 라면이 있었는데.. 없어요;; ㅋㅋㅋㅋㅋㅋㅋㅋ 최군님 푸파대회에서 1등하고 왔습니다! korean food fighter>
# [129개 -->  124개]
# 댓글 변환 성공 : [3/62] [유노-U_know] <실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜장면과 떡만둣국 먹방!! korean eating show korean food fighter>
# [65개 -->  59개]
# 댓글 변환 성공 : [4/62] [유노-U_know] <마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Korean eating show korean eating challenge>
# [76개 -->  70개]
# 댓글 변환 성공 : [5/62] [유노-U_know] <단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating show korean food fighter>
# 댓글 로드 실패 : [6/62] [유노-U_know] <협찬 받았는데..대왕떡볶이 도전먹방..? 20분 안에 다 먹으면 트로피에 10만원까지 주신대요! 맛난맛떡볶이  korean eating show korean food fighter>
# [52개 -->  46개]
# 댓글 변환 성공 : [7/62] [유노-U_know] <고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean eating show korean food fighter>
# [55개 -->  48개]
# 댓글 변환 성공 : [8/62] [유노-U_know] <모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋㅋㅋㅋ korean eating show korean food fighter pork cutlet>
# 댓글 로드 실패 : [9/62] [유노-U_know] <짜장면이 무려  9개..? 쟁반짜장이 작아서 초대형 사이즈로 만들어봤습니다! 짜장면 9개 차돌짬뽕 1개 먹방!korean eating show korean food fighter>
# [39개 -->  37개]
# 댓글 변환 성공 : [10/62] [유노-U_know] <자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카 볶음밥!! korean eating show korean food fighter>
# 댓글 로드 실패 : [11/62] [유노-U_know] <제한시간 30분인데 10분 컷이라고..? 컨버터피자 도전하고 왔습니다! korean eating show korean food fighter>
# 댓글 로드 실패 : [12/62] [유노-U_know] <총 길이 1M!? 서브웨이 샌드위치 7개, 쿠키 종류별 먹방! 서브웨이는 쿠키 맛집.. korean eating show korean food fighter>
# [20개 -->  20개]
# 댓글 변환 성공 : [13/62] [유노-U_know] <온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!>
# 댓글 로드 실패 : [14/62] [유노-U_know] <한 끼에 10000kcal..?  사장님이 너무 많이 보내주셨습니다.. 감사합니다 ㅎㅎ korean eating show mukbang korean food fighter>
# 댓글 로드 실패 : [15/62] [유노-U_know] <라최몇!?은 아니구 적당하게 라면 20봉만 먹어봤습니다! korean eating show korean mukbang korean  food fighter>
# 댓글 로드 실패 : [16/62] [유노-U_know] <농심 신상! 신라면 블랙 두부김치!? 간단하게 6개만 먹어보겠습니다! korean eating show korean mukbang korean food fighter>
# 댓글 로드 실패 : [17/62] [유노-U_know] <짜파게티 6개를 43초만에..? He is not human Korean eating show korean eating challenge korean food fighter>
# [46개 -->  42개]
# 댓글 변환 성공 : [18/62] [유노-U_know] <야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean eating show Korean mukbang Korean food fighter>
# 댓글 로드 실패 : [19/62] [유노-U_know] <짜장면 10개를 8분 안에 먹는다고..? 한국 최고기록 도전?! korean mukbangshow korean eating challenge korean food fighter>
# 댓글 로드 실패 : [20/62] [유노-U_know] <맘스터치 햄버거 10종 먹방! 10갠데 5000칼로리가 안넘는다고? ASMR korean hamburger korean mukbang show korean food fighter>
# [35개 -->  33개]
# 댓글 변환 성공 : [21/62] [유노-U_know] <이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! Korean mukbang Korean eating show food fighter>
# [64개 -->  58개]
# 댓글 변환 성공 : [22/62] [유노-U_know] <고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eating show! korean mukbang korean food fighter>
# 댓글 로드 실패 : [23/62] [유노-U_know] <요구르트 토 안하고 70개 먹으면 300만원이요..? 최대100개까지 도전!? korean eating challenge>
# 댓글 로드 실패 : [24/62] [유노-U_know] <[푸파]맥너겟 100개를 10분 만에..? 맥너겟 100개 10분대 도전해봤습니당 food eating challenge mukbang 도전먹방>
# [34개 -->  32개]
# 댓글 변환 성공 : [25/62] [유노-U_know] <간단하게 연어 1kg! 통연어,연어국수 먹방!>
# [29개 -->  29개]
# 댓글 변환 성공 : [26/62] [유노-U_know] <bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating challenge>
# 댓글 로드 실패 : [27/62] [유노-U_know] <짜장면 5개를 1분대 컷..? 요새 유행하는 푸파 저도 한 번 도전해봤습니다! korean eating challenge>
# 댓글 로드 실패 : [28/62] [유노-U_know] <혼자서 초밥 100접시를..?  korean mukbang show korean eating challenge>
# [104개 -->  100개]
# 댓글 변환 성공 : [29/62] [유노-U_know] <역대급 도전 메뉴.. 대왕수제버거 10개 사이드 메뉴 5개 제한시간 20분..! 다 먹으면 공짜! 브로스버거 도전!!  korean eating challenge>
# [63개 -->  60개]
# 댓글 변환 성공 : [30/62] [유노-U_know] <두끼 떡볶이에서 혼밥하고 왔습니다..!  korean mukbang show>
# [31개 -->  29개]
# 댓글 변환 성공 : [31/62] [유노-U_know] <탕수육 2000원 최저가 가성비 맛집 ! Feat. 떡볶이 튀김 짜장면 korean mukbang show korean eating challenge>
# [54개 -->  51개]
# 댓글 변환 성공 : [32/62] [유노-U_know] <엉터리생고기에서 삼겹살 4kg 먹방 korean mukbang show korean eating challenge>
# [132개 -->  109개]
# 댓글 변환 성공 : [33/62] [유노-U_know] <괴물짜장 100초 컷..!ㄹㅇ 진짜 얘는 괴물이다.. 영상 마지막까지 봐주세요! korean  mukbang show korean eating challenge>
# 댓글 로드 실패 : [34/62] [유노-U_know] <역대급 양..!? 츠케멘 20그릇 20분 안에 다 먹으면 20만원?! 대전 본미당 도전먹방! Korean mukbang korean eating challenge>
# 댓글 로드 실패 : [35/62] [유노-U_know] <총 6000kcal !? 다 먹으면 400만원..? 맥도날드 챌린지! 저도 한 번.. 도전해봤습니다! $3,500 McDonalds Challenge!! Korean mukbang>
# 댓글 로드 실패 : [36/62] [유노-U_know] <400원에 라면 한개씩!? 총 15봉!! 미친 가성빜ㅋㅋㅋㅋㅋ [운현나라 라면 무한리필] korean mukbang korean ramen noodle>
# [86개 -->  83개]
# 댓글 변환 성공 : [37/62] [유노-U_know] <빙수야 메뉴 다 먹고왔어용 사장님이 칭찬해쥼 ㅎㅎkorean mukbang show korean eating challenge>
# 댓글 로드 실패 : [38/62] [유노-U_know] <1등 도전해봤습니다! 3XL+3XL 대왕 피자와 초대형 스파게티..!? 20분 안에 다 먹으면 공짜! 1등 상금 30만원!!! Korean eating challenge>
# [77개 -->  73개]
# 댓글 변환 성공 : [39/62] [유노-U_know] <점보라멘 도전하고 왔어요! 20분 안에 다 먹으면 공짜! GIANT Ramen korean eating challenge>
# [118개 -->  118개]
# 댓글 변환 성공 : [40/62] [유노-U_know] <육개장 먹고 5kg 쪘습니다..^^ 20분 안에 다 먹으면 공짜! Korean eating challenge>
# 댓글 로드 실패 : [41/62] [유노-U_know] <이게 2인분..? 산더미물갈비 20분 안에 먹으면 공짜!! Korean mukbang show korean eating challenge>
# 댓글 로드 실패 : [42/62] [유노-U_know] <수제버거 8개 다 먹으면 10만원!? 햄최몇 도전 먹방!! Korean mukbang show korean eating challenge>
# 댓글 로드 실패 : [43/62] [유노-U_know] <통삼겹 1.5kg 다 먹으면 100만원?! 3분대 기록! 1위 달성숙달돼지 통삼겹격파챌린지!   korean mukbang show korean eating challenge>
# 댓글 로드 실패 : [44/62] [유노-U_know] <대패삼겹살 20인분 다 먹으면 30만원..!? Korean eating challenge>
# [35개 -->  34개]
# 댓글 변환 성공 : [45/62] [유노-U_know] <닭꾸버 숯불양념치킨 4마리! 우동사리에 치밥까지! spicy grilled chicken noodle>
# [85개 -->  82개]
# 댓글 변환 성공 : [46/62] [유노-U_know] <다 먹으면 10만원! 5인분 점보라멘 도전먹방!! Korean eating challenge korean mukbang show Jumbo Ramen!!>
# [35개 -->  34개]
# 댓글 변환 성공 : [47/62] [유노-U_know] <유노 첫 라이브! 버펠다겐 와플 50개 먹방!>
# 댓글 로드 실패 : [48/62] [유노-U_know] <1시간이 제한 시간인데  남은 시간이..? 홍대 대왕 파스타 도전! 다 먹으면 공짜에 커플 식사권!!? 착한 사장님 ㅠㅠ 도전먹방 korean eating challenge>
# [176개 -->  173개]
# 댓글 변환 성공 : [49/62] [유노-U_know] <오리불고기! 소고기무국 미역 줄기 등 집밥 먹방!! (With 12인분 밥솥 한 솥) korean mukbangshow korean food>
# 댓글 로드 실패 : [50/62] [유노-U_know] <유노는 햄최몇?? 불고기버거 20개 불닭게티 4개 탕수육2인분 후식 도넛4개 실내 먹방 korean eating challenge korean mukbang show>
# 댓글 로드 실패 : [51/62] [유노-U_know] <스테이크 1.5kg(10만원) 20분 안에 다 먹으면 공짜! 신촌 스떼이끄300!! 먹고 고기 하나 더?? 도전먹방 Korean eating challenge>
# [302개 -->  300개]
# 댓글 변환 성공 : [52/62] [유노-U_know] <대왕수제돈까스 5장 20분 안에 다 먹으면 공짜! 거기다 치즈카츠까지!! 울산 삼산동 쉐프1979! Korean mukbang show korean eating challenge>
# [268개 -->  266개]
# 댓글 변환 성공 : [53/62] [유노-U_know] <씨리얼 3봉(첵스초코 외 2종) 에그드랍 토스트5개 찹쌀도넛,찹쌀핫도그,찹쌀치즈볼korean mukbang show>
# [149개 -->  147개]
# 댓글 변환 성공 : [54/62] [유노-U_know] <[19.08.03-띵거먹방대회] 작년 먹방대회 영상입니다! Korean eating challenge>
# [473개 -->  466개]
# 댓글 변환 성공 : [55/62] [유노-U_know] <[중화가정] 괴물 짜장면 한 그릇 먹는데 3분 걸렸습니다 도전 먹방 korean eating challenge korean mukbang show>
# 댓글 로드 실패 : [56/62] [유노-U_know] <설빙에서 대왕 빙수를..? 대왕 몬스터 설빙 도전먹방!🥶🥶 제한 시간 15분!! 다 먹으면 공짜에 설빙 그릇!? mukbangshow korean eating challenge>
# [356개 -->  354개]
# 댓글 변환 성공 : [57/62] [유노-U_know] <BBQ 치킨 8마리(자메이카,황금올리브반반,순살크래커,허니갈릭스)치즈볼⚡️비비큐 누구나 먹방 콘테스트!⚡️Korean mukbang show #누구나먹방콘테스트 #누구나bbq>
# 댓글 로드 실패 : [58/62] [유노-U_know] <5kg 점보고기국수 6분컷..? 제주둘레국수! /Korean mukbang show/korean eating challenge>
# 댓글 로드 실패 : [59/62] [유노-U_know] <온정 돈까스 성공해서 2개월 무료권 받았습니다!-도전먹방 /korean mukbang /eating challenge>
# 댓글 로드 실패 : [60/62] [유노-U_know] <최초 성공! 노랑통닭 3마리 먹고 100만원 받았습니다-노랑통닭 순삭왕 이벤트! Korean mukbang show/eating challenge chicken>
# 댓글 로드 실패 : [61/62] [유노-U_know] <5.5kg 대왕닭칼국수 20분 안에 다 먹으면 상금 50만원! 현풍닭칼국수 도전먹방! Korean mukbang show/eating challenge noodle>
# [64개 -->  64개]
# 댓글 변환 성공 : [62/62] [유노-U_know] <첫 도전자! 노랑통닭 순살3마리 20분 안에 다 먹으면 상금 100만원! 노랑통닭-위대한 도전 순삭왕 이벤트! Koreanmukbangshow>
# [50개 -->  21개]
# 댓글 변환 성공 : [0/82] [캐피 KEPHI] <후참잘 양념반 후라이드반 치킨에 맥주 치즈볼 핫도그까지 먹방 FRIED CHICKEN & SPICY CHICKEN Eating sounds MUKBANG>
# 댓글 로드 실패 : [1/82] [캐피 KEPHI] <따끈한 겨울간식 호빵 먹방 GS25 삼립호빵 / KOREAN STEAMED BUNS Eating Sounds MUKBANG>
# [51개 -->  23개]
# 댓글 변환 성공 : [2/82] [캐피 KEPHI] <빌리엔젤 케이크 먹방 딸기크레이프, 체리치즈, 당근케이크, 쇼콜라봉봉 CAKE DESSERT Eating Sounds MUKBANG>
# [50개 -->  25개]
# 댓글 변환 성공 : [3/82] [캐피 KEPHI] <네네치킨 순살청양마요치킨 불타는 고추짜장 먹방 FRIED CHICKEN & BLACK BEAN NOODLES Eating Sounds MUKBANG>
# [55개 -->  28개]
# 댓글 변환 성공 : [4/82] [캐피 KEPHI] <찬바람 불면 생각나는 뜨끈한 바지락칼국수와 손만두 먹방(feat.열무비빔밥) KALGUKSU NOODLES & DUMPLINGS Eating Sounds MUKBANG>
# [53개 -->  30개]
# 댓글 변환 성공 : [5/82] [캐피 KEPHI] <삼첩분식 감자폭탄 치즈떡볶이 곱창구이 모듬튀김 먹방! CHEESE TTEOKBOKKI Eating Sounds MUKBANG>
# 댓글 로드 실패 : [6/82] [캐피 KEPHI] <커다란 피자 세 조각 먹방(feat.버팔로윙) / GIANT PIZZA & CHICKEN WINGS MUKBANG>
# [92개 -->  60개]
# 댓글 변환 성공 : [7/82] [캐피 KEPHI] <돼지고기 김치찌개와 스팸 계란말이 집밥먹방 KOREAN HOME FOOD Eating Sounds MUKBANG>
# [124개 -->  66개]
# 댓글 변환 성공 : [8/82] [캐피 KEPHI] <베이컨 까르보나라 파스타 그리고 치즈 돈까스 먹방 BACON CARBONARA PASTA & CHEESE PORK CUTLET eating sounds MUKBANG>
# [80개 -->  54개]
# 댓글 변환 성공 : [9/82] [캐피 KEPHI] <매콤한 알찜에 곤이전 날치알주먹밥 먹방! 마무리는 계란에 김넣고 비빔밥 BRAISED SEAFOOD & SEAFOOD PANCAKE Eating Sounds MUKBANG>
# [75개 -->  39개]
# 댓글 변환 성공 : [10/82] [캐피 KEPHI] <여러가지 생크림 와플과 꽈배기 먹방 WAFFLE & GGWABAEGI(Twisted Bread Stick) Eating Sounds MUKBANG>
# [51개 -->  23개]
# 댓글 변환 성공 : [11/82] [캐피 KEPHI] <GS25 X 편의점 샛별이 신메뉴(도시락, 김밥, 과일, 마카롱) 편의점먹방 KOREAN CONVENIENCE STORE FOOD Eating Sounds MUKBANG>
# [76개 -->  43개]
# 댓글 변환 성공 : [12/82] [캐피 KEPHI] <앵그리짜파구리 뿌링클 사이드메뉴(치즈볼, 핫도그, 감자튀김) 먹방 feat.통단무지 CHAPAGURI(Ram-don) & BBURINKLE Eating Sounds MUKBANG>
# [78개 -->  46개]
# 댓글 변환 성공 : [13/82] [캐피 KEPHI] <바삭한 해물파전에 막걸리먹방! 오삼불고기 충무김밥까지 SEAFOOD PANCAKE(Haemul-pajeon) & MINI GIMBAP Eating Sounds MUKBANG>
# [94개 -->  46개]
# 댓글 변환 성공 : [14/82] [캐피 KEPHI] <편의점 먹방! 쫄깃고소 고원정식 컵라면 핫바 김밥 샌드위치 마카롱등 인기조합 KOREAN CONVENIENCE STORE FOOD Eating Sounds MUKBANG>
# [78개 -->  47개]
# 댓글 변환 성공 : [15/82] [캐피 KEPHI] <명품으로치면💎 까르보불닭볶음면X푸라닭 고추마요 블랙알리오치킨(feat.블랙치즈케이크)먹방 CARBO FIRE NOODLES & CHICKEN Eating Sounds MUKBANG>
# [81개 -->  51개]
# 댓글 변환 성공 : [16/82] [캐피 KEPHI] <이열치열🔥 곱창전골 곱창 대창 우삼겹 가득넣어 먹방 마무리는 볶음밥! BEEF TRIPE HOT POT(Gopchang Jeongol) Eating Sounds MUKBANG>
# [56개 -->  30개]
# 댓글 변환 성공 : [17/82] [캐피 KEPHI] <흰쌀밥에 직접 만든 돼지갈비찜 알배추겉절이 먹방(feat.잡채) 한식 BRAISED PORK RIPS & KIMCHI Eating Sounds MUKBANG>
# [152개 -->  82개]
# 댓글 변환 성공 : [18/82] [캐피 KEPHI] <각종 빵 먹방🥐 크림단팥빵 고로케 샌드위치 크로와상 피자빵 맘모스빵 호두타르트 BREAD Eating Sounds MUKBANG dessert>
# 댓글 로드 실패 : [19/82] [캐피 KEPHI] <아는맛에 혼쭐남!! 피자 치킨 떡볶이 세트메뉴 먹방 / TTEOKBOKKI & PIZZA & FRIED CHICKEN Eating Sounds MUKBANG>
# [91개 -->  42개]
# 댓글 변환 성공 : [20/82] [캐피 KEPHI] <오므라이스에 BBQ자메이카통다리 햄치즈롱스틱 먹방 OMELET RICE & SPICY CHICKEN LEGS & CHEESE STICKS Eating Sounds MUKBANG>
# [49개 -->  31개]
# 댓글 변환 성공 : [21/82] [캐피 KEPHI] <시원한 냉모밀(판모밀)에 모듬초밥 돈까스 먹방 SOBA NOODLES & SUSHI & PORK CUTLET Eating Sounds MUKBANG>
# [41개 -->  24개]
# 댓글 변환 성공 : [22/82] [캐피 KEPHI] <곱창 먹방! 소곱창 대창 파김치볶음밥 까지 푸짐하게 볶아먹기 BEEF TRIPE(Gopchang) & FRIED RICE Eating Sounds MUKBANG>
# [66개 -->  40개]
# 댓글 변환 성공 : [23/82] [캐피 KEPHI] <2배 더 커진 대왕킬바사소세지 불닭볶음면 먹방 GIANT KIELBASA SAUSAGE & FIRE NOODLES Eating Sounds MUKBANG>
# [38개 -->  18개]
# 댓글 변환 성공 : [24/82] [캐피 KEPHI] <중국당면 넣은 마라떡볶이와 양갈비 숄더랙 먹방(feat.칭따오맥주) MALA TTEOKBOKKI & LAMB CHOPS Eating Sounds MUKBANG>
# [43개 -->  21개]
# 댓글 변환 성공 : [25/82] [캐피 KEPHI] <BBQ황금올리브 레드착착치킨 후추치킨과 치즈폭탄 명랑핫도그 먹방 SPICY FRIED CHICKEN & CHEESE CORN DOG MUKBANG>
# 댓글 로드 실패 : [26/82] [캐피 KEPHI] <새콤달콤 비빔칼국수! 농심 칼빔면에 삼겹살먹방 /  PORK BELLY (Samgyeopsal) & SPICY NOODLES MUKBANG>
# 댓글 로드 실패 : [27/82] [캐피 KEPHI] <직접만든 해물찜 먹방 (쭈꾸미, 전복, 새우, 키조개, 가리비, 백합) / BRAISED SPICY SEAFOOD (Haemuljjim) MUKBANG ヘムルチム>
# 댓글 로드 실패 : [28/82] [캐피 KEPHI] <밥도둑 연어장에 흰쌀밥 연어회 연어구이 연어먹방 / MARINATED SALMON & SALMON SASHIMI & SALMON STEAK Eating Sounds MUKBANG>
# 댓글 로드 실패 : [29/82] [캐피 KEPHI] <맘스터치 햄버거 먹방! 불싸이버거 언빌리버블버거 찜햇닭강정 / CHICKEN BURGER & NUGGETS & FRIES & SWEET CHICKEN MUKBANG>
# 댓글 로드 실패 : [30/82] [캐피 KEPHI] <쟁반짜장 차돌짬뽕에 바삭한 탕수육 까지 중식먹방! / BLACK BEAN NOODLES & JJAMBBONG & FRIED PORK Eating Sounds MUKBANG>
# 댓글 로드 실패 : [31/82] [캐피 KEPHI] <삼겹살 크림김치볶음밥 먹방! 계란말이 집밥 / PORK BELLY CREAM KIMCHI FRIED RICE Eating Sounds MUKBANG>
# 댓글 로드 실패 : [32/82] [캐피 KEPHI] <두찜 로제찜닭 새우튀김 치즈볼 먹방 ! / ROSÉ CHICKEN(JJIM DAK) & CHEESE BALLS & SHRIMP Eating Sounds MUKBANG>
# 댓글 로드 실패 : [33/82] [캐피 KEPHI] <굽네치킨 시카고피자 고추바사삭 순살 먹방 ! / CHEESE PIZZA & SPICY CHICKEN Eating Sounds MUKBANG>
# [108개 -->  59개]
# 댓글 변환 성공 : [34/82] [캐피 KEPHI] <대왕토스트 먹방 1000번 저어만든 계란과 통식빵으로 직접 만든 대왕 에그드랍🥪 GIANT EGG OMELETTE TOAST Eating Sounds MUKBANG 大王トースト>
# 댓글 로드 실패 : [35/82] [캐피 KEPHI] <직접 만든 제육김밥 참치마요김밥에 진짬뽕 라면 먹방 / RAMYEON & GIMBAP Eating Sounds MUKBANG ラーメン+キンパプ>
# 댓글 로드 실패 : [36/82] [캐피 KEPHI] <인도미 미고랭라면에 처갓집 슈프림양념치킨 먹방 / INDOMIE MI GORENG & SWEET FRIED CHICKEN Eating Sounds MUKBANG チキン+ラーメン>
# 댓글 로드 실패 : [37/82] [캐피 KEPHI] <차돌박이 한판에 치즈떡볶이 ! 신전떡볶이 신전김밥 차돌박이 먹방 / BEEF BRISKET TTEOKBOKKI & SPICY GIMBAP MUKBANG トッポッキ>
# 댓글 로드 실패 : [38/82] [캐피 KEPHI] <칼칼한 부대찌개에 버터밥 비벼먹어봤습니다 ! 부대찌개먹방 /  BUDAE JJIGAE(Sausage Stew) & BUTTER RICE MUKBANG プデチゲ>
# 댓글 로드 실패 : [39/82] [캐피 KEPHI] <뿌링대잔치 ! 뿌링클치킨 치즈볼 뿌링핫도그 소떡소떡 먹방 / BHC KOREAN FRIED CHICKEN & CHEESE BALL & CORN DOG MUKBANG プリンクル>
# 댓글 로드 실패 : [40/82] [캐피 KEPHI] <맵디매운 마라샹궈 !! 중국식 만두 냉면구이 먹방 / MALA XIANG GUO & DUMPLING & GRILLED COLD NOODLES eating sounds MUKBANG>
# 댓글 로드 실패 : [41/82] [캐피 KEPHI] <꾸덕꾸덕 크림파스타와 킬바사소세지 통스팸 먹방 ! 디저트는 마카롱❤ / CREAM PASTA & KIELBASA SAUSAGE & SPAM MUKBANG>
# 댓글 로드 실패 : [42/82] [캐피 KEPHI] <골뱅이소면에 돼지갈비 구이 먹방 / SPICY SEA SNAIL(WHELK) NOODLES & GRILLED PORK RIBS>
# 댓글 로드 실패 : [43/82] [캐피 KEPHI] <다크초코🍫 스모어딥 와플 매그넘 아이스크림 먹방 / S'MORES DIP & WAFFLE & CHOCOLATE ICE CREAM MUKBANG>
# 댓글 로드 실패 : [44/82] [캐피 KEPHI] <영화관먹방 메가박스📽 모든 스낵메뉴 먹어봤어요!! / KOREAN MOVIE SNACK MUKBANG 映画館の食べ物>
# 댓글 로드 실패 : [45/82] [캐피 KEPHI] <올바른조합🍗 대새치킨 후추치킨에 치즈떡볶이 먹방 / FRIED CHICKEN & CHEESE TTEOKBOKKI MUKBANG>
# 댓글 로드 실패 : [46/82] [캐피 KEPHI] <트러플오일 짜파게티 양념치킨 먹방 / TRUFFLE OIL BLACK BEAN NOODLES & SWEET FRIED CHICKEN MUKBANG チキン チャパゲティ>
# 댓글 로드 실패 : [47/82] [캐피 KEPHI] <연어 먹방!! 대왕연어초밥 연어국수 연어덮밥 / GIANT SALMON SUSHI & SALMON NOODLES MUKBANG サケモッパン>
# 댓글 로드 실패 : [48/82] [캐피 KEPHI] <묵은지 통삼겹 김치찜 집밥 먹방!! / SAMGYEOPSAL KIMCHI JJIM (STEAMED PORK KIMCHI) MUKBANG 豚肉、キムチ>
# 댓글 로드 실패 : [49/82] [캐피 KEPHI] <미트볼 함박스테이크에 까르보불닭볶음면 먹방 / CARBO FIRE NOODLES & MEATBALL & HAMBURG STEAK MUKBANG>
# 댓글 로드 실패 : [50/82] [캐피 KEPHI] <킹 블랙 타이거새우 부채살 스테이크 먹방!!  / KING TIGER SHRIMP & STEAK & STRETCHY CHEESE MUKBANG えび>
# 댓글 로드 실패 : [51/82] [캐피 KEPHI] <빙수야 동글이 만들어 먹어봤어요!! 떡볶이 우동까지 분식 먹방 / KOREAN FAMOUS ASSORTED FRIES & TTEOKBOKKI MUKBANG>
# 댓글 로드 실패 : [52/82] [캐피 KEPHI] <모짜렐라 불닭볶음면에 허니콤보 명랑핫도그 먹방 / FIRE NOODLES & HONEY FRIED CHICKEN & CHEESE CORNDOG MUKBANG>
# 댓글 로드 실패 : [53/82] [캐피 KEPHI] <매콤새콤 쫄면궁합❤ 꿀조합 먹방! 치즈돈까스 김밥 왕만두 새우튀김까지 / JJOLMYEON(SPICY NOODLES) & PORK CUTLET & DUMPLINGS MUKBANG>
# 댓글 로드 실패 : [54/82] [캐피 KEPHI] <통스팸 틈새라면 계란후라이에 바삭김 김치까지 집밥 먹방!! / KOREAN HOME FOOD MUKBANG>
# 댓글 로드 실패 : [55/82] [캐피 KEPHI] <반올림피자샵 반반피자 먹방 두판에 네가지맛 / PIZZA MUKBANG ASMR>
# 댓글 로드 실패 : [56/82] [캐피 KEPHI] <마카롱 뚱카롱 먹방 꼬끄후레이크 요거트에 말아먹기!! / MACARON &  FLAKE YOGURT MUKBANG>
# 댓글 로드 실패 : [57/82] [캐피 KEPHI] <편의점 음식 먹방!! (도시락,핫바,라면,김밥,지파이,햄버거) 편의점 먹방 / KOREAN CONVENIENCE STORE FOOD MUKBANG>
# 댓글 로드 실패 : [58/82] [캐피 KEPHI] <10가지 나물과반찬 듬뿍! 비빔밥에 소불고기 청국장까지 리얼사운드 먹방 / BIBIMBAP & BULGOGI MUKBANG>
# 댓글 로드 실패 : [59/82] [캐피 KEPHI] <파친조합! 차돌 짜파게티에 파김치 갓김치 까지 리얼사운드 / BLACK BEAN NOODLES & BEEF BRISKET MUKBANG>
# 댓글 로드 실패 : [60/82] [캐피 KEPHI] <BBQ황금올리브닭다리 뱀파이어치킨닭다리 먹방 직접만든 코울슬로 / KOREAN FRIED CHICKEN & SPICY CHICKEN & COLESLAW MUKBANG>
# 댓글 로드 실패 : [61/82] [캐피 KEPHI] <대왕 유부초밥 치즈돈까스 먹방 / GIANT FRIED TOFU RICE BALLS & CHEESE PORK CUTLET MUKBANG>
# 댓글 로드 실패 : [62/82] [캐피 KEPHI] <매운데 맛있다🌶실비김치 벌집 삼겹살과 흰쌀밥 먹방 / SILBI KIMCHI & PORK BELLY MUKBANG>
# 댓글 로드 실패 : [63/82] [캐피 KEPHI] <대왕 연어초밥🍣 연어 뱃살 리얼사운드 먹방 / GIANT SALMON SUSHI & SALMON BELLY MUKBANG>
# 댓글 로드 실패 : [64/82] [캐피 KEPHI] <마라탕 꿔바로우 리얼사운드 먹방 / CHINESE SPICY HOT POT(MALATANG) & FRIED PORK MUKBANG>
# 댓글 로드 실패 : [65/82] [캐피 KEPHI] <치밥 처갓집 슈프림양념치킨 고봉밥에 김치 / KOREAN SWEET CHICKEN & RICE MUKBANG>
# 댓글 로드 실패 : [66/82] [캐피 KEPHI] <SUB)초콜릿 디저트 먹방 아우어베이커리 더티초코 빨미까레 까눌레 / CHOCOLATE DESSERT MUKBANG>
# 댓글 로드 실패 : [67/82] [캐피 KEPHI] <SUB)불맛 야채곱창🔥먹방 참치마요주먹밥 계란찜 까지 / STIR-FRIED PORK TRIPE(GOBCHANG) MUKBANG>
# 댓글 로드 실패 : [68/82] [캐피 KEPHI] <SUB)진짜 '불닭'이네? 불닭볶음면 X 자메이카 통다리 먹방 / FIRE NOODLES & JAMAICAN CHICKEN LEGS MUKBANG>
# 댓글 로드 실패 : [69/82] [캐피 KEPHI] <SUB)달콤폭격 크리스마스 디저트 투썸플레이스 케이크 던킨도너츠 먹방 / CHRISTMAS CAKE DONUTS DESSERT MUKBANG>
# 댓글 로드 실패 : [70/82] [캐피 KEPHI] <SUB)수산시장🐟제철 방어 석화 그리고 도미 회먹방 / YELLOW TAIL OYSTER SEA BREAM MUKBANG>
# 댓글 로드 실패 : [71/82] [캐피 KEPHI] <SUB) 간단하고 든든한 아침식사!! 해쉬브라운 우유튀김 먹방 / CHEESY HASH BROWNS & TAIWAN FRIED MILK MUKBANG>
# 댓글 로드 실패 : [72/82] [캐피 KEPHI] <SUB) 나혼자 산다 족발 덮밥!! 카오카무 순살족발 먹방 / KHAO KHA MOO JOKBAL MUKBANG>
# 댓글 로드 실패 : [73/82] [캐피 KEPHI] <치떡 최강조합 교촌 허니콤보 X 엽떡 먹방 / HONEY FRIED CHICKEN & SPICY TTEOKBOKKI MUKBANG>
# 댓글 로드 실패 : [74/82] [캐피 KEPHI] <소박한 집밥 된장찌개 돼지불백 스팸 계란후라이 리얼사운드먹방 / KOREAN HOMEMADE FOOD MUKBANG>
# 댓글 로드 실패 : [75/82] [캐피 KEPHI] <김장김치에 수육 라면 참기름계란밥 리얼사운드먹방 / KIMCHI & PORK BELLY & RAMYEON & EGG RICE MUKBANG>
# 댓글 로드 실패 : [76/82] [캐피 KEPHI] <디디치킨 콤보 후라이드 매운불맛 까르보나라 리얼사운드먹방 / DD KOREAN FRIED CHICKEN FIRE SPICY & CARBONARA MUKBANG>
# 댓글 로드 실패 : [77/82] [캐피 KEPHI] <피자마루 페퍼로니 치즈폭탄피자 치킨텐더 리얼사운드먹방 / PEPPERONI CHEESE BOMB PIZZA & CHICKEN TENDER MUKBANG>
# 댓글 로드 실패 : [78/82] [캐피 KEPHI] <연어국수 연어먹방 까르보나라 간장 불닭소스 / SALMON NOODLES with CARBONARA & FIRE & SOY SAUCES>
# 댓글 로드 실패 : [79/82] [캐피 KEPHI] <명랑핫도그 명랑세트 통모짜 핫도그 리얼사운드 먹방 / CHEESY CORN DOG HOTDOG MUKBANG>
# 댓글 로드 실패 : [80/82] [캐피 KEPHI] <순대국밥 오소리감투 리얼사운드 먹방 / SUNDAEGUKBAP PIG INTESTINES MUKBANG>
# 댓글 로드 실패 : [81/82] [캐피 KEPHI] <뿌링클닭다리 뿌링클핫도그 신참떡볶이 리얼사운드 먹방 / BHC KOREAN FRIED CHICKEN HOTDOG & TTEOKBOKKI MUKBANG>
# 댓글 로드 실패 : [82/82] [캐피 KEPHI] <불닭볶음면X짜파게티 킬바사 소세지 리얼사운드 먹방 / FIRE NOODLE X BLACK BEAN NOODLE & SAUSAGES MUKBANG>
# ------------------------------------------------------------------
# 실행 종료
# [유노-U_know]채널의 댓글 정제 결과 , 변경 전 동영상 개수: 62 변경 후 동영상 개수 : 30
# [캐피 KEPHI]채널의 댓글 정제 결과 , 변경 전 동영상 개수: 82 변경 후 동영상 개수 : 23

# %%
# 폴더 내 모든 정보 수집
folder='크롤링폴더2'
channel_list=os.listdir(folder) #채널 이름 list
channel_path_list=glob(r'{}\*'.format(folder)) #채널 경로 list (위랑 같아야 함, 다르다면 수동 설정)
meta_path_list=[]
for i in range(len(channel_list)):
    meta_path_list.append(os.path.join(channel_path_list[i],
                                       '{}_meta.csv'.format(channel_list[i])))

# %%
pd.read_csv(os.path.join(channel_path_list[2],r'{}_meta_comment.csv'.format(channel_list[2])),)
# Out:
#      channel                                     title            author  \
# 0      부엉이TV   오늘날씨 완전겨울 보글보글 된장찌개와 코다리조림 입천장 까져도 즐거운맛               신준혁
# 1      부엉이TV   오늘날씨 완전겨울 보글보글 된장찌개와 코다리조림 입천장 까져도 즐거운맛  Hotel California
# 2      부엉이TV   오늘날씨 완전겨울 보글보글 된장찌개와 코다리조림 입천장 까져도 즐거운맛               박경옥
# 3      부엉이TV   오늘날씨 완전겨울 보글보글 된장찌개와 코다리조림 입천장 까져도 즐거운맛               김혜민
# 4      부엉이TV   오늘날씨 완전겨울 보글보글 된장찌개와 코다리조림 입천장 까져도 즐거운맛                ᄋᄋ
# ...      ...                                       ...               ...
# 9629   부엉이TV  제주에서 제일 잘 나가는 어묵집먹방.mukbang.eating show.          김빵이모1003
# 9630   부엉이TV  제주에서 제일 잘 나가는 어묵집먹방.mukbang.eating show.               서광일
# 9631   부엉이TV  제주에서 제일 잘 나가는 어묵집먹방.mukbang.eating show.                ᅳᅳ
# 9632   부엉이TV  제주에서 제일 잘 나가는 어묵집먹방.mukbang.eating show.                찌니
# 9633   부엉이TV  제주에서 제일 잘 나가는 어묵집먹방.mukbang.eating show.              새털구름
#
#                                                 comment  \
# 0     오늘도 맛있는 영상 잘봤습니다 영상과는 상관없는 댓글 올리는점 죄송하다는 말씀드리구...
# 1     보글보글 된장찌게 끓는소리가 온몸이 따듯해 지는듯 낼은 더 춥다네요~^^\n넘 맛있...
# 2     개인적으로 코다리 조림 무쟈게 좋아라 합니다. 음식두 잘하시나봐요 오늘도 맛나게 차...
# 3                               역시~~한국사람은된장찌게에흰쌀밥이죠~~😊😚
# 4                    오늘같이 추운 날씨에는 역시 따뜻한 국물을 먹어야 힘이나죠!!
# ...                                                 ...
# 9629                                            보기 좋아요~
# 9630  둘째 가라면 서러워 해도 됩니다 진국은 아래쪽 200와 400지점에 있는곳이 1.2...
# 9631  옆에서 아드님이 재미를 더해주는데 왜 자꾸 말리세요~ 영상은 찍어야 하는데 ㅋㅋ 아...
# 9632                          잘생긴 아드님 먹방이 훈훈 한데 ~~말리시네요
# 9633  너무 말씀이없어시네요 이영상은~\n보기만해도 그맛이 느껴지도록\n맛표현을 해주시면 ...
#
#                                         comment_refined  like
# 0     오늘도 맛있는 영상 잘봤습니다 영상과는 상관없는 댓글 올리는점 죄송하다는 말씀드리구...    12
# 1     보글보글 된장찌게 끓는소리가 온몸이 따듯해 지는듯 낼은 더 춥다네요넘 맛있게 드셔주...     7
# 2     개인적으로 코다리 조림 무쟈게 좋아라 합니다 음식두 잘하시나봐요 오늘도 맛나게 차분...     5
# 3                                     역시한국사람은된장찌게에흰쌀밥이죠     5
# 4                      오늘같이 추운 날씨에는 역시 따뜻한 국물을 먹어야 힘이나죠     7
# ...                                                 ...   ...
# 9629                                             보기 좋아요     1
# 9630  둘째 가라면 서러워 해도 됩니다 진국은 아래쪽 와 지점에 있는곳이 등 입니다 서부는...     0
# 9631  옆에서 아드님이 재미를 더해주는데 왜 자꾸 말리세요 영상은 찍어야 하는데 ㅋㅋ 아들...     2
# 9632                            잘생긴 아드님 먹방이 훈훈 한데 말리시네요     1
# 9633  너무 말씀이없어시네요 이영상은보기만해도 그맛이 느껴지도록맛표현을 해주시면 좋겠다는생...     1
#
# [9634 rows x 6 columns]

# %% [markdown]
# ### 댓글 예측 함수(개별모니터링용, 채널전체용)

# %%
from tensorflow.keras.models import load_model
loaded_model=load_model('best_model2.h5')
loaded_model2=load_model('best_model.h5')
#모델마다
# tokenizer, max_len 저장해야함 (30,65) (두개 나눠서 tokenizer 불러오는 함수를 만들자.)

# %%
loaded_model2=load_model('best_model.h5')

# %%
loaded_model.predict
# Out:
# <bound method Model.predict of <tensorflow.python.keras.engine.sequential.Sequential object at 0x0000023487CEF4C8>>

# %%
loaded_model.predict([[1,2,3,20]])
# Out:
# array([[0.21471]], dtype=float32)

# %%
#폴더 내 모든 출력을 위해서.
meta_comment_path_list=[]
for i in range(len(channel_list)):
    meta_comment_path_list.append(os.path.join(channel_path_list[i],
                                       '{}_meta_comment.csv'.format(channel_list[i])))

# %%
# 불용어 : 굉장히 중요하다. *** --> 데이터를 살핌으로써 진행할 수 있다. 
stopwords_shop=['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게']
stopwords_movie=['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']
stopwords=stopwords_movie

# %%
# tokenizer를 불러올 수는 없나 ? 
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# tokenizer fitting.
total_data=pd.read_csv('total_tokenized(0.4k).csv',converters={'document': eval})
X_train=total_data['document'].values
y_train=total_data['label'].values
tokenizer=Tokenizer() #keras의 전처리기
tokenizer.fit_on_texts(X_train)

# %%
X_train2=pd.read_csv('movie_tokenized(0.15k).csv',converters={'document': eval},header=None)

# %%
X_train2

# %%
X_train2=pd.read_csv('movie_tokenized(0.15k).csv',converters={'document': eval},header=None)
X_train2=X_train2[1].values
tokenizer2=Tokenizer() #keras의 전처리기
tokenizer2.fit_on_texts(X_train2)

# %%
print(tokenizer.word_index)

# %%
# 토큰화용, 빈도수가 적은 단어 제외.
vocab_size=for_tokenizer(tokenizer)
tokenizer=Tokenizer(vocab_size, oov_token='OOV')
tokeniOzer.fit_on_texts(X_train)
# Out:
# 단어 집합의 크기 : 30706
# 30706

# %%
vocab_size2=for_tokenizer(tokenizer2)
tokenizer2=Tokenizer(vocab_size2, oov_token='OOV')
tokenizer2.fit_on_texts(X_train2)
# Out:
# 단어 집합의 크기 : 19417

# %%
def for_tokenizer(tokenizer):
    threshold=3 # 이것들 구하는 이유를 확실히 하자 *** 빈도수 적은 건 빼는게 나음.

    total_cnt=len(tokenizer.word_index)
    rare_cnt=0 # threshold보다 작은 단어의 수  ?
    total_freq=0 # 전체 단어 빈도수의 합
    rare_freq=0 # 빈도수의 총 합.

    for key,value in tokenizer.word_counts.items(): #역시, 하나만 쓰여도 2개로 받아야 한다.
        total_freq+=value

        if(value<threshold):  #OrderedDict ? *** 
            rare_cnt+=1
            rare_freq+=value
    vocab_size=total_cnt-rare_cnt+2 # 0,1번의 패딩과 OOV토큰 고려
    print('단어 집합의 크기 :', vocab_size)
    return vocab_size

# %%
# 한 번만 실행하면 된다. 
max_len=65
# 불용어 : 굉장히 중요하다. *** --> 데이터를 살핌으로써 진행할 수 있다. 
stopwords_shop=['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯', '지', '임', '게']
stopwords_movie=['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
start=30
end=40
meta_comment=test_path
meta_comment=pd.read_csv(meta_comment) # meta_comment : 의 경로
X_train3=[]
okt=Okt() #형태소 분석기
original=meta_comment['comment'][start:end]
original
ro
for sentence in meta_comment['comment_refined'][start:end]: # 토큰화
    temp_X=okt.morphs(sentence,stem=True)
    temp_X=[word for word in temp_X if not word in stopwords_movie]
    temp_X=[word for word in temp_X if not word in stopwords_shop]
    X_train3.append(temp_X)
print(X_train3)
encoded3=tokenizer.texts_to_sequences(X_train)
print(encoded3)
pad_new=pad_sequences(encoded3,maxlen=max_len)
print(pad_new)
score_array=[]
for index,comment in enumerate(pad_new):
    score=float(loaded_model.predict(comment))
    if(score > 0.5):
        print(comment)
        print("--> ","{:.2f}% 확률로 긍정적인 댓글입니다.\n".format(score * 100))
        socre_array.append(score*100)
    else:
        print(comment)
        print("-->","{:.2f}% 확률로 부정적인 댓글입니다.\n".format((1 - score) * 100))
        score_array.append(score*100)
original["sentiment_score"]=score_array

# %%
test_path='유노-U_know_meta_comment.csv'

# %%
sol
# Out:
#                                               comment        GRU       LSTM
# 30                                        진짜 매운가보다 ㅠㅠ  58.147854  36.446673
# 31                                    방금푸파보고 왔습니다 레게년  37.591982  35.978538
# 32  ㅋㅋㅋㅋㅋ야이씨 이건 경품줘라 진짜 찐텐반응 ㄷ ㄷ....보면서 재밌긴한데 정말 고...  44.564611  49.602595
# 33                                 원칩 먹으면 큰일나겠다ㅋㅋㅋㅋㅋㅋ   5.131057  36.788368
# 34                           에고 내 속이 아파라 ㅠㅠ 수고하셨어용 ㅠㅠ  10.676727  36.788368
# 35                        나중에 꼭 세계대회 챔피언 되셧으면 좋겟다요 ㅜㅜ  90.991348  38.801748
# 36     아이구   \n이번 한번으로  이제 이런고통 스러운건 하지 않기로ㅜ\n성공 축하ㅜㅜ  66.523647  41.538233
# 37                                      손가락....개쩔어...  82.659209  36.446673
# 38  ㅜㅜ 늘 열심히 하는거 같아서 좋은데 건강에 무리만 안갔으면 하는 마음 ㅜ....다...  95.332766  50.369990
# 39                                         맴 아퍼 죽것네 ㅠ  70.766234  35.581738
# 40                               업로드 기다렸는데ㅠㅠ 우시다니..ㅠㅠ  66.022557  35.508558
# 41                      음료 푸파 너무 웃겨요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ  75.134766  35.508558
# 42                                아이고...  고생 하셨어요. ㅠㅜ   4.488897  36.446673
# 43                                         우는거 넘 귀욥당ㅎ  98.539197  35.978538
# 44                           하필 저 타이밍에 배터리교환...ㅜ 아쉽네요   1.516175  36.788368
# 45                                아 ㅜㅜ저느낌 알꺼 같은데.....  29.215765  35.978538
# 46                    저걸 먹으라고 만든것인가 죽으라고 만든것인가? 무서워..  14.992142  35.978538
# 47                                           헝ㅇ헝 맘아파요  79.117388  35.508558
# 48  헐 머리 그레이 ㅠㅠㅠ 완전 좋아요 ㅠㅠㅠㅠㅠㅠ 진짜 짱이야 ♥️ 아 우는거 너무 ...  98.957610  50.208956
# 49                            등갈비 영상 있었는데, 왜 없어졌어요?ㅡㅠ  12.671512  36.788368
# 50                               고릴라 느낌 난다 잘먹게 생깄~~🤣🤣  64.467806  35.508558
# 51  하지마하지마 이런거하지마 ㅠㅠ\n\n내가말했잔아여 가만히있어도 얼굴이다했다고 ㅠㅠ굳...  21.701664  44.028670
# 52                                   옛날부터 구독했는데 대단합니다  87.997800  35.581738
# 53  맵찔이 유노님  한테는  지옥행 인데 ㅠㅠ\n넘넘고생해써요~   물도 못머꾸 참느냐...   8.436009  50.208956
# 54                             기.. 기요미 ㅠㅅ ㅠ♡ 맵찔이 ㄹㅇㅋㅋ  61.412531  37.771323
# 55  맛을 괜히 느껴 버렷어ㅋ\n인생살면서 4분44초가 이리 길엇던가\n느낌이 새로웟겟네...  89.666665  48.780748
# 56                                아 보면서 넘 웃었네요 ㅎㅎㅎ 죄송  20.642132  35.978538
# 57  입술 퉁퉁 부은것봐 .. ㄷㄷ 무슨맛인지 궁금했는데 유체이탈 경험하는 맛이군요 ;;...  22.424597  50.369990
# 58              저도맵찔이인데 보는것도매워서\n정신없이 물먹다가\n옷에물쏬았음ㅋㅋㅋ  74.628186  40.706700
# 59               아우  절대 사먹지 말아야겠어요!!  진짜 속상해서 못보겠네 ㅠㅠ   2.384406  38.801748
# 60                           유노님 짜장 기네스 도전 한번 해보심이...  33.156025  37.771323
# 61                           우와~맵겠다ㅠ\n유노님의다른모습\n귀엽네ㅋㅋ  91.631007  38.801748
# 62                             철구 푸파대결 보고왔음ㅎㅎ기여워서 구독함  95.388103  39.794469
# 63                                         유노님 훌룡햄!!!  62.875223  36.446673
# 64                         유노님  보는것만으로도 대게 매울것 같아요~최고  97.685182  36.788368
# 65                              나는 왜!!?이라면이 안매운걸까?'ㅜㅜ  38.909388  36.788368
# 66                                       도둑가시 나무젖가락 ㅋ  47.910056  35.978538
# 67                                            🤣🤣🤣🤣🤣아포  24.483058  40.724164
# 68  걱정됩니다ᆢ이젠하지마세요 ㅜㅜ 빨리 우유나 맨밥드시지ᆢ화이팅하시고요ᆢ  건강챙기면서...  97.218090  43.135080
# 69               애쓰시는 모습에 응원은 하지만\n걱정이네요 ~먹기전에 우유라도^^  81.107950  39.794469
# 70                                  근데  왜 웃기지?  ㅋ 미안요  41.618586  35.978538
# 71  먹을때도 힘들지만 담날이 더 괴로우셨을듯 한데 게안았죠?\n불닭볶음면도 넘 매워서 ...  38.857004  50.208956
# 72  철구 동영상보고 팬됬어여 ㅎㅎ 너무 착하시고 잘생기시고 잘웃으셔서 보기 좋으세여 !...  98.095453  41.538233
# 73                             유노는 하는거에 비해서 구독자가 작네..  32.542461  35.508558
# 74                         아고  왜 그랬어\n앞으로 매운거 멋지마셈 ㅋㅋ  17.812294  37.771323
# 75        대단해요!!!!! 보는내내 제가더 맵더라구용\nㅠ.ㅠ속 괜찮으실런지요 걱정되요  53.675705  43.135080
# 76  무조건 첼린지 라고 다 하는것 보다는 잘 할수 있는것이나 맛있게 먹을수 있는것이나 ...  92.601383  50.369990
# 77  근데\n매운맛 가시게 하는 방법은\n입 약간 연 상태에서 계속\n깊게 호흡하면 되는...  11.844808  49.754626
# 78                                              옥동~자야  29.391083  38.381600
# 79                          아! 보기만 해도 무섭네요. 안먹는 걸로 ㅎㅎ  21.977004  39.794469
# 80                                              ㅋㅋㅋㅋㅋ  64.851153  40.724164
# 81        헐. . 유노님 속아프시겠어요!!! ㅜㅜ. . . 불마왕 볶음면 무섭네요 ㅜㅜ  11.042741  41.538233
# 82                                최군방송에서 12초컷은 어케나온거지   8.483309  37.771323
# 83  매운거먹고 멘탈 탈탈 털리네요ㅜ\n요즘 매운거 마니 드시는데 속아파요  건강 조심하세요~  42.277515  43.135080
# 84                  전에 푸파 나갔을 땐 속 괜찮았나요?? 건강관리 잘 하세요ㅠ  88.903391  39.794469
# 85                                                 ㅠㅜ  52.727968  40.724164
# 86  아이고,ㅋㅋ맵찔이 유노님............이.... 어쩌자곸ㅋㅋ이런 챌린지를.....  39.880481  43.135080
# 87  엄청 빨리 많이 잘드신다......\n\n\n\n그래도 꼭꼭 잘씹어드세용ㅜㅜ위에 엄...  52.364028  42.326778
# 88  님 저 드디어 님말씀에\n맵기 궁금증 풀려서 한개 사서 먹어봤는데\n틈새라면 맵기정...  30.234253  49.754626
# 89         유노님 맵찔이시잖아요ㅜ 아우~ 우째ㅜㅠ아 근데 왜케 귀여워요 ~~~미치긋다ㅋ  93.581057  45.048833
# 90             먹는거 왤케 귀여우시지 ㅜㅜㅜㅜ팔은 어쩌다 다치신지 아시는분 있나요?  87.202489  40.706700
# 91  저도  엄청 맵찔인데\n저거  못먹어요\n어지럽고  귀아프고 눈물콧물 토할것같고\n...  74.373829  50.763983
# 92                                        오잉?? 12초엿는데  49.681404  38.381600
# 93                              ㅎ 맵긴 매운가  부다요\n화이팅~^^  91.873741  35.978538
# 94  영상 올릴때 일반인이 바로 공감가능한거 좀 올려주세요..많이 먹는것도 중요하지만.....  86.414158  49.754626
# 95  매운거 좋아하는데..맛이없어 가격도 되도않게 비싸고 틈새1.5배 난 차라리 .틈새가...   0.656044  44.028670
# 96                                               ㅎㅎㅡㅡ  59.523147  40.724164
# 97                               이런건  좀  안했으면요,,,  ㅠㅠ   7.959884  36.446673
# 98  그정도로 안매운데 더 차원이 다른 디진다돈까스나 다른 매운거 먹은거 보면 이거 오버...   2.289629  49.754626
# 99                                      그리고 저초등1학년이에요  84.434152  35.508558

# %%
sol
# Out:
#                                                comment       LSTM        GRU
# 800  아니.. 양을 거의 두배로 늘리고 시간을 줄이는건.. 이건 도전메뉴가 아니고.. 유...  49.754626   0.564322
# 801        많이  먹는거 보다  맛있게  믝는 컨셉이 더 좋다 목소리도 좋고 말도 잘해서  40.706700  92.167813
# 802                                              흥하시길!  40.724164  86.054492
# 803                         그냥 조용히 먹는 모습도 좋은데...... 너무  35.978538  84.207612
# 804        노력하는 남자  유노  멋진남자 유노  힘내라~~힘 무조건  전진\n~~~~~  39.794469  92.630523
# 805                                   🏆🥇최고예요  유노~👋🙆‍♀️  36.446673  98.083729
# 806                                      진짜 잘먹는다 대리만족을  35.581738  96.878970
# 807  아프리카tv 어제  마피아 떡볶이 보고  왔어요 구독  앞으로 홧팅입니다\n햄식이 ...  50.208956  10.833231
# 808                                     앗ㅡ일빠넹ㅡ응원해요 유노씨  36.788368  89.370263
# 809                                        왤케 많이 먹어 윤호  35.581738  38.357618
# 810                                 처음 보는데 목소리가 너무 좋아요  35.508558  98.049808
# 811               새벽에 이 영상을보다니.... 떡볶이가 너무 먹고 싶어졌다....  36.788368  92.389345
# 812                            아구 맛 표현 명랑하네요^^ 꿀성대 꿀조합  37.771323  90.427458
# 813                                          맛깔나게먹는다진짜  36.446673  83.627814
# 814        그동안 돈내고 못먹은거 유노님이 대신 먹었다고 생각할게요~ 돈 안아까워~ ㅎㅎ  43.135080  60.828191
# 815                              마지막 리조또 같아서 더 맛있겠다 ㅠㅠ  35.978538  95.231771
# 816     잘 먹는 사람 보면 왜이렇게 흐믓하지 ㅋㅋ 전 식탐은 많은데 입이 짧아요 하.. 😔  42.326778  34.579247
# 817             유노 화이팅\n몸 건강하게 식사하세요\n장마 곧 시작이라니 조심하세요  39.794469  78.531927
# 818                      헐 저기 두끼 저희 동네 두끼에요ㅜㅜㅜ 대박대박...  41.538233  73.208231
# 819     진짜 어떻게 하면 사람들이 좋아할지를 딱 아는 듯해요‼️ 영상 너무 재미있네욤 ㅎㅎ  40.706700  99.375629
# 820               이 영상 엄청 기다리고 있었다구요 후 오늘도 배불리 보고가용>_<  39.794469  44.821882
# 821  이미지랑 스타일이랑 호감도랑 등등이 남성형 쯔양 느낌...뜰것 같은데...여튼 좋아요~!  44.028670  82.797194
# 822  유노님 제목이...😲\n항상 열심히 하시고 애 많이 쓰시는데 저번영상에 어쩌네 저쩌...  49.754626  98.544550
# 823                                     재료들 똑똑똑! 01:12  36.446673  29.123449
# 824                                           리조또맛있겠당ㅜ  36.446673  88.492537
# 825                        먹방하는 비제이들이 남기는건 없어요..다 드셔주길  36.788368  35.568738
# 826  영상 몇개 봤는데 \n잘 드시고 \n목소리가 진짜 좋다 \n아... 두끼 가고 싶네...  43.135080  98.438650
# 827  와~~다이어트 중인데 떡볶이 영상 보니깐 미치겠네요 ㅎㅎ 어째 떡볶이보다 밥을 더 ...  49.754626  77.812827
# 828                 맛나보여요..귀욤 귀욤..구독자  10만 100만 가즈아~~~  42.326778  34.366125
# 829              다이어트줄일라더더더먹고싶네요 오늘도 맛나게 드셔주셔서 감사해요~~~  39.794469  97.932029
# 830                           다른분에 비해 구독자수가 빨리 늘지 않네요.  37.771323  26.980394
# 831  오늘 아프리카tv잘봤습니다.\n근데 가장 최근영상이 두끼 떡뽂이네요ㅋㅋㅋ\n마피아떡...  47.397187  93.670011
# 832                              유노님 무한리필오면 한명으로 계산해오?  36.788368  22.632992
# 833  이제 댓글도 50 넘는드아~~~구독자도늘고~~~\n유노 항상 화이팅이에요~~^^♡\...  44.028670  69.291699
# 834  어제 영상 올라오는거 알고 기다렸는데 너무 피곤해서 오늘에서야 시청\n떡볶이 좋아해...  49.754626  94.329804
# 835  두끼 떡볶이집 일부러 더 안갔는데..유노님  먹방에 함 가봐야겠어요~^^무한리필에 ...  48.572451  89.043736
# 836                                          맛있어  보이네요  38.381600  97.400206
# 837                  맛있게 드셔 주셔서 감사해용! 오늘도 대리만족하구 갑니다❤️  37.771323  98.470080
# 838                              너~무 잘드시고 귀요미세용~올아들같네옹  37.771323  93.846655
# 839  울 아들 딸이 먹방 유투버 보는거 왜 보나 했는데.\n유노님 보다보니 자꾸 보게 되...  50.208956  88.517743
# 840                                     아~   떡볶이 맛있겠다.  36.446673  86.671293
# 841  떡볶이도 좋지만 우삼겹 안타까워용!! 근데 그냥 떡볶이 1인분에 튀김+순대 갖춰 먹...  50.706095  75.277996
# 842                          다이어트중인데 항상대리만족 감사해요 ㅎㅎㅎ !  37.771323  99.182856
# 843  허ㅜㅜ 드셔달라구 그랬는데 영상 올라와서 넘 기뻤어용 .. 우삼겹 아쉬워... 참기...  49.455029  99.232048
# 844      떡볶이는 언제 머거도 맛나요~~ㅎ 영상 잘 보고 갑니다 ~응원합니다 ~ 감사합니다  42.326778  98.803818
# 845  아~~ 주말에 두끼 가야겠어요~~♡\n예의바른 유노님~\n오늘도 맛있게 잘 드시네요...  49.455029  98.477376
# 846                      헉 저 덮밥? 에 데리야끼소스 안 넣으셨어요..ㅠㅠㅠ  38.801748  12.839136
# 847  나 유노 천따리  히밥 백따리 때  같은날 같이 구독햇는데  히밥은 지금 20만 코...  50.208956  21.458021
# 848                                     히밥님과한번같이콜라보합시다  35.978538  84.141707
# 849  안녕하세요~~~ 안동 신세계찜닭에서 대왕찜닭 푸파 이벤트 진행중입니다 ^^\n찜닭2...  49.754626  25.162792
# 850                                       오뎅 언제 먹었지..?  36.446673  38.741702
# 851  제목이 살짝 아쉽네요.\n오늘도 잘 드셨네요!\n오늘은 표정이 조금ㅜ 기분이 안좋아...  49.754626  98.879731
# 852                                      으이그 이러이 안되네~~  35.581738   4.596749
# 853  저는마감한시간전에와서 배터지는줄 흑당치즈볼이 젤맛잇어요 마감시간 10신데 9시40분...  49.754626  83.812511
# 854                                               2빠다!  40.724164  25.583842
# 855  두끼좋아하는데 시간제한때문에  갈때마다 양껏 못먹어서 너무 아쉬워요.  끓이는 시간...  50.706095   3.863153
# 856  항상 응원합니다 ᆢ건강챙기고 \n구독이 많이 늘기를 기원합니다ᆢ뒤에서 응원하니까 힘...  44.028670  99.449360
# 857                  말하는걸 반만 줄이면 좋을것같네요.\n먹다가 흐름 끊기네요.  38.801748   5.769578
# 858  초반에 유투브라이브킬때 매번챙겨보고\n유노님 회사들어간뒤로도 영상꾸준히 챙겨보고잇는...  49.754626  68.802351
# 859  입안에서 개한마리가 왜뛰어요.,..\n그냥 말많이안하시구 먹방하시는게...ㅠㅠ\n기...  47.397187   1.916260
# 860                                              식상하네요  40.724164   1.356548
# 861  안녕하세요 여러분! 유노입니다!\n오늘은! 어떤 음식을 가지고 왔냐면요!\n바로 1...  49.754626  85.766029
# 862                                          손점 가만히...  38.381600  49.021477
# 863                                    🏆🥇최고예요 유노~👋🙆‍♀️  36.446673  98.083729
# 864                     아니그래서 지금 총 몇인분인지가 중요한건데\n그게빠졌네  39.794469   3.775972
# 865  진짜 넘 귀여워서 보면서 몇번을 웃었나 모르궸눼요!!😍 담부턴 빨간음식 먹을땐 어두...  47.397187  95.606363
# 866                       이열치열이다! 날 더우니 뜨끈~한 국밥종류 가즈아!  38.801748  58.334780
# 867                   유노님 날씨 더운데 좋은 영상 찍으시느라 수고 많으세요~~  38.801748  59.760332
# 868                               배달을 시켜버리게 만드는 유노님 ㅠㅠ  36.788368   4.072139
# 869                                        구여우셔......😊  36.446673  88.174224
# 870  국물 튀었을땐 절대!!!  물 묻히지 말고 ****바로 퐁퐁 ****묻혀서 비빈다음...  49.602595  15.961796
# 871                               밀떡이 맛난데 ㅎㅎㅎ 밀떡이었을거에요  36.788368  72.074747
# 872                        대리만족 느끼는중 \n항상 맛나게 먹어서 너무좋음  39.794469  99.326819
# 873    오늘도 맛난거 드셨네요!! 항상 영상 잘 챙겨보고 있어용 🥰 오늘 하루도 좋은 하루~  44.028670  95.800579
# 874          외국에서 와서 젖가락질을 잘 몬하는것 같지요? 힘내요 ㅋ 연습하믄 되요~♡  43.135080  45.057690
# 875  분식메뉴 가성비 좋네요. 😎🤓😆😋\n양천구면 넘 멀어요.\n산더미 탕수육 대박이에요...  50.208956  82.198477
# 876                     오늘도 맛있게 드시는 먹방 잘보고 갑니다! 응원할꼐요!  36.788368  98.785424
# 877  오!! 저 양천구 살 때 가끔 가던 곳이네요. 엄청 맛집은 아녀도 가격 대비 좋죠....  49.602595  91.478336
# 878  초하~~~\n 가성비좋고 맛있는곳 너므좋아^^\n부천에 사는데 이쪽 리뷰할만한곳 읎나?ㅋ  46.190676  97.439420
# 879                          2마넌치 치고는 많넹 ㅎ\n순대보다 싸네요 ㅎ  37.771323  90.887481
# 880  유노님~ 저는 탕수육이 아예  소스에 저려져서 눅눅한걸 좋아하는데~ 모두들 제 입맛...  49.754626  86.028731
# 881                                 양미라 조카님 아니심? 왜케닮았노  36.788368  78.925514
# 882  담에서울가면 사먹으러가야겠어요 가성비좋네요 옷에묻은 양념은 주방세제 트리오 옷에뭍혀...  48.486945  95.295924
# 883                                  뻘건거 묻자마자 퐁퐁을 발라야죠  35.978538  55.704808
# 884                        어린 나이에 열심히 도전하는윤호 항상응원 할께요~  36.788368  97.355402
# 885                          새로운곳들 많이많이 소개시켜주세요~~홧팅!!!  36.788368  95.548046
# 886                                유노님 왜 오늘은 안뛰세여!!ㅎㅎㅎ  36.788368  49.595487
# 887                                 솔직히 손동작이 좀 어설퍼요 ㅠㅠ  35.581738   4.431352
# 888  얘기할때 저 손 움직임 ㅜ\n너--무 산만하고 어색하고 그래요...\n조금 고민하셔...  50.706095   3.129721
# 889  코로나가 서울지역에 지금 꾸준히 확진자가 나오는걸로 아는데.. 영상을 찍을때 잠시 ...  49.754626  47.323421
# 890  안녕하세요 여러분! 유노입니당!\n오늘은 바로바로 무한리필의 원조격인!\n엉터리 생...  49.754626  92.863327
# 891                    울산의 청년 윤호군~\n울산에서 응원합니다~\n홧팅♡♡♡  37.771323  92.501926
# 892  이 분 진짜 맛있게 많이 깔끔하게 잘 드시는데 ㅠㅠ 얼른 더더욱 뜨셨으면 좋겠습니다...  50.208956  99.378842
# 893  잘 봤습니다. 근데 주실 수 있을까요? 라는 말보다 주세요가 맞는 표현 일듯. 더더...  47.397187  99.313962
# 894                                   유노님도  얼렁 떡상해야델텐데  37.771323  56.675100
# 895  착하고 겸손한 왕자님.🤓😎😆😲\n늘 열심히 하셔서 보기 좋아요.\n구독자 얘기가 매...  49.754626  98.738211
# 896                                    🏆🥇최고예요 유노~👋🙆‍♀️  36.446673  98.083729
# 897  유노님 덕분에 몇달만에 삼겹살을\n(눈으로) 먹었네요. 혹시 수령처가\n바뀌지 않았...  50.208956  32.034785
# 898                     유노님이랑 밥먹음 나 없던 입맛이 살아날거 같아 최고!  40.706700  98.148084
# 899                       무한리필갈때 유노님 위장 빌릴수있으면 꿀이겠다...  37.771323  16.761410

# %%
val.columns=['comment','LSTM','GRU']

# %%
val['ve2']=val2['sentiment_score'].values

# %%
val2=sentiment_predict(test_path,800,900)
# Out:
# ['아니.. 양을 거의 두배로 늘리고 시간을 줄이는건.. 이건 도전메뉴가 아니고.. 유튜버들 놀리는거 같아서 화나네요..상해기님꺼 유노님꺼 히밥님꺼 영상 다 봤는데.. 솔직히 유노님 상해기님 못드실 정도면 일반인은 도전 엄두도 못낼 양..']
# --> 99.44% 확률로 부정적인 댓글입니다.
#
# ['많이  먹는거 보다  맛있게  믝는 컨셉이 더 좋다 목소리도 좋고 말도 잘해서']
# -->  92.17% 확률로 긍정적인 댓글입니다.
#
# ['흥하시길!']
# -->  86.05% 확률로 긍정적인 댓글입니다.
#
# ['그냥 조용히 먹는 모습도 좋은데...... 너무']
# -->  84.21% 확률로 긍정적인 댓글입니다.
#
# ['노력하는 남자  유노  멋진남자 유노  힘내라~~힘 무조건  전진\n~~~~~']
# -->  92.63% 확률로 긍정적인 댓글입니다.
#
# ['🏆🥇최고예요  유노~👋🙆\u200d♀️']
# -->  98.08% 확률로 긍정적인 댓글입니다.
#
# ['진짜 잘먹는다 대리만족을']
# -->  96.88% 확률로 긍정적인 댓글입니다.
#
# ['아프리카tv 어제  마피아 떡볶이 보고  왔어요 구독  앞으로 홧팅입니다\n햄식이 같은  방송하시면 절대 안됨 갠방 전혀 안하고 모기짖만 하면 절대안됨']
# --> 89.17% 확률로 부정적인 댓글입니다.
#
# ['앗ㅡ일빠넹ㅡ응원해요 유노씨']
# -->  89.37% 확률로 긍정적인 댓글입니다.
#
# ['왤케 많이 먹어 윤호']
# --> 61.64% 확률로 부정적인 댓글입니다.
#
# ['처음 보는데 목소리가 너무 좋아요']
# -->  98.05% 확률로 긍정적인 댓글입니다.
#
# ['새벽에 이 영상을보다니.... 떡볶이가 너무 먹고 싶어졌다....']
# -->  92.39% 확률로 긍정적인 댓글입니다.
#
# ['아구 맛 표현 명랑하네요^^ 꿀성대 꿀조합']
# -->  90.43% 확률로 긍정적인 댓글입니다.
#
# ['맛깔나게먹는다진짜']
# -->  83.63% 확률로 긍정적인 댓글입니다.
#
# ['그동안 돈내고 못먹은거 유노님이 대신 먹었다고 생각할게요~ 돈 안아까워~ ㅎㅎ']
# -->  60.83% 확률로 긍정적인 댓글입니다.
#
# ['마지막 리조또 같아서 더 맛있겠다 ㅠㅠ']
# -->  95.23% 확률로 긍정적인 댓글입니다.
#
# ['잘 먹는 사람 보면 왜이렇게 흐믓하지 ㅋㅋ 전 식탐은 많은데 입이 짧아요 하.. 😔']
# --> 65.42% 확률로 부정적인 댓글입니다.
#
# ['유노 화이팅\n몸 건강하게 식사하세요\n장마 곧 시작이라니 조심하세요']
# -->  78.53% 확률로 긍정적인 댓글입니다.
#
# ['헐 저기 두끼 저희 동네 두끼에요ㅜㅜㅜ 대박대박...']
# -->  73.21% 확률로 긍정적인 댓글입니다.
#
# ['진짜 어떻게 하면 사람들이 좋아할지를 딱 아는 듯해요‼️ 영상 너무 재미있네욤 ㅎㅎ']
# -->  99.38% 확률로 긍정적인 댓글입니다.
#
# ['이 영상 엄청 기다리고 있었다구요 후 오늘도 배불리 보고가용>_<']
# --> 55.18% 확률로 부정적인 댓글입니다.
#
# ['이미지랑 스타일이랑 호감도랑 등등이 남성형 쯔양 느낌...뜰것 같은데...여튼 좋아요~!']
# -->  82.80% 확률로 긍정적인 댓글입니다.
#
# ['유노님 제목이...😲\n항상 열심히 하시고 애 많이 쓰시는데 저번영상에 어쩌네 저쩌네가 넘 많더라구요. 유노님 스타일대로 하고픈대로 잘 하셨으면 좋겠어요.\n두끼 다녀오셨네요. 작년 여름 미금역점에서 쇼핑하다 먹어봤는데 엄청 맛있었어요. 왕자님 드시니 가고 싶네..\n개인적으로 쌀떡파라서 쌀떡을 더 좋아해요.🤓😎😄😊😆\n날 더운데 더위 조심해요.😋🍦🍨🍧\n그리고 캡이에요.🍀🍀🍀👍']
# -->  98.54% 확률로 긍정적인 댓글입니다.
#
# ['재료들 똑똑똑! 01:12']
# --> 70.88% 확률로 부정적인 댓글입니다.
#
# ['리조또맛있겠당ㅜ']
# -->  88.49% 확률로 긍정적인 댓글입니다.
#
# ['먹방하는 비제이들이 남기는건 없어요..다 드셔주길']
# --> 64.43% 확률로 부정적인 댓글입니다.
#
# ['영상 몇개 봤는데 \n잘 드시고 \n목소리가 진짜 좋다 \n아... 두끼 가고 싶네 \n응원합니다']
# -->  98.44% 확률로 긍정적인 댓글입니다.
#
# ['와~~다이어트 중인데 떡볶이 영상 보니깐 미치겠네요 ㅎㅎ 어째 떡볶이보다 밥을 더 드신것같은 느낌이 ㅋㅋ 유노님~~오늘도 수고하셨습니다~^^참 아프리도 영상은 유툽에 업로드 안하시나요?']
# -->  77.81% 확률로 긍정적인 댓글입니다.
#
# ['맛나보여요..귀욤 귀욤..구독자  10만 100만 가즈아~~~']
# --> 65.63% 확률로 부정적인 댓글입니다.
#
# ['다이어트줄일라더더더먹고싶네요 오늘도 맛나게 드셔주셔서 감사해요~~~']
# -->  97.93% 확률로 긍정적인 댓글입니다.
#
# ['다른분에 비해 구독자수가 빨리 늘지 않네요.']
# --> 73.02% 확률로 부정적인 댓글입니다.
#
# ['오늘 아프리카tv잘봤습니다.\n근데 가장 최근영상이 두끼 떡뽂이네요ㅋㅋㅋ\n마피아떡뽁이 vs 두끼떡뽁이\n먹방 잘하세요']
# -->  93.67% 확률로 긍정적인 댓글입니다.
#
# ['유노님 무한리필오면 한명으로 계산해오?']
# --> 77.37% 확률로 부정적인 댓글입니다.
#
# ['이제 댓글도 50 넘는드아~~~구독자도늘고~~~\n유노 항상 화이팅이에요~~^^♡\n100만가즈아~~']
# -->  69.29% 확률로 긍정적인 댓글입니다.
#
# ['어제 영상 올라오는거 알고 기다렸는데 너무 피곤해서 오늘에서야 시청\n떡볶이 좋아해서 두끼가면 엄청 먹고와야지 하는데도 우리 네식구 가면 4명이서 유노님 양만큼도 못 먹어요ㅎ\n우삼겹이 없어서 아쉬우셨겠지만\n전 덕분에 대리만족 했어요']
# -->  94.33% 확률로 긍정적인 댓글입니다.
#
# ['두끼 떡볶이집 일부러 더 안갔는데..유노님  먹방에 함 가봐야겠어요~^^무한리필에 약간에..좀 그랬는데..좋은 먹방 감사합니다^^']
# -->  89.04% 확률로 긍정적인 댓글입니다.
#
# ['맛있어  보이네요']
# -->  97.40% 확률로 긍정적인 댓글입니다.
#
# ['맛있게 드셔 주셔서 감사해용! 오늘도 대리만족하구 갑니다❤️']
# -->  98.47% 확률로 긍정적인 댓글입니다.
#
# ['너~무 잘드시고 귀요미세용~올아들같네옹']
# -->  93.85% 확률로 긍정적인 댓글입니다.
#
# ['울 아들 딸이 먹방 유투버 보는거 왜 보나 했는데.\n유노님 보다보니 자꾸 보게 되네요..\n마약 유노님입니다..\n옥수수면 맛이 궁금하네요~^^']
# -->  88.52% 확률로 긍정적인 댓글입니다.
#
# ['아~   떡볶이 맛있겠다.']
# -->  86.67% 확률로 긍정적인 댓글입니다.
#
# ['떡볶이도 좋지만 우삼겹 안타까워용!! 근데 그냥 떡볶이 1인분에 튀김+순대 갖춰 먹는 가격에 무한리필이면 대식가들한테\n짱이겠네요. 저도 한 번 가봐야겠어요.']
# -->  75.28% 확률로 긍정적인 댓글입니다.
#
# ['다이어트중인데 항상대리만족 감사해요 ㅎㅎㅎ !']
# -->  99.18% 확률로 긍정적인 댓글입니다.
#
# ['허ㅜㅜ 드셔달라구 그랬는데 영상 올라와서 넘 기뻤어용 .. 우삼겹 아쉬워... 참기름대신에 데리야끼소스 넣었으면 존맛이에오 ㅠ ㅜ오늘도 영상 재밌게 봤어요 ㅎㅎ']
# -->  99.23% 확률로 긍정적인 댓글입니다.
#
# ['떡볶이는 언제 머거도 맛나요~~ㅎ 영상 잘 보고 갑니다 ~응원합니다 ~ 감사합니다']
# -->  98.80% 확률로 긍정적인 댓글입니다.
#
# ['아~~ 주말에 두끼 가야겠어요~~♡\n예의바른 유노님~\n오늘도 맛있게 잘 드시네요~ \n치킨마요 꿀팁 꼭 따라해볼게요 ^^\n맛있는 영상 잘 보고 갑니다~!!']
# -->  98.48% 확률로 긍정적인 댓글입니다.
#
# ['헉 저 덮밥? 에 데리야끼소스 안 넣으셨어요..ㅠㅠㅠ']
# --> 87.16% 확률로 부정적인 댓글입니다.
#
# ['나 유노 천따리  히밥 백따리 때  같은날 같이 구독햇는데  히밥은 지금 20만 코앞   그 이유가 뭘까']
# --> 78.54% 확률로 부정적인 댓글입니다.
#
# ['히밥님과한번같이콜라보합시다']
# -->  84.14% 확률로 긍정적인 댓글입니다.
#
# ['안녕하세요~~~ 안동 신세계찜닭에서 대왕찜닭 푸파 이벤트 진행중입니다 ^^\n찜닭2마리 + 공기밥2 20분내 클리어시 상금10만원 ! 신기록 갱신시 추가로 +20만원 상금있습니다.\n시간되시면 참여 부탁드려요!!!!']
# --> 74.84% 확률로 부정적인 댓글입니다.
#
# ['오뎅 언제 먹었지..?']
# --> 61.26% 확률로 부정적인 댓글입니다.
#
# ['제목이 살짝 아쉽네요.\n오늘도 잘 드셨네요!\n오늘은 표정이 조금ㅜ 기분이 안좋아보이네요.\n우삼겹을 못먹어서 그런가...\n잘먹는 사람 보니 기분 좋네요.\n항상 응원합니다. \n다음에도 맛난거 먹어주세요!굿굿 화이팅']
# -->  98.88% 확률로 긍정적인 댓글입니다.
#
# ['으이그 이러이 안되네~~']
# --> 95.40% 확률로 부정적인 댓글입니다.
#
# ['저는마감한시간전에와서 배터지는줄 흑당치즈볼이 젤맛잇어요 마감시간 10신데 9시40분까지먹엇어요 7분쉬구계산햇어요 빨리먹엇어요 8시50분쯤와서 떡볶이먹구잇는데 어묵다주구 볶음밥가져가라하구 위장에서욕하는줄... 사이다랑 콜라 미친듯이먹구 걷구...나온담에 미친듯이셔서 집에서 원두가루사서 아아만들어서먹엇어요저도볶음밥조합이상하게함ㅎ소스넣으니맛잇엇어요ㅋ']
# -->  83.81% 확률로 긍정적인 댓글입니다.
#
# ['2빠다!']
# --> 74.42% 확률로 부정적인 댓글입니다.
#
# ['두끼좋아하는데 시간제한때문에  갈때마다 양껏 못먹어서 너무 아쉬워요.  끓이는 시간도있는데 두시간정도만 됐어도 ㅠㅠ']
# --> 96.14% 확률로 부정적인 댓글입니다.
#
# ['항상 응원합니다 ᆢ건강챙기고 \n구독이 많이 늘기를 기원합니다ᆢ뒤에서 응원하니까 힘내요~~화이팅~~~~^^']
# -->  99.45% 확률로 긍정적인 댓글입니다.
#
# ['말하는걸 반만 줄이면 좋을것같네요.\n먹다가 흐름 끊기네요.']
# --> 94.23% 확률로 부정적인 댓글입니다.
#
# ['초반에 유투브라이브킬때 매번챙겨보고\n유노님 회사들어간뒤로도 영상꾸준히 챙겨보고잇는데\n상금이 걸려잇는곳이나 무한리필로만가서 좀 그래요...\n촬영 범위도 좀 늘려줫음하네요\n상금걸려잇능곳이나 무한리필은 적당히가주세요...']
# -->  68.80% 확률로 긍정적인 댓글입니다.
#
# ['입안에서 개한마리가 왜뛰어요.,..\n그냥 말많이안하시구 먹방하시는게...ㅠㅠ\n기분나쁘셧으면 죄송해요']
# --> 98.08% 확률로 부정적인 댓글입니다.
#
# ['식상하네요']
# --> 98.64% 확률로 부정적인 댓글입니다.
#
# ['안녕하세요 여러분! 유노입니다!\n오늘은! 어떤 음식을 가지고 왔냐면요!\n바로 1인분에 2000천원밖에 안하는!\n할범탕수육을 가지고 왔어욥 ㅎㅎㅎㅎ\n(진짜 가성비 ㄹㅇ 너무 쩌는듯..)\n영상 찍기 전에는 중국집 탕수육 대 사이즈랑\n할범탕수육 10인분이랑 비교하려고 했으나!\n여러분들에게 할범탕수육을 좀 더\n자세히 알려드리고 싶어서!\n오늘은 그냥 할범탕수육에 전메뉴를\n먹으며 소개시키는 영상을 한 번\n찍어봤는데 진짜 영상 다시 보면서도\n느끼는거지만 가성비 진짜 갑이에요..\n여러분들도 서울 강서구 목동,등촌동\n주변 지나다 시간 나시면은! 할범 탕수육\n꼭 들려보세요! 탕수육뿐만 아니라!\n할범세트,돈까스세트 막 이런 것도 있는데\n잔치국수.떡볶이.튀김2종.탕수육\n잔치국수,밥.돈까스 이렇게 주는데도\n단돈 5천원 밖에 하지 않아요..ㅠㅠㅠㅠ\n앗 너무 tmi였나..? ㅎㅎㅎㅎ 아무튼!\n여러분! 요새 날이 많이 더워져서\n마스크도 꼭 써야하고 날이 덥고 하니\n밖에 다니기 힘든데! 학업! 직장! 모두들\n고생이 많습니다! 내일은 꼭 시원하게\n휴식을 취하고! 주말 잘 보내셨으면 \n좋겠습니다! (시간나면 아프리카tv 유노라고해요 놀러와주세용 ㅎㅎㅎ)\n오늘 하루도 수고많으셨습니다!\n좋은 밤 되세요! 안녕~~!!!!\n\n🍒유노 인스타그램:https://www.instagram.com/u.n.o_o/\n🍒유노 페이스북:https://www.facebook.com/profile.php?id=100005451199138\n🍒유노 틱톡: https://www.tiktok.com/@u.n.o_o\n\n✉문의 메일 :choiyunho16@gmail.com\n\n++아 맞다! 오늘 10시 조금 넘어서! 아프리카티비 방송하니까 시간 되시면 한 번씩 놀러오셔서 채팅 갈겨주세욥!!!!! 막 갈겨갈겨!!!!']
# -->  85.77% 확률로 긍정적인 댓글입니다.
#
# ['손점 가만히...']
# --> 50.98% 확률로 부정적인 댓글입니다.
#
# ['🏆🥇최고예요 유노~👋🙆\u200d♀️']
# -->  98.08% 확률로 긍정적인 댓글입니다.
#
# ['아니그래서 지금 총 몇인분인지가 중요한건데\n그게빠졌네']
# --> 96.22% 확률로 부정적인 댓글입니다.
#
# ['진짜 넘 귀여워서 보면서 몇번을 웃었나 모르궸눼요!!😍 담부턴 빨간음식 먹을땐 어두운티 입으세요♥']
# -->  95.61% 확률로 긍정적인 댓글입니다.
#
# ['이열치열이다! 날 더우니 뜨끈~한 국밥종류 가즈아!']
# -->  58.33% 확률로 긍정적인 댓글입니다.
#
# ['유노님 날씨 더운데 좋은 영상 찍으시느라 수고 많으세요~~']
# -->  59.76% 확률로 긍정적인 댓글입니다.
#
# ['배달을 시켜버리게 만드는 유노님 ㅠㅠ']
# --> 95.93% 확률로 부정적인 댓글입니다.
#
# ['구여우셔......😊']
# -->  88.17% 확률로 긍정적인 댓글입니다.
#
# ['국물 튀었을땐 절대!!!  물 묻히지 말고 ****바로 퐁퐁 ****묻혀서 비빈다음   물로 헹궈요..얼룩 절대 안 남아요']
# --> 84.04% 확률로 부정적인 댓글입니다.
#
# ['밀떡이 맛난데 ㅎㅎㅎ 밀떡이었을거에요']
# -->  72.07% 확률로 긍정적인 댓글입니다.
#
# ['대리만족 느끼는중 \n항상 맛나게 먹어서 너무좋음']
# -->  99.33% 확률로 긍정적인 댓글입니다.
#
# ['오늘도 맛난거 드셨네요!! 항상 영상 잘 챙겨보고 있어용 🥰 오늘 하루도 좋은 하루~']
# -->  95.80% 확률로 긍정적인 댓글입니다.
#
# ['외국에서 와서 젖가락질을 잘 몬하는것 같지요? 힘내요 ㅋ 연습하믄 되요~♡']
# --> 54.94% 확률로 부정적인 댓글입니다.
#
# ['분식메뉴 가성비 좋네요. 😎🤓😆😋\n양천구면 넘 멀어요.\n산더미 탕수육 대박이에요.😲\n유노님 더운데 넘 고생하셨네...😄😊\n주말 즐겁게 보내요.🍈🍉🍋\n그리고 캡이에요.🍀🍀🍀👍']
# -->  82.20% 확률로 긍정적인 댓글입니다.
#
# ['오늘도 맛있게 드시는 먹방 잘보고 갑니다! 응원할꼐요!']
# -->  98.79% 확률로 긍정적인 댓글입니다.
#
# ['오!! 저 양천구 살 때 가끔 가던 곳이네요. 엄청 맛집은 아녀도 가격 대비 좋죠. 전 잔치국수 주로 먹었어요.']
# -->  91.48% 확률로 긍정적인 댓글입니다.
#
# ['초하~~~\n 가성비좋고 맛있는곳 너므좋아^^\n부천에 사는데 이쪽 리뷰할만한곳 읎나?ㅋ']
# -->  97.44% 확률로 긍정적인 댓글입니다.
#
# ['2마넌치 치고는 많넹 ㅎ\n순대보다 싸네요 ㅎ']
# -->  90.89% 확률로 긍정적인 댓글입니다.
#
# ['유노님~ 저는 탕수육이 아예  소스에 저려져서 눅눅한걸 좋아하는데~ 모두들 제 입맛을 이해할수없다고 하더라구요🤤\n오늘도 맛있는 영상 감사합니다~~^^\n참 그리고 저는 아프리카티비 앱 설치를 안해 어제 생방송을 못봤어요ㅠ\n유노님 보고싶어~ 아프리카앱 다운받아야 할까봐요 ㅎㅎ']
# -->  86.03% 확률로 긍정적인 댓글입니다.
#
# ['양미라 조카님 아니심? 왜케닮았노']
# -->  78.93% 확률로 긍정적인 댓글입니다.
#
# ['담에서울가면 사먹으러가야겠어요 가성비좋네요 옷에묻은 양념은 주방세제 트리오 옷에뭍혀서 30분정도놔뒀다가문지르면 깨끗하게집니다 저만의 팁입니다^^']
# -->  95.30% 확률로 긍정적인 댓글입니다.
#
# ['뻘건거 묻자마자 퐁퐁을 발라야죠']
# -->  55.70% 확률로 긍정적인 댓글입니다.
#
# ['어린 나이에 열심히 도전하는윤호 항상응원 할께요~']
# -->  97.36% 확률로 긍정적인 댓글입니다.
#
# ['새로운곳들 많이많이 소개시켜주세요~~홧팅!!!']
# -->  95.55% 확률로 긍정적인 댓글입니다.
#
# ['유노님 왜 오늘은 안뛰세여!!ㅎㅎㅎ']
# --> 50.40% 확률로 부정적인 댓글입니다.
#
# ['솔직히 손동작이 좀 어설퍼요 ㅠㅠ']
# --> 95.57% 확률로 부정적인 댓글입니다.
#
# ['얘기할때 저 손 움직임 ㅜ\n너--무 산만하고 어색하고 그래요...\n조금 고민하셔야  될듯요...\n얘기하는것도 연습 하고 녹화해보세요\n보다가 나가고 싶어요 ㅜ']
# --> 96.87% 확률로 부정적인 댓글입니다.
#
# ['코로나가 서울지역에 지금 꾸준히 확진자가 나오는걸로 아는데.. 영상을 찍을때 잠시 턱밑으로 내리셨겠지만... 길거리에서 뒤돌아서 가는 장면에서도 계속 마스크를 턱밑에 걸치고계시니 좀 그래요 ㅠㅠ 다른 유튜버분들은 마스크 끝까지 착용하고 이야기하시던데......']
# --> 52.68% 확률로 부정적인 댓글입니다.
# ['안녕하세요 여러분! 유노입니당!\n오늘은 바로바로 무한리필의 원조격인!\n엉터리 생고기 무한리필에 다녀왔어요!\n여기는 서울 강서구 발산역 쪽에 위치한\n엉터리생고기 마곡사이언스점인데요!\n미리 사전에 제가 좀 많이 먹는데\n계속 계속 리필 받아먹어도 괜찮을까요라고\n여쭤봤는데 얼마든지 먹어도 된다고 하셔서\n이번에 삼겹살 약 4키로를.. 털고 왔어요\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n죄송합니다.. 사장님...\n아 근데도 마지막에 결제하고 나가려고 하니까\n사장님께서 공짜로 주실려고 하셔서\n진짜 감동먹었었는데!\n음식값은 그래도 다행히 결제하고 나왔어요!\n진짜 오랜만에 고기 폭식하니까\n이 말이 진짜 와닿더라고요..\n기분이 저기압일땐 고기앞으로 가라...\n진짜 띵언...\n여러분도 오늘 하루? 내일?\n맛있는 지글지글 익은 삼겹살\n어떠신가요!?\n저는 이만! 물러나구요!\n영상 재밌게 시청해주시고!\n앞으로도 더 맛있는 영상으로\n찾아뵐게요! 안뇽!!!\n오늘 하루도 수고많으셨어요!!']
# -->  92.86% 확률로 긍정적인 댓글입니다.
#
# ['울산의 청년 윤호군~\n울산에서 응원합니다~\n홧팅♡♡♡']
# -->  92.50% 확률로 긍정적인 댓글입니다.
#
# ['이 분 진짜 맛있게 많이 깔끔하게 잘 드시는데 ㅠㅠ 얼른 더더욱 뜨셨으면 좋겠습니다!유노님 화이팅~!!! -구독자 3천명때부터 보던 독자 올림.']
# -->  99.38% 확률로 긍정적인 댓글입니다.
#
# ['잘 봤습니다. 근데 주실 수 있을까요? 라는 말보다 주세요가 맞는 표현 일듯. 더더욱 번창하세요']
# -->  99.31% 확률로 긍정적인 댓글입니다.
#
# ['유노님도  얼렁 떡상해야델텐데']
# -->  56.68% 확률로 긍정적인 댓글입니다.
#
# ['착하고 겸손한 왕자님.🤓😎😆😲\n늘 열심히 하셔서 보기 좋아요.\n구독자 얘기가 매번 나오는데 너무 연연하지 않았음 하네요. 그냥 단단한 집을 지어가는 과정이라고 생각하심 좋지 않을까 싶어요. \n노력은 절대 배신하지 않아요. \n유노님 돼지고기 트라우마로 못먹는데 넘 대리만족되네요.😆😄😊🍎🍈🍉🍋\n더위 조심하시고 건강도 잘 챙기셔요.\n그리고 캡이에요.🍀🍀🍀👍']
# -->  98.74% 확률로 긍정적인 댓글입니다.
#
# ['🏆🥇최고예요 유노~👋🙆\u200d♀️']
# -->  98.08% 확률로 긍정적인 댓글입니다.
#
# ['유노님 덕분에 몇달만에 삼겹살을\n(눈으로) 먹었네요. 혹시 수령처가\n바뀌지 않았다면 만두 보내드릴테니\n집에서 드실 거 없을 때 드세요.']
# --> 67.97% 확률로 부정적인 댓글입니다.
#
# ['유노님이랑 밥먹음 나 없던 입맛이 살아날거 같아 최고!']
# -->  98.15% 확률로 긍정적인 댓글입니다.
#
# ['무한리필갈때 유노님 위장 빌릴수있으면 꿀이겠다...']
# --> 83.24% 확률로 부정적인 댓글입니다.

# %%
val=sentiment_predict(test_path,800,900)
# Out:
# ['아니.. 양을 거의 두배로 늘리고 시간을 줄이는건.. 이건 도전메뉴가 아니고.. 유튜버들 놀리는거 같아서 화나네요..상해기님꺼 유노님꺼 히밥님꺼 영상 다 봤는데.. 솔직히 유노님 상해기님 못드실 정도면 일반인은 도전 엄두도 못낼 양..']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['많이  먹는거 보다  맛있게  믝는 컨셉이 더 좋다 목소리도 좋고 말도 잘해서']
# --> 59.29% 확률로 부정적인 댓글입니다.
#
# ['흥하시길!']
# --> 59.28% 확률로 부정적인 댓글입니다.
#
# ['그냥 조용히 먹는 모습도 좋은데...... 너무']
# --> 64.02% 확률로 부정적인 댓글입니다.
#
# ['노력하는 남자  유노  멋진남자 유노  힘내라~~힘 무조건  전진\n~~~~~']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['🏆🥇최고예요  유노~👋🙆\u200d♀️']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['진짜 잘먹는다 대리만족을']
# --> 64.42% 확률로 부정적인 댓글입니다.
#
# ['아프리카tv 어제  마피아 떡볶이 보고  왔어요 구독  앞으로 홧팅입니다\n햄식이 같은  방송하시면 절대 안됨 갠방 전혀 안하고 모기짖만 하면 절대안됨']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['앗ㅡ일빠넹ㅡ응원해요 유노씨']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['왤케 많이 먹어 윤호']
# --> 64.42% 확률로 부정적인 댓글입니다.
#
# ['처음 보는데 목소리가 너무 좋아요']
# --> 64.49% 확률로 부정적인 댓글입니다.
#
# ['새벽에 이 영상을보다니.... 떡볶이가 너무 먹고 싶어졌다....']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['아구 맛 표현 명랑하네요^^ 꿀성대 꿀조합']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['맛깔나게먹는다진짜']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['그동안 돈내고 못먹은거 유노님이 대신 먹었다고 생각할게요~ 돈 안아까워~ ㅎㅎ']
# --> 56.86% 확률로 부정적인 댓글입니다.
#
# ['마지막 리조또 같아서 더 맛있겠다 ㅠㅠ']
# --> 64.02% 확률로 부정적인 댓글입니다.
#
# ['잘 먹는 사람 보면 왜이렇게 흐믓하지 ㅋㅋ 전 식탐은 많은데 입이 짧아요 하.. 😔']
# --> 57.67% 확률로 부정적인 댓글입니다.
#
# ['유노 화이팅\n몸 건강하게 식사하세요\n장마 곧 시작이라니 조심하세요']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['헐 저기 두끼 저희 동네 두끼에요ㅜㅜㅜ 대박대박...']
# --> 58.46% 확률로 부정적인 댓글입니다.
#
# ['진짜 어떻게 하면 사람들이 좋아할지를 딱 아는 듯해요‼️ 영상 너무 재미있네욤 ㅎㅎ']
# --> 59.29% 확률로 부정적인 댓글입니다.
#
# ['이 영상 엄청 기다리고 있었다구요 후 오늘도 배불리 보고가용>_<']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['이미지랑 스타일이랑 호감도랑 등등이 남성형 쯔양 느낌...뜰것 같은데...여튼 좋아요~!']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['유노님 제목이...😲\n항상 열심히 하시고 애 많이 쓰시는데 저번영상에 어쩌네 저쩌네가 넘 많더라구요. 유노님 스타일대로 하고픈대로 잘 하셨으면 좋겠어요.\n두끼 다녀오셨네요. 작년 여름 미금역점에서 쇼핑하다 먹어봤는데 엄청 맛있었어요. 왕자님 드시니 가고 싶네..\n개인적으로 쌀떡파라서 쌀떡을 더 좋아해요.🤓😎😄😊😆\n날 더운데 더위 조심해요.😋🍦🍨🍧\n그리고 캡이에요.🍀🍀🍀👍']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['재료들 똑똑똑! 01:12']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['리조또맛있겠당ㅜ']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['먹방하는 비제이들이 남기는건 없어요..다 드셔주길']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['영상 몇개 봤는데 \n잘 드시고 \n목소리가 진짜 좋다 \n아... 두끼 가고 싶네 \n응원합니다']
# --> 56.86% 확률로 부정적인 댓글입니다.
#
# ['와~~다이어트 중인데 떡볶이 영상 보니깐 미치겠네요 ㅎㅎ 어째 떡볶이보다 밥을 더 드신것같은 느낌이 ㅋㅋ 유노님~~오늘도 수고하셨습니다~^^참 아프리도 영상은 유툽에 업로드 안하시나요?']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['맛나보여요..귀욤 귀욤..구독자  10만 100만 가즈아~~~']
# --> 57.67% 확률로 부정적인 댓글입니다.
#
# ['다이어트줄일라더더더먹고싶네요 오늘도 맛나게 드셔주셔서 감사해요~~~']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['다른분에 비해 구독자수가 빨리 늘지 않네요.']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['오늘 아프리카tv잘봤습니다.\n근데 가장 최근영상이 두끼 떡뽂이네요ㅋㅋㅋ\n마피아떡뽁이 vs 두끼떡뽁이\n먹방 잘하세요']
# --> 52.60% 확률로 부정적인 댓글입니다.
#
# ['유노님 무한리필오면 한명으로 계산해오?']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['이제 댓글도 50 넘는드아~~~구독자도늘고~~~\n유노 항상 화이팅이에요~~^^♡\n100만가즈아~~']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['어제 영상 올라오는거 알고 기다렸는데 너무 피곤해서 오늘에서야 시청\n떡볶이 좋아해서 두끼가면 엄청 먹고와야지 하는데도 우리 네식구 가면 4명이서 유노님 양만큼도 못 먹어요ㅎ\n우삼겹이 없어서 아쉬우셨겠지만\n전 덕분에 대리만족 했어요']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['두끼 떡볶이집 일부러 더 안갔는데..유노님  먹방에 함 가봐야겠어요~^^무한리필에 약간에..좀 그랬는데..좋은 먹방 감사합니다^^']
# --> 51.43% 확률로 부정적인 댓글입니다.
#
# ['맛있어  보이네요']
# --> 61.62% 확률로 부정적인 댓글입니다.
#
# ['맛있게 드셔 주셔서 감사해용! 오늘도 대리만족하구 갑니다❤️']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['너~무 잘드시고 귀요미세용~올아들같네옹']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['울 아들 딸이 먹방 유투버 보는거 왜 보나 했는데.\n유노님 보다보니 자꾸 보게 되네요..\n마약 유노님입니다..\n옥수수면 맛이 궁금하네요~^^']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['아~   떡볶이 맛있겠다.']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['떡볶이도 좋지만 우삼겹 안타까워용!! 근데 그냥 떡볶이 1인분에 튀김+순대 갖춰 먹는 가격에 무한리필이면 대식가들한테\n짱이겠네요. 저도 한 번 가봐야겠어요.']
# -->  50.71% 확률로 긍정적인 댓글입니다.
#
# ['다이어트중인데 항상대리만족 감사해요 ㅎㅎㅎ !']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['허ㅜㅜ 드셔달라구 그랬는데 영상 올라와서 넘 기뻤어용 .. 우삼겹 아쉬워... 참기름대신에 데리야끼소스 넣었으면 존맛이에오 ㅠ ㅜ오늘도 영상 재밌게 봤어요 ㅎㅎ']
# --> 50.54% 확률로 부정적인 댓글입니다.
#
# ['떡볶이는 언제 머거도 맛나요~~ㅎ 영상 잘 보고 갑니다 ~응원합니다 ~ 감사합니다']
# --> 57.67% 확률로 부정적인 댓글입니다.
#
# ['아~~ 주말에 두끼 가야겠어요~~♡\n예의바른 유노님~\n오늘도 맛있게 잘 드시네요~ \n치킨마요 꿀팁 꼭 따라해볼게요 ^^\n맛있는 영상 잘 보고 갑니다~!!']
# --> 50.54% 확률로 부정적인 댓글입니다.
#
# ['헉 저 덮밥? 에 데리야끼소스 안 넣으셨어요..ㅠㅠㅠ']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['나 유노 천따리  히밥 백따리 때  같은날 같이 구독햇는데  히밥은 지금 20만 코앞   그 이유가 뭘까']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['히밥님과한번같이콜라보합시다']
# --> 64.02% 확률로 부정적인 댓글입니다.
#
# ['안녕하세요~~~ 안동 신세계찜닭에서 대왕찜닭 푸파 이벤트 진행중입니다 ^^\n찜닭2마리 + 공기밥2 20분내 클리어시 상금10만원 ! 신기록 갱신시 추가로 +20만원 상금있습니다.\n시간되시면 참여 부탁드려요!!!!']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['오뎅 언제 먹었지..?']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['제목이 살짝 아쉽네요.\n오늘도 잘 드셨네요!\n오늘은 표정이 조금ㅜ 기분이 안좋아보이네요.\n우삼겹을 못먹어서 그런가...\n잘먹는 사람 보니 기분 좋네요.\n항상 응원합니다. \n다음에도 맛난거 먹어주세요!굿굿 화이팅']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['으이그 이러이 안되네~~']
# --> 64.42% 확률로 부정적인 댓글입니다.
#
# ['저는마감한시간전에와서 배터지는줄 흑당치즈볼이 젤맛잇어요 마감시간 10신데 9시40분까지먹엇어요 7분쉬구계산햇어요 빨리먹엇어요 8시50분쯤와서 떡볶이먹구잇는데 어묵다주구 볶음밥가져가라하구 위장에서욕하는줄... 사이다랑 콜라 미친듯이먹구 걷구...나온담에 미친듯이셔서 집에서 원두가루사서 아아만들어서먹엇어요저도볶음밥조합이상하게함ㅎ소스넣으니맛잇엇어요ㅋ']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['2빠다!']
# --> 59.28% 확률로 부정적인 댓글입니다.
#
# ['두끼좋아하는데 시간제한때문에  갈때마다 양껏 못먹어서 너무 아쉬워요.  끓이는 시간도있는데 두시간정도만 됐어도 ㅠㅠ']
# -->  50.71% 확률로 긍정적인 댓글입니다.
#
# ['항상 응원합니다 ᆢ건강챙기고 \n구독이 많이 늘기를 기원합니다ᆢ뒤에서 응원하니까 힘내요~~화이팅~~~~^^']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['말하는걸 반만 줄이면 좋을것같네요.\n먹다가 흐름 끊기네요.']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['초반에 유투브라이브킬때 매번챙겨보고\n유노님 회사들어간뒤로도 영상꾸준히 챙겨보고잇는데\n상금이 걸려잇는곳이나 무한리필로만가서 좀 그래요...\n촬영 범위도 좀 늘려줫음하네요\n상금걸려잇능곳이나 무한리필은 적당히가주세요...']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['입안에서 개한마리가 왜뛰어요.,..\n그냥 말많이안하시구 먹방하시는게...ㅠㅠ\n기분나쁘셧으면 죄송해요']
# --> 52.60% 확률로 부정적인 댓글입니다.
#
# ['식상하네요']
# --> 59.28% 확률로 부정적인 댓글입니다.
#
# ['안녕하세요 여러분! 유노입니다!\n오늘은! 어떤 음식을 가지고 왔냐면요!\n바로 1인분에 2000천원밖에 안하는!\n할범탕수육을 가지고 왔어욥 ㅎㅎㅎㅎ\n(진짜 가성비 ㄹㅇ 너무 쩌는듯..)\n영상 찍기 전에는 중국집 탕수육 대 사이즈랑\n할범탕수육 10인분이랑 비교하려고 했으나!\n여러분들에게 할범탕수육을 좀 더\n자세히 알려드리고 싶어서!\n오늘은 그냥 할범탕수육에 전메뉴를\n먹으며 소개시키는 영상을 한 번\n찍어봤는데 진짜 영상 다시 보면서도\n느끼는거지만 가성비 진짜 갑이에요..\n여러분들도 서울 강서구 목동,등촌동\n주변 지나다 시간 나시면은! 할범 탕수육\n꼭 들려보세요! 탕수육뿐만 아니라!\n할범세트,돈까스세트 막 이런 것도 있는데\n잔치국수.떡볶이.튀김2종.탕수육\n잔치국수,밥.돈까스 이렇게 주는데도\n단돈 5천원 밖에 하지 않아요..ㅠㅠㅠㅠ\n앗 너무 tmi였나..? ㅎㅎㅎㅎ 아무튼!\n여러분! 요새 날이 많이 더워져서\n마스크도 꼭 써야하고 날이 덥고 하니\n밖에 다니기 힘든데! 학업! 직장! 모두들\n고생이 많습니다! 내일은 꼭 시원하게\n휴식을 취하고! 주말 잘 보내셨으면 \n좋겠습니다! (시간나면 아프리카tv 유노라고해요 놀러와주세용 ㅎㅎㅎ)\n오늘 하루도 수고많으셨습니다!\n좋은 밤 되세요! 안녕~~!!!!\n\n🍒유노 인스타그램:https://www.instagram.com/u.n.o_o/\n🍒유노 페이스북:https://www.facebook.com/profile.php?id=100005451199138\n🍒유노 틱톡: https://www.tiktok.com/@u.n.o_o\n\n✉문의 메일 :choiyunho16@gmail.com\n\n++아 맞다! 오늘 10시 조금 넘어서! 아프리카티비 방송하니까 시간 되시면 한 번씩 놀러오셔서 채팅 갈겨주세욥!!!!! 막 갈겨갈겨!!!!']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['손점 가만히...']
# --> 61.62% 확률로 부정적인 댓글입니다.
#
# ['🏆🥇최고예요 유노~👋🙆\u200d♀️']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['아니그래서 지금 총 몇인분인지가 중요한건데\n그게빠졌네']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['진짜 넘 귀여워서 보면서 몇번을 웃었나 모르궸눼요!!😍 담부턴 빨간음식 먹을땐 어두운티 입으세요♥']
# --> 52.60% 확률로 부정적인 댓글입니다.
#
# ['이열치열이다! 날 더우니 뜨끈~한 국밥종류 가즈아!']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['유노님 날씨 더운데 좋은 영상 찍으시느라 수고 많으세요~~']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['배달을 시켜버리게 만드는 유노님 ㅠㅠ']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['구여우셔......😊']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['국물 튀었을땐 절대!!!  물 묻히지 말고 ****바로 퐁퐁 ****묻혀서 비빈다음   물로 헹궈요..얼룩 절대 안 남아요']
# --> 50.40% 확률로 부정적인 댓글입니다.
#
# ['밀떡이 맛난데 ㅎㅎㅎ 밀떡이었을거에요']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['대리만족 느끼는중 \n항상 맛나게 먹어서 너무좋음']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['오늘도 맛난거 드셨네요!! 항상 영상 잘 챙겨보고 있어용 🥰 오늘 하루도 좋은 하루~']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['외국에서 와서 젖가락질을 잘 몬하는것 같지요? 힘내요 ㅋ 연습하믄 되요~♡']
# --> 56.86% 확률로 부정적인 댓글입니다.
#
# ['분식메뉴 가성비 좋네요. 😎🤓😆😋\n양천구면 넘 멀어요.\n산더미 탕수육 대박이에요.😲\n유노님 더운데 넘 고생하셨네...😄😊\n주말 즐겁게 보내요.🍈🍉🍋\n그리고 캡이에요.🍀🍀🍀👍']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['오늘도 맛있게 드시는 먹방 잘보고 갑니다! 응원할꼐요!']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['오!! 저 양천구 살 때 가끔 가던 곳이네요. 엄청 맛집은 아녀도 가격 대비 좋죠. 전 잔치국수 주로 먹었어요.']
# --> 50.40% 확률로 부정적인 댓글입니다.
#
# ['초하~~~\n 가성비좋고 맛있는곳 너므좋아^^\n부천에 사는데 이쪽 리뷰할만한곳 읎나?ㅋ']
# --> 53.81% 확률로 부정적인 댓글입니다.
#
# ['2마넌치 치고는 많넹 ㅎ\n순대보다 싸네요 ㅎ']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['유노님~ 저는 탕수육이 아예  소스에 저려져서 눅눅한걸 좋아하는데~ 모두들 제 입맛을 이해할수없다고 하더라구요🤤\n오늘도 맛있는 영상 감사합니다~~^^\n참 그리고 저는 아프리카티비 앱 설치를 안해 어제 생방송을 못봤어요ㅠ\n유노님 보고싶어~ 아프리카앱 다운받아야 할까봐요 ㅎㅎ']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['양미라 조카님 아니심? 왜케닮았노']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['담에서울가면 사먹으러가야겠어요 가성비좋네요 옷에묻은 양념은 주방세제 트리오 옷에뭍혀서 30분정도놔뒀다가문지르면 깨끗하게집니다 저만의 팁입니다^^']
# --> 51.51% 확률로 부정적인 댓글입니다.
#
# ['뻘건거 묻자마자 퐁퐁을 발라야죠']
# --> 64.02% 확률로 부정적인 댓글입니다.
#
# ['어린 나이에 열심히 도전하는윤호 항상응원 할께요~']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['새로운곳들 많이많이 소개시켜주세요~~홧팅!!!']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['유노님 왜 오늘은 안뛰세여!!ㅎㅎㅎ']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['솔직히 손동작이 좀 어설퍼요 ㅠㅠ']
# --> 64.42% 확률로 부정적인 댓글입니다.
#
# ['얘기할때 저 손 움직임 ㅜ\n너--무 산만하고 어색하고 그래요...\n조금 고민하셔야  될듯요...\n얘기하는것도 연습 하고 녹화해보세요\n보다가 나가고 싶어요 ㅜ']
# -->  50.71% 확률로 긍정적인 댓글입니다.
#
# ['코로나가 서울지역에 지금 꾸준히 확진자가 나오는걸로 아는데.. 영상을 찍을때 잠시 턱밑으로 내리셨겠지만... 길거리에서 뒤돌아서 가는 장면에서도 계속 마스크를 턱밑에 걸치고계시니 좀 그래요 ㅠㅠ 다른 유튜버분들은 마스크 끝까지 착용하고 이야기하시던데......']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['안녕하세요 여러분! 유노입니당!\n오늘은 바로바로 무한리필의 원조격인!\n엉터리 생고기 무한리필에 다녀왔어요!\n여기는 서울 강서구 발산역 쪽에 위치한\n엉터리생고기 마곡사이언스점인데요!\n미리 사전에 제가 좀 많이 먹는데\n계속 계속 리필 받아먹어도 괜찮을까요라고\n여쭤봤는데 얼마든지 먹어도 된다고 하셔서\n이번에 삼겹살 약 4키로를.. 털고 왔어요\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n죄송합니다.. 사장님...\n아 근데도 마지막에 결제하고 나가려고 하니까\n사장님께서 공짜로 주실려고 하셔서\n진짜 감동먹었었는데!\n음식값은 그래도 다행히 결제하고 나왔어요!\n진짜 오랜만에 고기 폭식하니까\n이 말이 진짜 와닿더라고요..\n기분이 저기압일땐 고기앞으로 가라...\n진짜 띵언...\n여러분도 오늘 하루? 내일?\n맛있는 지글지글 익은 삼겹살\n어떠신가요!?\n저는 이만! 물러나구요!\n영상 재밌게 시청해주시고!\n앞으로도 더 맛있는 영상으로\n찾아뵐게요! 안뇽!!!\n오늘 하루도 수고많으셨어요!!']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['울산의 청년 윤호군~\n울산에서 응원합니다~\n홧팅♡♡♡']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['이 분 진짜 맛있게 많이 깔끔하게 잘 드시는데 ㅠㅠ 얼른 더더욱 뜨셨으면 좋겠습니다!유노님 화이팅~!!! -구독자 3천명때부터 보던 독자 올림.']
# -->  50.21% 확률로 긍정적인 댓글입니다.
# ['잘 봤습니다. 근데 주실 수 있을까요? 라는 말보다 주세요가 맞는 표현 일듯. 더더욱 번창하세요']
# --> 52.60% 확률로 부정적인 댓글입니다.
#
# ['유노님도  얼렁 떡상해야델텐데']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['착하고 겸손한 왕자님.🤓😎😆😲\n늘 열심히 하셔서 보기 좋아요.\n구독자 얘기가 매번 나오는데 너무 연연하지 않았음 하네요. 그냥 단단한 집을 지어가는 과정이라고 생각하심 좋지 않을까 싶어요. \n노력은 절대 배신하지 않아요. \n유노님 돼지고기 트라우마로 못먹는데 넘 대리만족되네요.😆😄😊🍎🍈🍉🍋\n더위 조심하시고 건강도 잘 챙기셔요.\n그리고 캡이에요.🍀🍀🍀👍']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['🏆🥇최고예요 유노~👋🙆\u200d♀️']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['유노님 덕분에 몇달만에 삼겹살을\n(눈으로) 먹었네요. 혹시 수령처가\n바뀌지 않았다면 만두 보내드릴테니\n집에서 드실 거 없을 때 드세요.']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['유노님이랑 밥먹음 나 없던 입맛이 살아날거 같아 최고!']
# --> 59.29% 확률로 부정적인 댓글입니다.
#
# ['무한리필갈때 유노님 위장 빌릴수있으면 꿀이겠다...']
# --> 62.23% 확률로 부정적인 댓글입니다.

# %%
stopwords_movie
# Out:
# ['의',
#  '가',
#  '이',
#  '은',
#  '들',
#  '는',
#  '좀',
#  '잘',
#  '걍',
#  '과',
#  '도',
#  '를',
#  '으로',
#  '자',
#  '에',
#  '와',
#  '한',
#  '하다']

# %%
lstm
# Out:
#                                               comment  sentiment_score
# 50                               고릴라 느낌 난다 잘먹게 생깄~~🤣🤣        35.508558
# 51  하지마하지마 이런거하지마 ㅠㅠ\n\n내가말했잔아여 가만히있어도 얼굴이다했다고 ㅠㅠ굳...        44.028670
# 52                                   옛날부터 구독했는데 대단합니다        35.581738
# 53  맵찔이 유노님  한테는  지옥행 인데 ㅠㅠ\n넘넘고생해써요~   물도 못머꾸 참느냐...        50.208956
# 54                             기.. 기요미 ㅠㅅ ㅠ♡ 맵찔이 ㄹㅇㅋㅋ        37.771323
# 55  맛을 괜히 느껴 버렷어ㅋ\n인생살면서 4분44초가 이리 길엇던가\n느낌이 새로웟겟네...        48.780748
# 56                                아 보면서 넘 웃었네요 ㅎㅎㅎ 죄송        35.978538
# 57  입술 퉁퉁 부은것봐 .. ㄷㄷ 무슨맛인지 궁금했는데 유체이탈 경험하는 맛이군요 ;;...        50.369990
# 58              저도맵찔이인데 보는것도매워서\n정신없이 물먹다가\n옷에물쏬았음ㅋㅋㅋ        40.706700
# 59               아우  절대 사먹지 말아야겠어요!!  진짜 속상해서 못보겠네 ㅠㅠ        38.801748
# 60                           유노님 짜장 기네스 도전 한번 해보심이...        37.771323
# 61                           우와~맵겠다ㅠ\n유노님의다른모습\n귀엽네ㅋㅋ        38.801748
# 62                             철구 푸파대결 보고왔음ㅎㅎ기여워서 구독함        39.794469
# 63                                         유노님 훌룡햄!!!        36.446673
# 64                         유노님  보는것만으로도 대게 매울것 같아요~최고        36.788368
# 65                              나는 왜!!?이라면이 안매운걸까?'ㅜㅜ        36.788368
# 66                                       도둑가시 나무젖가락 ㅋ        35.978538
# 67                                            🤣🤣🤣🤣🤣아포        40.724164
# 68  걱정됩니다ᆢ이젠하지마세요 ㅜㅜ 빨리 우유나 맨밥드시지ᆢ화이팅하시고요ᆢ  건강챙기면서...        43.135080
# 69               애쓰시는 모습에 응원은 하지만\n걱정이네요 ~먹기전에 우유라도^^        39.794469
# 70                                  근데  왜 웃기지?  ㅋ 미안요        35.978538
# 71  먹을때도 힘들지만 담날이 더 괴로우셨을듯 한데 게안았죠?\n불닭볶음면도 넘 매워서 ...        50.208956
# 72  철구 동영상보고 팬됬어여 ㅎㅎ 너무 착하시고 잘생기시고 잘웃으셔서 보기 좋으세여 !...        41.538233
# 73                             유노는 하는거에 비해서 구독자가 작네..        35.508558
# 74                         아고  왜 그랬어\n앞으로 매운거 멋지마셈 ㅋㅋ        37.771323
# 75        대단해요!!!!! 보는내내 제가더 맵더라구용\nㅠ.ㅠ속 괜찮으실런지요 걱정되요        43.135080
# 76  무조건 첼린지 라고 다 하는것 보다는 잘 할수 있는것이나 맛있게 먹을수 있는것이나 ...        50.369990
# 77  근데\n매운맛 가시게 하는 방법은\n입 약간 연 상태에서 계속\n깊게 호흡하면 되는...        49.754626
# 78                                              옥동~자야        38.381600
# 79                          아! 보기만 해도 무섭네요. 안먹는 걸로 ㅎㅎ        39.794469
# 80                                              ㅋㅋㅋㅋㅋ        40.724164
# 81        헐. . 유노님 속아프시겠어요!!! ㅜㅜ. . . 불마왕 볶음면 무섭네요 ㅜㅜ        41.538233
# 82                                최군방송에서 12초컷은 어케나온거지        37.771323
# 83  매운거먹고 멘탈 탈탈 털리네요ㅜ\n요즘 매운거 마니 드시는데 속아파요  건강 조심하세요~        43.135080
# 84                  전에 푸파 나갔을 땐 속 괜찮았나요?? 건강관리 잘 하세요ㅠ        39.794469
# 85                                                 ㅠㅜ        40.724164
# 86  아이고,ㅋㅋ맵찔이 유노님............이.... 어쩌자곸ㅋㅋ이런 챌린지를.....        43.135080
# 87  엄청 빨리 많이 잘드신다......\n\n\n\n그래도 꼭꼭 잘씹어드세용ㅜㅜ위에 엄...        42.326778
# 88  님 저 드디어 님말씀에\n맵기 궁금증 풀려서 한개 사서 먹어봤는데\n틈새라면 맵기정...        49.754626
# 89         유노님 맵찔이시잖아요ㅜ 아우~ 우째ㅜㅠ아 근데 왜케 귀여워요 ~~~미치긋다ㅋ        45.048833
# 90             먹는거 왤케 귀여우시지 ㅜㅜㅜㅜ팔은 어쩌다 다치신지 아시는분 있나요?        40.706700
# 91  저도  엄청 맵찔인데\n저거  못먹어요\n어지럽고  귀아프고 눈물콧물 토할것같고\n...        50.763983
# 92                                        오잉?? 12초엿는데        38.381600
# 93                              ㅎ 맵긴 매운가  부다요\n화이팅~^^        35.978538
# 94  영상 올릴때 일반인이 바로 공감가능한거 좀 올려주세요..많이 먹는것도 중요하지만.....        49.754626
# 95  매운거 좋아하는데..맛이없어 가격도 되도않게 비싸고 틈새1.5배 난 차라리 .틈새가...        44.028670
# 96                                               ㅎㅎㅡㅡ        40.724164
# 97                               이런건  좀  안했으면요,,,  ㅠㅠ        36.446673
# 98  그정도로 안매운데 더 차원이 다른 디진다돈까스나 다른 매운거 먹은거 보면 이거 오버...        49.754626
# 99                                      그리고 저초등1학년이에요        35.508558

# %%
lstm=sentiment_predict(test_path,800,900)
# Out:
# ['아니.. 양을 거의 두배로 늘리고 시간을 줄이는건.. 이건 도전메뉴가 아니고.. 유튜버들 놀리는거 같아서 화나네요..상해기님꺼 유노님꺼 히밥님꺼 영상 다 봤는데.. 솔직히 유노님 상해기님 못드실 정도면 일반인은 도전 엄두도 못낼 양..']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['많이  먹는거 보다  맛있게  믝는 컨셉이 더 좋다 목소리도 좋고 말도 잘해서']
# --> 59.29% 확률로 부정적인 댓글입니다.
#
# ['흥하시길!']
# --> 59.28% 확률로 부정적인 댓글입니다.
#
# ['그냥 조용히 먹는 모습도 좋은데...... 너무']
# --> 64.02% 확률로 부정적인 댓글입니다.
#
# ['노력하는 남자  유노  멋진남자 유노  힘내라~~힘 무조건  전진\n~~~~~']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['🏆🥇최고예요  유노~👋🙆\u200d♀️']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['진짜 잘먹는다 대리만족을']
# --> 64.49% 확률로 부정적인 댓글입니다.
#
# ['아프리카tv 어제  마피아 떡볶이 보고  왔어요 구독  앞으로 홧팅입니다\n햄식이 같은  방송하시면 절대 안됨 갠방 전혀 안하고 모기짖만 하면 절대안됨']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['앗ㅡ일빠넹ㅡ응원해요 유노씨']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['왤케 많이 먹어 윤호']
# --> 64.42% 확률로 부정적인 댓글입니다.
#
# ['처음 보는데 목소리가 너무 좋아요']
# --> 64.49% 확률로 부정적인 댓글입니다.
#
# ['새벽에 이 영상을보다니.... 떡볶이가 너무 먹고 싶어졌다....']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['아구 맛 표현 명랑하네요^^ 꿀성대 꿀조합']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['맛깔나게먹는다진짜']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['그동안 돈내고 못먹은거 유노님이 대신 먹었다고 생각할게요~ 돈 안아까워~ ㅎㅎ']
# --> 56.86% 확률로 부정적인 댓글입니다.
#
# ['마지막 리조또 같아서 더 맛있겠다 ㅠㅠ']
# --> 64.02% 확률로 부정적인 댓글입니다.
#
# ['잘 먹는 사람 보면 왜이렇게 흐믓하지 ㅋㅋ 전 식탐은 많은데 입이 짧아요 하.. 😔']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['유노 화이팅\n몸 건강하게 식사하세요\n장마 곧 시작이라니 조심하세요']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['헐 저기 두끼 저희 동네 두끼에요ㅜㅜㅜ 대박대박...']
# --> 58.46% 확률로 부정적인 댓글입니다.
#
# ['진짜 어떻게 하면 사람들이 좋아할지를 딱 아는 듯해요‼️ 영상 너무 재미있네욤 ㅎㅎ']
# --> 58.46% 확률로 부정적인 댓글입니다.
#
# ['이 영상 엄청 기다리고 있었다구요 후 오늘도 배불리 보고가용>_<']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['이미지랑 스타일이랑 호감도랑 등등이 남성형 쯔양 느낌...뜰것 같은데...여튼 좋아요~!']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['유노님 제목이...😲\n항상 열심히 하시고 애 많이 쓰시는데 저번영상에 어쩌네 저쩌네가 넘 많더라구요. 유노님 스타일대로 하고픈대로 잘 하셨으면 좋겠어요.\n두끼 다녀오셨네요. 작년 여름 미금역점에서 쇼핑하다 먹어봤는데 엄청 맛있었어요. 왕자님 드시니 가고 싶네..\n개인적으로 쌀떡파라서 쌀떡을 더 좋아해요.🤓😎😄😊😆\n날 더운데 더위 조심해요.😋🍦🍨🍧\n그리고 캡이에요.🍀🍀🍀👍']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['재료들 똑똑똑! 01:12']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['리조또맛있겠당ㅜ']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['먹방하는 비제이들이 남기는건 없어요..다 드셔주길']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['영상 몇개 봤는데 \n잘 드시고 \n목소리가 진짜 좋다 \n아... 두끼 가고 싶네 \n응원합니다']
# --> 56.86% 확률로 부정적인 댓글입니다.
#
# ['와~~다이어트 중인데 떡볶이 영상 보니깐 미치겠네요 ㅎㅎ 어째 떡볶이보다 밥을 더 드신것같은 느낌이 ㅋㅋ 유노님~~오늘도 수고하셨습니다~^^참 아프리도 영상은 유툽에 업로드 안하시나요?']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['맛나보여요..귀욤 귀욤..구독자  10만 100만 가즈아~~~']
# --> 57.67% 확률로 부정적인 댓글입니다.
#
# ['다이어트줄일라더더더먹고싶네요 오늘도 맛나게 드셔주셔서 감사해요~~~']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['다른분에 비해 구독자수가 빨리 늘지 않네요.']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['오늘 아프리카tv잘봤습니다.\n근데 가장 최근영상이 두끼 떡뽂이네요ㅋㅋㅋ\n마피아떡뽁이 vs 두끼떡뽁이\n먹방 잘하세요']
# --> 52.60% 확률로 부정적인 댓글입니다.
#
# ['유노님 무한리필오면 한명으로 계산해오?']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['이제 댓글도 50 넘는드아~~~구독자도늘고~~~\n유노 항상 화이팅이에요~~^^♡\n100만가즈아~~']
# --> 54.95% 확률로 부정적인 댓글입니다.
#
# ['어제 영상 올라오는거 알고 기다렸는데 너무 피곤해서 오늘에서야 시청\n떡볶이 좋아해서 두끼가면 엄청 먹고와야지 하는데도 우리 네식구 가면 4명이서 유노님 양만큼도 못 먹어요ㅎ\n우삼겹이 없어서 아쉬우셨겠지만\n전 덕분에 대리만족 했어요']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['두끼 떡볶이집 일부러 더 안갔는데..유노님  먹방에 함 가봐야겠어요~^^무한리필에 약간에..좀 그랬는데..좋은 먹방 감사합니다^^']
# --> 51.43% 확률로 부정적인 댓글입니다.
#
# ['맛있어  보이네요']
# --> 61.62% 확률로 부정적인 댓글입니다.
#
# ['맛있게 드셔 주셔서 감사해용! 오늘도 대리만족하구 갑니다❤️']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['너~무 잘드시고 귀요미세용~올아들같네옹']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['울 아들 딸이 먹방 유투버 보는거 왜 보나 했는데.\n유노님 보다보니 자꾸 보게 되네요..\n마약 유노님입니다..\n옥수수면 맛이 궁금하네요~^^']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['아~   떡볶이 맛있겠다.']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['떡볶이도 좋지만 우삼겹 안타까워용!! 근데 그냥 떡볶이 1인분에 튀김+순대 갖춰 먹는 가격에 무한리필이면 대식가들한테\n짱이겠네요. 저도 한 번 가봐야겠어요.']
# -->  50.71% 확률로 긍정적인 댓글입니다.
#
# ['다이어트중인데 항상대리만족 감사해요 ㅎㅎㅎ !']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['허ㅜㅜ 드셔달라구 그랬는데 영상 올라와서 넘 기뻤어용 .. 우삼겹 아쉬워... 참기름대신에 데리야끼소스 넣었으면 존맛이에오 ㅠ ㅜ오늘도 영상 재밌게 봤어요 ㅎㅎ']
# --> 50.54% 확률로 부정적인 댓글입니다.
#
# ['떡볶이는 언제 머거도 맛나요~~ㅎ 영상 잘 보고 갑니다 ~응원합니다 ~ 감사합니다']
# --> 57.67% 확률로 부정적인 댓글입니다.
#
# ['아~~ 주말에 두끼 가야겠어요~~♡\n예의바른 유노님~\n오늘도 맛있게 잘 드시네요~ \n치킨마요 꿀팁 꼭 따라해볼게요 ^^\n맛있는 영상 잘 보고 갑니다~!!']
# --> 50.54% 확률로 부정적인 댓글입니다.
#
# ['헉 저 덮밥? 에 데리야끼소스 안 넣으셨어요..ㅠㅠㅠ']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['나 유노 천따리  히밥 백따리 때  같은날 같이 구독햇는데  히밥은 지금 20만 코앞   그 이유가 뭘까']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['히밥님과한번같이콜라보합시다']
# --> 64.02% 확률로 부정적인 댓글입니다.
#
# ['안녕하세요~~~ 안동 신세계찜닭에서 대왕찜닭 푸파 이벤트 진행중입니다 ^^\n찜닭2마리 + 공기밥2 20분내 클리어시 상금10만원 ! 신기록 갱신시 추가로 +20만원 상금있습니다.\n시간되시면 참여 부탁드려요!!!!']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['오뎅 언제 먹었지..?']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['제목이 살짝 아쉽네요.\n오늘도 잘 드셨네요!\n오늘은 표정이 조금ㅜ 기분이 안좋아보이네요.\n우삼겹을 못먹어서 그런가...\n잘먹는 사람 보니 기분 좋네요.\n항상 응원합니다. \n다음에도 맛난거 먹어주세요!굿굿 화이팅']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['으이그 이러이 안되네~~']
# --> 64.42% 확률로 부정적인 댓글입니다.
#
# ['저는마감한시간전에와서 배터지는줄 흑당치즈볼이 젤맛잇어요 마감시간 10신데 9시40분까지먹엇어요 7분쉬구계산햇어요 빨리먹엇어요 8시50분쯤와서 떡볶이먹구잇는데 어묵다주구 볶음밥가져가라하구 위장에서욕하는줄... 사이다랑 콜라 미친듯이먹구 걷구...나온담에 미친듯이셔서 집에서 원두가루사서 아아만들어서먹엇어요저도볶음밥조합이상하게함ㅎ소스넣으니맛잇엇어요ㅋ']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['2빠다!']
# --> 59.28% 확률로 부정적인 댓글입니다.
#
# ['두끼좋아하는데 시간제한때문에  갈때마다 양껏 못먹어서 너무 아쉬워요.  끓이는 시간도있는데 두시간정도만 됐어도 ㅠㅠ']
# -->  50.71% 확률로 긍정적인 댓글입니다.
#
# ['항상 응원합니다 ᆢ건강챙기고 \n구독이 많이 늘기를 기원합니다ᆢ뒤에서 응원하니까 힘내요~~화이팅~~~~^^']
# --> 54.95% 확률로 부정적인 댓글입니다.
#
# ['말하는걸 반만 줄이면 좋을것같네요.\n먹다가 흐름 끊기네요.']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['초반에 유투브라이브킬때 매번챙겨보고\n유노님 회사들어간뒤로도 영상꾸준히 챙겨보고잇는데\n상금이 걸려잇는곳이나 무한리필로만가서 좀 그래요...\n촬영 범위도 좀 늘려줫음하네요\n상금걸려잇능곳이나 무한리필은 적당히가주세요...']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['입안에서 개한마리가 왜뛰어요.,..\n그냥 말많이안하시구 먹방하시는게...ㅠㅠ\n기분나쁘셧으면 죄송해요']
# --> 51.43% 확률로 부정적인 댓글입니다.
#
# ['식상하네요']
# --> 59.28% 확률로 부정적인 댓글입니다.
#
# ['안녕하세요 여러분! 유노입니다!\n오늘은! 어떤 음식을 가지고 왔냐면요!\n바로 1인분에 2000천원밖에 안하는!\n할범탕수육을 가지고 왔어욥 ㅎㅎㅎㅎ\n(진짜 가성비 ㄹㅇ 너무 쩌는듯..)\n영상 찍기 전에는 중국집 탕수육 대 사이즈랑\n할범탕수육 10인분이랑 비교하려고 했으나!\n여러분들에게 할범탕수육을 좀 더\n자세히 알려드리고 싶어서!\n오늘은 그냥 할범탕수육에 전메뉴를\n먹으며 소개시키는 영상을 한 번\n찍어봤는데 진짜 영상 다시 보면서도\n느끼는거지만 가성비 진짜 갑이에요..\n여러분들도 서울 강서구 목동,등촌동\n주변 지나다 시간 나시면은! 할범 탕수육\n꼭 들려보세요! 탕수육뿐만 아니라!\n할범세트,돈까스세트 막 이런 것도 있는데\n잔치국수.떡볶이.튀김2종.탕수육\n잔치국수,밥.돈까스 이렇게 주는데도\n단돈 5천원 밖에 하지 않아요..ㅠㅠㅠㅠ\n앗 너무 tmi였나..? ㅎㅎㅎㅎ 아무튼!\n여러분! 요새 날이 많이 더워져서\n마스크도 꼭 써야하고 날이 덥고 하니\n밖에 다니기 힘든데! 학업! 직장! 모두들\n고생이 많습니다! 내일은 꼭 시원하게\n휴식을 취하고! 주말 잘 보내셨으면 \n좋겠습니다! (시간나면 아프리카tv 유노라고해요 놀러와주세용 ㅎㅎㅎ)\n오늘 하루도 수고많으셨습니다!\n좋은 밤 되세요! 안녕~~!!!!\n\n🍒유노 인스타그램:https://www.instagram.com/u.n.o_o/\n🍒유노 페이스북:https://www.facebook.com/profile.php?id=100005451199138\n🍒유노 틱톡: https://www.tiktok.com/@u.n.o_o\n\n✉문의 메일 :choiyunho16@gmail.com\n\n++아 맞다! 오늘 10시 조금 넘어서! 아프리카티비 방송하니까 시간 되시면 한 번씩 놀러오셔서 채팅 갈겨주세욥!!!!! 막 갈겨갈겨!!!!']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['손점 가만히...']
# --> 61.62% 확률로 부정적인 댓글입니다.
#
# ['🏆🥇최고예요 유노~👋🙆\u200d♀️']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['아니그래서 지금 총 몇인분인지가 중요한건데\n그게빠졌네']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['진짜 넘 귀여워서 보면서 몇번을 웃었나 모르궸눼요!!😍 담부턴 빨간음식 먹을땐 어두운티 입으세요♥']
# --> 51.43% 확률로 부정적인 댓글입니다.
#
# ['이열치열이다! 날 더우니 뜨끈~한 국밥종류 가즈아!']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['유노님 날씨 더운데 좋은 영상 찍으시느라 수고 많으세요~~']
# --> 61.20% 확률로 부정적인 댓글입니다.
#
# ['배달을 시켜버리게 만드는 유노님 ㅠㅠ']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['구여우셔......😊']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['국물 튀었을땐 절대!!!  물 묻히지 말고 ****바로 퐁퐁 ****묻혀서 비빈다음   물로 헹궈요..얼룩 절대 안 남아요']
# --> 50.40% 확률로 부정적인 댓글입니다.
#
# ['밀떡이 맛난데 ㅎㅎㅎ 밀떡이었을거에요']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['대리만족 느끼는중 \n항상 맛나게 먹어서 너무좋음']
# --> 60.21% 확률로 부정적인 댓글입니다.
#
# ['오늘도 맛난거 드셨네요!! 항상 영상 잘 챙겨보고 있어용 🥰 오늘 하루도 좋은 하루~']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['외국에서 와서 젖가락질을 잘 몬하는것 같지요? 힘내요 ㅋ 연습하믄 되요~♡']
# --> 55.97% 확률로 부정적인 댓글입니다.
#
# ['분식메뉴 가성비 좋네요. 😎🤓😆😋\n양천구면 넘 멀어요.\n산더미 탕수육 대박이에요.😲\n유노님 더운데 넘 고생하셨네...😄😊\n주말 즐겁게 보내요.🍈🍉🍋\n그리고 캡이에요.🍀🍀🍀👍']
# --> 50.54% 확률로 부정적인 댓글입니다.
#
# ['오늘도 맛있게 드시는 먹방 잘보고 갑니다! 응원할꼐요!']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['오!! 저 양천구 살 때 가끔 가던 곳이네요. 엄청 맛집은 아녀도 가격 대비 좋죠. 전 잔치국수 주로 먹었어요.']
# --> 50.40% 확률로 부정적인 댓글입니다.
#
# ['초하~~~\n 가성비좋고 맛있는곳 너므좋아^^\n부천에 사는데 이쪽 리뷰할만한곳 읎나?ㅋ']
# --> 52.60% 확률로 부정적인 댓글입니다.
#
# ['2마넌치 치고는 많넹 ㅎ\n순대보다 싸네요 ㅎ']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['유노님~ 저는 탕수육이 아예  소스에 저려져서 눅눅한걸 좋아하는데~ 모두들 제 입맛을 이해할수없다고 하더라구요🤤\n오늘도 맛있는 영상 감사합니다~~^^\n참 그리고 저는 아프리카티비 앱 설치를 안해 어제 생방송을 못봤어요ㅠ\n유노님 보고싶어~ 아프리카앱 다운받아야 할까봐요 ㅎㅎ']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['양미라 조카님 아니심? 왜케닮았노']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['담에서울가면 사먹으러가야겠어요 가성비좋네요 옷에묻은 양념은 주방세제 트리오 옷에뭍혀서 30분정도놔뒀다가문지르면 깨끗하게집니다 저만의 팁입니다^^']
# --> 51.51% 확률로 부정적인 댓글입니다.
#
# ['뻘건거 묻자마자 퐁퐁을 발라야죠']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['어린 나이에 열심히 도전하는윤호 항상응원 할께요~']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['새로운곳들 많이많이 소개시켜주세요~~홧팅!!!']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['유노님 왜 오늘은 안뛰세여!!ㅎㅎㅎ']
# --> 63.21% 확률로 부정적인 댓글입니다.
#
# ['솔직히 손동작이 좀 어설퍼요 ㅠㅠ']
# --> 64.42% 확률로 부정적인 댓글입니다.
#
# ['얘기할때 저 손 움직임 ㅜ\n너--무 산만하고 어색하고 그래요...\n조금 고민하셔야  될듯요...\n얘기하는것도 연습 하고 녹화해보세요\n보다가 나가고 싶어요 ㅜ']
# --> 50.54% 확률로 부정적인 댓글입니다.
#
# ['코로나가 서울지역에 지금 꾸준히 확진자가 나오는걸로 아는데.. 영상을 찍을때 잠시 턱밑으로 내리셨겠지만... 길거리에서 뒤돌아서 가는 장면에서도 계속 마스크를 턱밑에 걸치고계시니 좀 그래요 ㅠㅠ 다른 유튜버분들은 마스크 끝까지 착용하고 이야기하시던데......']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['안녕하세요 여러분! 유노입니당!\n오늘은 바로바로 무한리필의 원조격인!\n엉터리 생고기 무한리필에 다녀왔어요!\n여기는 서울 강서구 발산역 쪽에 위치한\n엉터리생고기 마곡사이언스점인데요!\n미리 사전에 제가 좀 많이 먹는데\n계속 계속 리필 받아먹어도 괜찮을까요라고\n여쭤봤는데 얼마든지 먹어도 된다고 하셔서\n이번에 삼겹살 약 4키로를.. 털고 왔어요\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n죄송합니다.. 사장님...\n아 근데도 마지막에 결제하고 나가려고 하니까\n사장님께서 공짜로 주실려고 하셔서\n진짜 감동먹었었는데!\n음식값은 그래도 다행히 결제하고 나왔어요!\n진짜 오랜만에 고기 폭식하니까\n이 말이 진짜 와닿더라고요..\n기분이 저기압일땐 고기앞으로 가라...\n진짜 띵언...\n여러분도 오늘 하루? 내일?\n맛있는 지글지글 익은 삼겹살\n어떠신가요!?\n저는 이만! 물러나구요!\n영상 재밌게 시청해주시고!\n앞으로도 더 맛있는 영상으로\n찾아뵐게요! 안뇽!!!\n오늘 하루도 수고많으셨어요!!']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['울산의 청년 윤호군~\n울산에서 응원합니다~\n홧팅♡♡♡']
# --> 62.23% 확률로 부정적인 댓글입니다.
# ['이 분 진짜 맛있게 많이 깔끔하게 잘 드시는데 ㅠㅠ 얼른 더더욱 뜨셨으면 좋겠습니다!유노님 화이팅~!!! -구독자 3천명때부터 보던 독자 올림.']
# -->  50.21% 확률로 긍정적인 댓글입니다.
#
# ['잘 봤습니다. 근데 주실 수 있을까요? 라는 말보다 주세요가 맞는 표현 일듯. 더더욱 번창하세요']
# --> 52.60% 확률로 부정적인 댓글입니다.
#
# ['유노님도  얼렁 떡상해야델텐데']
# --> 62.23% 확률로 부정적인 댓글입니다.
#
# ['착하고 겸손한 왕자님.🤓😎😆😲\n늘 열심히 하셔서 보기 좋아요.\n구독자 얘기가 매번 나오는데 너무 연연하지 않았음 하네요. 그냥 단단한 집을 지어가는 과정이라고 생각하심 좋지 않을까 싶어요. \n노력은 절대 배신하지 않아요. \n유노님 돼지고기 트라우마로 못먹는데 넘 대리만족되네요.😆😄😊🍎🍈🍉🍋\n더위 조심하시고 건강도 잘 챙기셔요.\n그리고 캡이에요.🍀🍀🍀👍']
# --> 50.25% 확률로 부정적인 댓글입니다.
#
# ['🏆🥇최고예요 유노~👋🙆\u200d♀️']
# --> 63.55% 확률로 부정적인 댓글입니다.
#
# ['유노님 덕분에 몇달만에 삼겹살을\n(눈으로) 먹었네요. 혹시 수령처가\n바뀌지 않았다면 만두 보내드릴테니\n집에서 드실 거 없을 때 드세요.']
# --> 50.54% 확률로 부정적인 댓글입니다.
#
# ['유노님이랑 밥먹음 나 없던 입맛이 살아날거 같아 최고!']
# --> 59.29% 확률로 부정적인 댓글입니다.
#
# ['무한리필갈때 유노님 위장 빌릴수있으면 꿀이겠다...']
# --> 62.23% 확률로 부정적인 댓글입니다.

# %%
test2
# Out:
#         channel                                              title  \
# 0     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 1     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 2     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 3     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 4     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 5     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 6     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 7     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 8     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 9     유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 10    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 11    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 12    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 13    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 14    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 15    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 16    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 17    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 18    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 19    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 20    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 21    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 22    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 23    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 24    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 25    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 26    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 27    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 28    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 29    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 30    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 31    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 32    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 33    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 34    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 35    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 36    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 37    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 38    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 39    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 40    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 41    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 42    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 43    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 44    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 45    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 46    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 47    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 48    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 49    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 50    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 51    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 52    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 53    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 54    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 55    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 56    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 57    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 58    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 59    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 60    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 61    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 62    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 63    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 64    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 65    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 66    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 67    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 68    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 69    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 70    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 71    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 72    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 73    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 74    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 75    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 76    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 77    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 78    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 79    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 80    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 81    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 82    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 83    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 84    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 85    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 86    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 87    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 88    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 89    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 90    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 91    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 92    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 93    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 94    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 95    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 96    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 97    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 98    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 99    유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 100   유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 101   유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 102   유노-U_know  한국에서 가장 맵다는 불마왕라면 챌린지 도전해봤습니다! 1분 44초 안에 불마왕 볶...
# 103   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 104   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 105   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 106   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 107   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 108   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 109   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 110   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 111   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 112   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 113   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 114   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 115   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 116   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 117   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 118   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 119   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 120   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 121   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 122   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 123   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 124   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 125   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 126   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 127   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 128   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 129   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 130   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 131   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 132   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 133   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 134   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 135   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 136   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 137   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 138   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 139   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 140   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 141   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 142   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 143   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 144   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 145   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 146   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 147   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 148   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 149   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 150   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 151   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 152   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 153   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 154   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 155   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 156   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 157   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 158   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 159   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 160   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 161   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 162   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 163   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 164   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 165   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 166   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 167   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 168   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 169   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 170   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 171   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 172   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 173   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 174   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 175   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 176   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 177   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 178   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 179   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 180   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 181   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 182   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 183   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 184   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 185   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 186   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 187   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 188   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 189   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 190   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 191   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 192   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 193   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 194   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 195   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 196   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 197   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 198   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 199   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 200   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 201   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 202   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 203   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 204   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 205   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 206   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 207   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 208   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 209   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 210   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 211   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 212   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 213   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 214   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 215   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 216   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 217   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 218   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 219   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 220   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 221   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 222   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 223   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 224   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 225   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 226   유노-U_know  실비김치 광고 받았는데 너무 솔직하게 리뷰해서 죄송합니다 광고주님.. 실비김치에 짜...
# 227   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 228   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 229   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 230   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 231   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 232   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 233   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 234   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 235   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 236   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 237   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 238   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 239   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 240   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 241   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 242   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 243   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 244   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 245   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 246   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 247   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 248   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 249   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 250   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 251   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 252   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 253   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 254   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 255   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 256   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 257   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 258   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 259   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 260   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 261   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 262   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 263   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 264   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 265   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 266   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 267   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 268   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 269   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 270   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 271   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 272   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 273   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 274   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 275   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 276   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 277   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 278   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 279   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 280   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 281   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 282   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 283   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 284   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 285   유노-U_know  마피아 떡볶이 고기 떡볶이에 튀김 8종 먹방!! 저는 이 떡볶이 원픽입니다.. Ko...
# 286   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 287   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 288   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 289   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 290   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 291   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 292   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 293   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 294   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 295   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 296   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 297   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 298   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 299   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 300   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 301   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 302   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 303   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 304   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 305   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 306   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 307   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 308   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 309   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 310   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 311   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 312   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 313   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 314   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 315   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 316   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 317   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 318   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 319   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 320   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 321   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 322   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 323   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 324   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 325   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 326   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 327   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 328   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 329   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 330   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 331   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 332   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 333   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 334   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 335   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 336   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 337   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 338   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 339   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 340   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 341   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 342   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 343   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 344   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 345   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 346   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 347   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 348   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 349   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 350   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 351   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 352   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 353   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 354   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 355   유노-U_know  단짠단짠 최고!! 밥 한 대접에 국물 치즈두루치기 먹방! korean eating ...
# 356   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 357   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 358   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 359   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 360   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 361   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 362   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 363   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 364   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 365   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 366   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 367   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 368   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 369   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 370   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 371   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 372   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 373   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 374   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 375   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 376   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 377   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 378   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 379   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 380   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 381   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 382   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 383   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 384   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 385   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 386   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 387   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 388   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 389   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 390   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 391   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 392   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 393   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 394   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 395   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 396   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 397   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 398   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 399   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 400   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 401   유노-U_know  고기국수 6인분에 삼겹살1kg!! 완전 꿀조합입니다.. 완전 강추!!! korean...
# 402   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 403   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 404   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 405   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 406   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 407   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 408   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 409   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 410   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 411   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 412   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 413   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 414   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 415   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 416   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 417   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 418   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 419   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 420   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 421   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 422   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 423   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 424   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 425   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 426   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 427   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 428   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 429   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 430   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 431   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 432   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 433   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 434   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 435   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 436   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 437   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 438   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 439   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 440   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 441   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 442   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 443   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 444   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 445   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 446   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 447   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 448   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 449   유노-U_know  모듬돈까스 약 3KG 10장 먹방! 먹다가 입 천장이 없어질뻔 했습니다.. ㅋㅋㅋㅋ...
# 450   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 451   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 452   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 453   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 454   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 455   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 456   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 457   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 458   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 459   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 460   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 461   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 462   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 463   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 464   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 465   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 466   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 467   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 468   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 469   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 470   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 471   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 472   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 473   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 474   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 475   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 476   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 477   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 478   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 479   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 480   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 481   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 482   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 483   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 484   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 485   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 486   유노-U_know  자메이카 통다리 4마리 황금올리브 닭다리 1마리 치즈볼 5종 먹방 후식으로 자메이카...
# 487   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 488   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 489   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 490   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 491   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 492   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 493   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 494   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 495   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 496   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 497   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 498   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 499   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 500   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 501   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 502   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 503   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 504   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 505   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 506   유노-U_know                        온정돈까스 혼내고 3개월 무료식사권 받아왔습니다!
# 507   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 508   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 509   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 510   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 511   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 512   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 513   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 514   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 515   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 516   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 517   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 518   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 519   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 520   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 521   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 522   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 523   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 524   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 525   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 526   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 527   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 528   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 529   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 530   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 531   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 532   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 533   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 534   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 535   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 536   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 537   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 538   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 539   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 540   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 541   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 542   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 543   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 544   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 545   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 546   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 547   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 548   유노-U_know  야식으로 간단하게 KFC치킨 30조각 먹방! KFC Chicken Korean ea...
# 549   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 550   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 551   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 552   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 553   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 554   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 555   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 556   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 557   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 558   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 559   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 560   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 561   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 562   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 563   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 564   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 565   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 566   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 567   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 568   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 569   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 570   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 571   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 572   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 573   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 574   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 575   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 576   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 577   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 578   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 579   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 580   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 581   유노-U_know  이마트 달달한 디저트9종과 마카롱! 1L달고나라떼 흑당버블티 딸기밀크쉐이크 먹방! ...
# 582   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 583   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 584   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 585   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 586   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 587   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 588   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 589   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 590   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 591   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 592   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 593   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 594   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 595   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 596   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 597   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 598   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 599   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 600   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 601   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 602   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 603   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 604   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 605   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 606   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 607   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 608   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 609   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 610   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 611   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 612   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 613   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 614   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 615   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 616   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 617   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 618   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 619   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 620   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 621   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 622   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 623   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 624   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 625   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 626   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 627   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 628   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 629   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 630   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 631   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 632   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 633   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 634   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 635   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 636   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 637   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 638   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 639   유노-U_know  고기폭탄짜파게티! 우삼겹,삼겹살 1kg 짜파게티 4봉 먹방! mukbang eati...
# 640   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 641   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 642   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 643   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 644   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 645   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 646   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 647   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 648   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 649   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 650   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 651   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 652   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 653   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 654   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 655   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 656   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 657   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 658   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 659   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 660   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 661   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 662   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 663   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 664   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 665   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 666   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 667   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 668   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 669   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 670   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 671   유노-U_know                          간단하게 연어 1kg! 통연어,연어국수 먹방!
# 672   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 673   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 674   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 675   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 676   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 677   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 678   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 679   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 680   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 681   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 682   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# 683   유노-U_know  bhc 치즈볼 100개 도전먹방! 다신 안할래요..korean eating chal...
# ...
# 2994                                            만세 닮았어요     1
# 2995                                         워매 엄청 잘드시네     0
# 2996    구독자 명일 때 댓글 남겨요 만은 무조건 돌파하실 듯 이정도면 국내를 넘어 월클이네요     5
# 2997                                          먹방 최고봉인듯      0
# 2998              유노유노 화이팅 누구냐넌경자년 만수무강하시고 대기만성하는 유노되소서     2
# 2999                        고치라는 댓글들 불편 너무 상처 안받으셨으면 ㅎㅎ     0
# 3000  목소리 진짜 좋네요 ㅎㅎ 근데 일자 앞머리 컷보단 좀 긴게 더 순정만화일본애니 주인...     0
# 3001                     전문가님들 유노님 스프라이트 할 때 짤 좀 만드러주세요     1
# 3002                                       넘 기여운데욤 ㅠㅠㅠㅠ     0
# 3003                너무 잘드셔서 기대반 걱정반 하면서  보게 됩니다 늘 응원합니다     6
# 3004                                              화이팅임댜     0
# 3005  오물오물 너무 잘드신다 진짜 유노님이 내 친동생이였음 좋겠어요 매일 델꾸다니면서 맛...     1
# 3006  맛있게먹는모습이 보기만해도 행복해지네요그리고 눈코입 다 완벽 그자체임 이상한소리 그...     0
# 3007                                       맷 스토니가 생각납니다     0
# 3008                      또다른 여자신인은 완전 대형급 거물신인 ㅋㅋㅋ 히밥님     1
# 3009                   ㅎㄷㄷ 진짜 다시 드셔서 올리셧네요ㅜㅜ넘넘 잘드시는 유노뉨     4
# 3010                                           마리 어데로갔노     0
# 3011                        대단하십니다 바로 구독 눌렀습니다 응원할게요 ㅎㅎ     0
# 3012                                         말이말문이막혔 후허     0
# 3013  무리해서 드시는거 아니죠ㅠㅠ건강이 제일 우선이에요영상보니 치킨이 너무 먹고싶어지네요...     0
# 3014                              아니 시간동안 먹기만 하면 턱 안아파요     0
# 3015                                                 대박     0
# 3016         배부른것도 있겠지만 물리고 씹는게귀찮아서 지쳤겠음 ㅋㅋ정말 맛나게 잘드십니다     0
# 3017                                 끝나고 토하시죠토해도 못먹을듯ㄷㄷ     1
# 3018                   대리 만족 실컷 하고 갑니다 잘 봤어요 먹방유노펜이 될 듯     1
# 3019                                 윤호파이팅항상응원하고 항상볼게성호     1
# 3020                                     형님 닭다리 하나만 주십쇼     1
# 3021             정말 잘드시는데  어쩜 이리  날씬할까요  뼈  조심하고 천천히 꼭꼭     0
# 3022                               진짜 정말 잘드시네요앞으로도 승승장구     0
# 3023  광마니 히밥 등이 먹었던 늘봄식당 도전성공시 기부되는 그곳도 시간되시면 도전해 주세...     0
# 3024  먹는 모습이 다람쥐 같이 귀엽고 앙증맞아요ㅋㅋ소화제 꼭 챙겨드시고 건강하세요널 응원...     4
# 3025                                       금방뜰것같아요 진심으로     0
# 3026                                       닭뼈 무덤    대박      4
# 3027                          와  대박이네요  한달  식비는 얼마나 나와요     0
# 3028  남 말에 신경쓰지말아요 다 끌고갈 순 없어요 원래 사람은 다 재각각이라 생각도 다르...     1
# 3029                                        와 대박 구독 박아요     0
# 3030                                와정말 많이 먹네요 조심해서 드세요     0
# 3031             닭먹다가 갑자기 밥 적응안됄라구해난 한계가마리인대 ㅋㅋㅋ거기다 밥까지     0
# 3032                                     진짜 대단하네요 구독했어요     2
# 3033                                          치킨을마리 먹는겨     0
# 3034         와 진짜 존경스러워요영상 몆개보다 구독하구갑니다ㅎ인성까지 잘생기신듯응원합니다     1
# 3035                               분명 먹으면서 밑으로 싸고 있을듯ㄷㄷ     0
# 3036                          이 영상도 구독전에 몇번 봤는데 진짜 캡이네요     1
# 3037             노컷 원래 안보는데 유노님껀 노컷 기본배속으로 다 보네요 노컷 좋아여     2
# 3038              음료 먹으면 더 배부르지않나요 근데도 쭉쭉 들어가시네 대박이다 ㅠㅠ     0
# 3039  상해기 먹방보고 너무 놀랐는데 유노 먹방 보고서는 말도 안나오네 그많은 양이 도대체...     0
# 3040                        우와작은체구에서어떻게저만큼드시는지신기하고대단하네요     0
# 3041                                             ㅋ산더미치킨     0
# 3042                  윤정돈가스보고 구독해요 건강생각하시면서 먹방 즐기세요 화이팅     0
# 3043  전부다보고왔는데 진짜  먹방 유튜버 중 누구에게도 뒤지지않는거 같네요  화이팅구독 ...     3
# 3044                                                 천명     1
# 3045                                 다이어트 하는데 배고프자나요ㅠㅠㅠ     0
# 3046              천명 축하해요 곧 더 빠르게  떡상 할겁니다  진짜 유노님 먹방최고     0
# 3047                              엠브로처럽병원실려가기싫음몸건강신경스세요     0
# 3048        진짜 어떻게 저게 다들어가나요 ㅋㅋㅋㅋ나도 진짜 많이먹는데 역대 최고가 마린데     0
# 3049  저희 둘째 구염둥이 아들이랑 비슷하게 생겨서 엄청 귀여워요 ㅋㅋ아직 초보 먹방분이셔...     0
# 3050                                 앞으로 더 좋은 모습들 기대할게요     1
# 3051                                             귀요미귀요미     1
# 3052            어머나 저 많은 조각들이 다 사라지ㄴ 와 잘먹고 아니ㅡㅡ 잘보고 갑니당     0
# 3053  헐 유노님은 정말정말 떡상하실것 같아요 오늘 올리신 영상 보느라 벌써 시간이 네시네...     0
# 3054                         쯔양님 남자버전이 나타나셧네둘이 합방하면 지릴듯    16
# 3055                    유노님은 유아기 초딩기 때부터 많이 드셨나요 타고나신듯      0
# 3056                                          우와 넘사벽이네요     0
# 3057                                             치킨이고싶다     1
# 3058       저정도 양이면 저렇게 벌려놔서 많아보이는 거지 실제로는 존나 많음 ㅅㅂ 어캐먹노     0
# 3059                                        대박 구독하고 갑니다     1
# 3060         닭들이 유노님보면 무서워하겠어요피자마루 치즈폭탄피자도 드셔주시면 안돼나요ㅎㅎ     0
# 3061                                     뼈는 안보이는데 놔라더럽게     4
# 3062  먹방 꽤나 본 사람으로서 잘 될것 같습니다 비싸지기전에 싸게 광고영상 한번 합시다 ...    27
# 3063                                    구독박고갑니당진짜 잘드시넹ㅎ     0
# 3064                         건강에 이상은 없으신거죠ㅜㅜ영상볼때마다 걱정돼요     0
# 3065                             자메이카부터 다르네요 귀여워용 구독합니당     1
# 3066       치킨 마리 정도는 식은죽먹기지 ㅋㅋㅋ그래서 제 죽은 아직까지 식지 않고 있습니다     1
# 3067  저게 다 어디로나지금 뭘본거지꼭꼭 씹어먹어요 근데 저렇게 치킨산이 내눈앞에 있다면기...     0
# 3068  첨엔 닭 탑을 보고마지막엔 뼈 탑을 보고진짜 나두 마니먹는거  어디가섳빠지지않는데슬...     1
# 3069  먹방의 판도가 뒤바뀌겠다 이분 보니까 유노님 떡상하시겠어요ㅋㅋ백만은 금방 가겠네 구...     3
# 3070                                     이것을 다 먹다니대단 대단     1
# 3071                                외국 배우중에 데인 드한이랑 닮았넹     2
# 3072                                         맛있게 먹는걸로 등     0
# 3073                비비큐 어떻게 해야 당첨되죠이분이 당첨됐으면 좋겟어요 개인적으로     1
# 3074  답글 하나하나 다시느라 귀찮아하실거 같아두 댓글 쓰고 갈래요 ㅜㅜ햄찌처럼 와구와구 ...     0
# 3075                                새벽에 배고파서 들어왔네요 맛있겠다     0
# 3076                                       오오옹 구독자 명 ㄷㄷ     1
# 3077         먹방유투버라사과먹방 자주 올리시네ㅋ사과 그만대신 맛있는 음식먹방으로응원합니다     0
# 3078                                        오오대박ㅎ구독 좋아요     1
# 3079                                                맙소사     0
# 3080                대박 유튜버로 질주하시길첨이다이렇게까지 많이 먹는분응원합니다 님     1
# 3081                                 나도 저렇게 쌓아두고 먹어보고싶다     1
# 3082                                구독하고 가요ㅎㅎ 잘되셨음 좋겠어요     1
# 3083  정말 대단하시네요ㅜㅜ 대리만족 하고 갑니다ㅠ 항상 건강 챙기시면서 즐겁게 촬영 하세...     1
# 3084                                         뼈다귀는 뼈다귀통에     7
# 3085    엄청 먹는데 소화 잘 되시나요건강 잘챙기시며 방송하시길 바래요대단한 먹방 보고 갑니다     0
# 3086                                            저걸 다먹다니     0
# 3087  닭다리 끝에 물렁뼈 안먹는거 불편영상 잘 보고 있어요 년 연말에는 구독자만명 넘기고...     1
# 3088  뼈를 왜 치킨위에다 ㅋㅋ 맛 표현 하면서 먹음 좋겠어요 다른 이야기라도요 끝까지 맛...     4
# 3089  와 진짜 엄청잘드시네요 ㅋㅋ 저많은게 어디로 가는거죠 ㅎ 대단하심 먹방강자화이팅입니...     4
# 3090  티도안나게 먹겠지만 저두 저렇게 쌓아놓구 먹어보고싶네요 미국이라 못먹어서 더더 먹구...     0
# 3091                                                인 닭     0
# 3092                           상해기님의 오늘 올라온 도전먹방 도전해주세요     0
# 3093  번째 구독자예용위대하시네요 유트브 잘시작하셨어요 대리만족중언능 구독자 올라서 식비 ...     6
# 3094                                           으아  배고프당     1
# 3095           아무리 치킨이여도 저정도면 물리고 안물린다고쳐도 위에 저게 어케 다들가지     0
# 3096          유노님  대단하시다요  항상 응원할께요건강생각하시고 새해복  많이받으세요      1
# 3097                                          눈 진짜 이쁘세요     1
# 3098  기름진거 먹으면 저도 아이스크림 타령하는뎈ㅋㅋㅋ 너무 맛있게 잘 드셔서 좋아요 초기...     2
# 3099                                           마리를 다먹허걱     0
# 3100                                               잘묵네요     2
# 3101                                   히밥이랑 합방한번했으면 좋겠네     0
# 3102                            뼈는왜ㅋ 밑에버려요천천히 꼭꼭씹어서 드세요     2
# 3103                     유노님 영상하나보고 반해서 정주행해버렸습니다 대성하실듯     1
# 3104          우왘ㅋㅋㅋ저랑 동갑이시네요 같은 나이 다른 위크기대단해요 응원해요떡상하십숑     1
# 3105                                              빙수야 ㄱ     0
# 3106  ㅡㅡ 닭똥집 먹방해주세요대구에 평화시장에 닭똥집 튀김 있어요 ㅎㅎ 간장 양념 후라이...     1
# 3107  저 원래 쩝쩝 거리면서 먹는 유튜버 손절 하는데 이분은 왠지 괜찮아그래도 조금 줄여...     6
# 3108                                           참 맛나게 먹네     0
# 3109               조회수 좋아요까지 점수에 반영한다니  어떻게 홍보를 해드려야 하나     1
# 3110          저 거짓말 아니고 이번주에 이친구 곱창 사주기로 했는대 대출 받아야 할까요     1
# 3111                             누구세요신상소개  좀  해주세요궁금합니다     1
# 3112           저많은 양을 먹고 소화시키려면 하루에 운동을 몇시간이나 하는건가요 ㅎㄷㄷ     0
# 3113  이야저 많은것이 어디로 들어가누속은 괜찮은지 모르겠네요우연히 오늘 첨 보게 됐는데 ...     1
# 3114  유노님 구독자분들도 생기셨는데  팬애칭 정하면어떨까요유노님이시니까 팬 애칭은아이 노...     1
# 3115   헐ㅋ 구독자님들하고 트름 트셨네요 ㅋ 축하 곧 구독자 명이시네요 구독자 이벤트는 없나요     2
# 3116                                              사람 맞음     0
# 3117                                        왜  이거 하는건가요     0
# 3118                                                잘묵네     1
# 3119           저 많은 것을 다 먹나요 상상으 못하게네  음식은 줄지 않고 걱정이 대네     0
# 3120                                        진짜 이걸 다먹는걸까     0
# 3121                                          존나 잘처먹네 ㅋ     0
# 3122                                 유노님은 어릴때부터 대식가 셨나요     0
# 3123                                     카메라 설정은 해결하셨나요     0
# 3124                                    응원합니다 진짜잘드시네요ㅋㅋ     1
# 3125                                         먹는소리가 너무커요     1
# 3126                                                ㄹㅈㄷ     0
# 3127                                     한달에 식비 얼마나 들어요     0
# 3128                                   닭들에 무덤에 조의를 표합니다     1
# 3129                                             살 안찌나요     0
# 3130  입안에 내용물이 너무 많이보여서 그것만 고치시면 훨씬 더 좋은 영상이 될거같아요 맛...     9
# 3131  유노님은 대박날듯첫번째 많이잘먹는다두번째 예의있음세번째  눈속임안함네번째  맛있게 ...    12
# 3132                                         저 번째 구독했어요     1
# 3133                                          비비큐는 믿거해야     0
# 3134                                          음료 식혜 드세요     0
# 3135                        혹시 키가 몇신지 궁금하네요  기럭지가 커보여서요     0
# 3136                             유명해지기 전에 미리 구독해야지 ㅎㅎㅎㅎ     1
# 3137  전 라면 두개먹으면 숨쉬기힘들정도로 배불러지는데  많이드시는분보면 신기해요많이드시면...     0
# 3138  쯔앙님이랑 대결해보심 ㅋㅋ 쯔앙님이 감히 대결신청 하는 사람이 없다는데 야식님보다 ...     0
# 3139                      다 좋은데 뼈를 안보이는 곳에다 두면 좋을 거 같아요    23
# 3140  ㅋㅋㅋㅋㅋ에휴 진짜 못 먹네아니요  여러분 저 말입니다 저  다이어트중이라서 못 먹...     3
# 3141  푸파를 마니하셔서 빨리먹는게 습관이 되신듯 좀 덜먹어도 되니 보는 사람이 즐길수있게...     0
# 3142                         침샘의 붓기  다크마른정도 약간 의심이 가는걸요     0
# 3143                                          먹다가 질리겠는데     1
# 3144                              뼈을 왜 한가운데 노우세요 비우상요 ㅠ     0
# 3145  카메라 발열문제로 꺼지는 듯합니다 현재 사용하시는 카메라가 어떤 모델인지는 모르겠으...     1
# 3146  개인적으로 괜찮은데 뼈다귀는 따로 다른곳에 치우는게 어떨까요 남은 찌꺼기를 앞에 보...     4
# 3147                                              니가등이다     1
# 3148  ㅋㅋ 죄송합니다  귀여운 아들같네  치킨뼈는 치킨 위에 놓지말고  뼈가 보여도 개안...     2
# 3149                                  쩝쩝안하면서 음식을먹을수있나 ㅋ     2
# 3150                                           쩝쩝거리는거싫다     1
# 3151                            쩝쩝소리들으면 배 더 고픈 내가 이상한건가     0
# 3152                             다음부터 뼈는 따로 분리 하셨으면 좋을듯     1
# 3153                                          제발뼈는쓰레기통에    15
# 3154    요즘젊은이들은 대기업같은데 갈필요없다 위좀늘러서 먹방하면 바로 어린나이에 떼돈벌수있다     0
# 3155  어케요광고지라도 돌려야하나첫영상보고 구독자가 됐는데 구독자분이 많아야 좋아요도 많을...     2
# 3156                               님 씹고 뱉으세요 그만 드세요 죽어요     0
# 3157                             신기해서보다가 뼈쌓이는거 더럽그만보게됨ㅠ     1
# 3158                       다 좋은데 왜 입에 넣었던 뼈들을 음식위에 놓는건지    19
# 3159                            쩝쩝하는 것만 고치시면 좋을 것 같아요 ㅠ    39
# 3160  나는 쩝쩝소리 별로 신경 안쓰이는데 의외로 싫어하시는 분이 많네요 잘먹는 모습이 보...     1
# 3161           드실때 입을 다물고 드시면 더 좋을꺼 같아요ㅜ입안에 음식이 조금씩 보여서     3
# 3162  먹을때 입다물고 먹으면 더 조을듯 싶네요되새김질 하듯이 입 밖으로  음식이 왔다리갔...    13
# 3163             입을 다물고 먹으면 음식물도 안보이고 쩝쩝소리도 안나서 좋을거 같아요     2
# 3164     먹을때 입안음식물 안보이게 뼈는 안보이게좀 너무 쩝쩝대시는듯세개만 고치면 떡상 가능    41
# 3165                                   뼈를왜 음식위에놓냐드러워죽갓네     1
# 3166  잘드시네요 진짜ㅠㅠ근데 입안의 내용물이 너무보이시게드시는거같아여ㅠㅠ 그것만고치시면 ...     6
# 3167              쩝쩝  하면서 음식물 보이며 드시는거만 고치면  좋을듯제생각 입니다    25
# 3168                   음식 쓰레기 시청자 보라고 쌓아 놓는거 보소매너 참 더럽다     0
# 3169          씹을 때 입안에 음식물이 보여요 그것만 좀 신경 써 주시면 좋을 것 같아요     5
# 3170              다좋은데요 입 다물고드셔주시면ㅜㅜ음식이자꾸보여서요제개인의견입니다ㅜㅜ     0
# 3171  먹었던 치킨뼈는 통 같은데에 버리셨으면 좋겠어요 그리고 먹방보러 온사람들한테 트름도...     1
# 3172  왜이리 더럽게 먹냐 입안에 안보이게좀 먹던지 십은거 다보이노 고칠껀 고치면서 먹방하...     2
# 3173               드럽게 뼈다귀를 니가 먹는 음식에 올려 놓냐 보는 사람 생각안하냐     1
# 3174  입안에 음식물이 다 보이는건 좀 많이 보기 안좋네요 쩝쩝소리도 너무 심하고 드실 때...     6
# 3175               뼈를 왜 보이는 앞에 놔두는거야 ㅈ 같네 ㅈ 더러움 ㅈㄴ 짭짭대고     1
# 3176                                       입좀 다믈고 ㅠㅠ 드러     1
# 3177                        일부러 그러는 건지 입 벌리고 쩝쩝대는거못 듣겠음     5
# 3178  움식에 대한 개인적인 감정표현이 너무 없어서  내내 무표정  먹기만 하는인공지능 같...     1
# 3179  뼈를 좀 입을 좀 다물고 드세요 소처럼 입앞으로 음식 혀로 내굴리는거 안좋아요 여태...     2
# 3180                              전설의 시작년후 이 댓글은 성지가 된다    15
# 3181                                 귀엽게 생겼는데 목소리는 상남자네    22
# 3182               사장님앞에서 자꾸 말걸지마세요근무중에잡담은  먹방에 방해가됩니다ㅎ     9
# 3183         이분 대박각이다  외모도 귀엽고 예의바르고 깔끔하게 잘 먹고 대박나세요흥해라     2
# 3184                                    안타까워요괜찮아요넘 잘했어요     0
# 3185                        첫영상부터 유노님직원분들 인성에 보기가 훈훈합니다     2
# 3186                             아이고 아까워라 ㅠㅠ잘될꺼야 분명히 유노     4
# 3187                           아니 저건 다먹은거지진짜 너무하네성공한거예요     2
# 3188                                              응원합니다     4
# 3189                                       분명 쯔양급으로 되실듯     2
# 3190  진짜 궁굼한데 보통 저 정도 먹을 정도면 원래 양이 크다는건데 그동안 식비를 어찌 ...    10
# 3191             와 ㅠㅠ 아쉽다ㅠㅠ근데 먹기전 빵을 왜드시는지궁금한데 알 수 있을까요    14
# 3192             이분은 떡상각이다 존버한다 깔끔하게 먹으면서 옷이나 얼굴 다 깔끔해      6
# 3193                                    옆모습 짤 문희준 리즈 빼박     0
# 3194  벌써 명 완전 축하드려요첫 영상 분명 레전드 될듯차근차근 상승중인 작년에 데뷔한광마...     0
# 3195                                   먹는거 왤케 오물오물 귀여우심     1
# 3196                       대단하시네요 구독 누르고갑니다 곧 유명해지실것같네요     7
# 3197                                  초면이지만 진짜 제 이상형이세요     0
# 3198                                         이 채널 떡상하겠다     0
# 3199                                           년 떡상할유튜버     0
# 3200     최근에 입덕하고 영상 정주행해요 너무 아쉽네요  근데 진짜 턱아플것같아요 수고했어요     0
# 3201        뭔가 진짜 잘 될 거 같은 느낌제가복희님 초창기 때 찾았거든요뭔가 삘이 오는데     1
# 3202                                         아 착해ㅠㅠ아아쉽다     0
# 3203                                           조회 천회 돌파     2
# 3204                                          대박나라 할수있다     3
# 3205                            도전영상 두개보고왔는데  이분이 찐이네ㅋㅋ     0
# 3206                                           진짜 파이팅이다     5
# 3207  유노님 비비큐인가 닭다리 개 먹는거 있는데 도전해보심 안되나요 상해기님은 실패했는데...     8
# 3208                                재도전 응원할께요 충분히 가능하실듯     1
# 3209                                         햄버거 개는먹겠는걸     0
# 3210                         예의바르고 잘생겼네요구독 누르고 갑니다대박나세요     3
# 3211                     썸녤 오류인가여 왼쪽 밑에 온정 돈까스라고 처져 있는데     0
# 3212                            너무잘먹어요 대단해요 ㅋㅋ먹방계의 레젼드      0
# 3213                      빵 먹고 시작하는거 부터 대단하네요 ㅎㅎ 좋아요 구독     0
# 3214                                        구독독독구독전설이다ㅋ     0
# 3215  넘 아쉽게 실패한거군요 ㅎ  두번째 성공했쟌아요 ㅎㅎ 넘아쉽다 ㅠ 넘고생했네요 행복하세요     0
# 3216                                                 대박     3
# 3217                                              귀요우시당     0
# 3218                               저정도면 성공으로 해주지ㅠㅠ 아쉽네요     0
# 3219                                      급하게 먹지 말고 화이팅     0
# 3220  성공한거보고 역순으로왔는데저 원인의 식빵 가서 뺏고싶다 ㅋ그나저나 저기 직원분들 진...     0
# 3221                                                 유노     2
# 3222                                          아 몰라 구독이야     0
# 3223  아 이땐 실패를 햇구나 ㅎㅎㅎ실패는 성공의 유노성공햇는데  담에그 영상을 구독자분들...     0
# 3224              악마지막 찌끄래기 땜에 떨어지다닝우짜쓰까잉응원합니다 으쌰으샤 하시길     1
# 3225                                               구독 꾹     0
# 3226                                        도전 해 보고 싶네여     0
# 3227                                            김재원 닮았다     0
# 3228                                                 유노     3
# 3229                                            아유 잘하는교     2
# 3230                     근데  다른영상은 후라이드에 양념치킨소스 부어먹든데ㅠㅠ     0
# 3231                                  잘봤습니당 구독 좋아요박고 가요     0
# 3232                                     인스타 안하시나요ㅠ내이상형     0
# 3233                                                시작      0
# 3234                             아쉽네요ㄷㄷ크게 될 먹방유튜버 인것같네요     1
# 3235                           오늘  번째 구독자는  나야나진심 응원합니다     1
# 3236                                            근데 맛있겠다     0
# 3237                                             너무 아깝네     0
# 3238                               이정도는 성공이라 봐도 괜찮지 않을지     3
# 3239                             저도 월욜날도전하는데 팁같은거  잇을까요     1
# 3240                                         여기는 어느점인가요     1
# 3241  요즘 신흥 먹방러들은 외모도 장난 아니네요쯔양님 상해기님 유노님 스타가 될만한 실력...     1
# 3242              인성 너무 좋아요 말하는것도 좋고 쯔양님 보다 더 크게 성공하시기를     0
# 3243                                      빵 먼저먹은이유가 뭐에용     1

# %%
test2=pd.read_csv('유노-U_know_meta_comment.csv')
